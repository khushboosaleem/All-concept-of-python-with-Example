# %%
file_name = "compensation data.csv"

# %%
with open(file_name) as f:
    print(f)
# Out:
# <_io.TextIOWrapper name='compensation data.csv' mode='r' encoding='cp1252'>

# %%
with open(file_name) as f:
    data = f.read()

# %%
data
# Out:
# 'experience_coding,python_user,r_user,sql_user,most_used,compensation\n6.1,TRUE,FALSE,TRUE,Scikit-learn,124267\n12.3,TRUE,TRUE,TRUE,Scikit-learn,236889\n2.2,TRUE,FALSE,FALSE,None,74321\n2.7,FALSE,FALSE,TRUE,None,62593\n1.2,TRUE,FALSE,FALSE,Scikit-learn,36288\n1,TRUE,FALSE,FALSE,PyTorch,61302\n1.8,FALSE,FALSE,FALSE,None,68984\n6.1,TRUE,FALSE,FALSE,TensorFlow,18858\n4.5,TRUE,FALSE,TRUE,Scikit-learn,55418\n1.1,TRUE,FALSE,TRUE,TensorFlow,614\n2.7,TRUE,TRUE,TRUE,None,70564\n0.93,TRUE,TRUE,FALSE,Scikit-learn,55525\n0.32,TRUE,FALSE,FALSE,None,61005\n9.9,TRUE,FALSE,TRUE,Scikit-learn,2846\n0.78,TRUE,FALSE,FALSE,TensorFlow,21\n13.5,TRUE,FALSE,FALSE,Scikit-learn,14699\n26.5,TRUE,FALSE,TRUE,Scikit-learn,2110\n1.5,TRUE,FALSE,TRUE,Scikit-learn,620\n3.4,TRUE,FALSE,TRUE,PyTorch,73527\n0.6,FALSE,FALSE,FALSE,None,6992\n0.95,TRUE,FALSE,FALSE,None,22311\n4.6,TRUE,TRUE,TRUE,Scikit-learn,1377\n2.8,FALSE,TRUE,FALSE,None,69174\n28.2,TRUE,FALSE,TRUE,Scikit-learn,117636\n1.4,TRUE,TRUE,TRUE,TensorFlow,65937\n4.8,TRUE,FALSE,FALSE,Scikit-learn,27856\n0.37,TRUE,TRUE,FALSE,Scikit-learn,903\n4.5,TRUE,FALSE,FALSE,TensorFlow,50501\n4.4,TRUE,FALSE,FALSE,Scikit-learn,482\n0.69,TRUE,FALSE,FALSE,None,70407\n1.5,TRUE,FALSE,FALSE,None,8690\n9.6,TRUE,TRUE,TRUE,None,114648\n0.31,FALSE,TRUE,FALSE,None,73454\n3.5,TRUE,FALSE,FALSE,None,8075\n1,TRUE,FALSE,FALSE,None,59151\n0.2,TRUE,TRUE,TRUE,None,70112\n0.39,TRUE,FALSE,TRUE,None,70183\n5,TRUE,FALSE,FALSE,None,64502\n4,TRUE,FALSE,TRUE,None,2521\n0.47,TRUE,FALSE,FALSE,Scikit-learn,63616\n8.1,TRUE,FALSE,TRUE,Scikit-learn,59849\n1.8,TRUE,FALSE,FALSE,None,31516\n17.1,TRUE,FALSE,TRUE,TensorFlow,18582\n1.4,TRUE,FALSE,FALSE,Keras,4187\n1.3,TRUE,FALSE,FALSE,None,64405\n3.1,TRUE,FALSE,FALSE,Keras,114807\n0.26,TRUE,FALSE,TRUE,Scikit-learn,632\n2.1,TRUE,TRUE,FALSE,Scikit-learn,61157\n4.4,TRUE,FALSE,TRUE,Keras,1194\n5.2,TRUE,TRUE,FALSE,Scikit-learn,28955\n0.7,TRUE,TRUE,TRUE,TensorFlow,56553\n0.69,FALSE,FALSE,FALSE,None,75177\n1.3,FALSE,TRUE,TRUE,None,28009\n1.5,TRUE,FALSE,TRUE,Scikit-learn,67074\n2.2,FALSE,FALSE,TRUE,None,50059\n6.3,FALSE,FALSE,FALSE,TensorFlow,7624\n2.9,TRUE,FALSE,FALSE,None,74321\n1.2,TRUE,TRUE,FALSE,None,671\n1.5,TRUE,FALSE,TRUE,TensorFlow,837\n1.8,TRUE,FALSE,TRUE,Scikit-learn,2011\n0.91,FALSE,FALSE,FALSE,Scikit-learn,62937\n4.5,TRUE,FALSE,FALSE,None,685\n1.6,TRUE,FALSE,TRUE,Scikit-learn,41615\n0.27,TRUE,FALSE,FALSE,None,52572\n2.6,TRUE,FALSE,FALSE,Scikit-learn,51856\n1.7,TRUE,FALSE,FALSE,Keras,411\n0.74,TRUE,FALSE,FALSE,None,152\n2.7,TRUE,FALSE,FALSE,TensorFlow,8181\n0.99,TRUE,TRUE,FALSE,Keras,2708\n24.8,TRUE,FALSE,FALSE,Scikit-learn,55041\n0.32,TRUE,TRUE,TRUE,Scikit-learn,68412\n3.5,FALSE,FALSE,TRUE,TensorFlow,6141\n5.7,FALSE,FALSE,TRUE,None,3979\n22,TRUE,FALSE,FALSE,Keras,3760\n9.9,TRUE,FALSE,FALSE,Keras,57465\n3.9,TRUE,FALSE,FALSE,Keras,3864\n20.5,TRUE,FALSE,FALSE,None,488487\n0.81,TRUE,FALSE,FALSE,Scikit-learn,24393\n9.8,TRUE,FALSE,FALSE,TensorFlow,68624\n1.5,TRUE,FALSE,TRUE,None,70796\n12.3,TRUE,TRUE,TRUE,Scikit-learn,236889\n6.6,TRUE,FALSE,TRUE,PyTorch,57861\n2.1,TRUE,FALSE,FALSE,None,21055\n2.5,TRUE,FALSE,FALSE,Keras,59167\n0,FALSE,FALSE,FALSE,None,55882\n1.7,FALSE,FALSE,FALSE,None,73802\n5.3,TRUE,FALSE,TRUE,Scikit-learn,21206\n1.4,TRUE,FALSE,TRUE,Scikit-learn,79803\n1.5,TRUE,FALSE,TRUE,None,73043\n28.2,TRUE,FALSE,TRUE,PyTorch,268191\n0.97,TRUE,FALSE,TRUE,Scikit-learn,14298\n1.1,TRUE,FALSE,TRUE,Scikit-learn,68805\n7,TRUE,FALSE,FALSE,TensorFlow,56003\n1,TRUE,FALSE,TRUE,None,73664\n0.71,TRUE,FALSE,TRUE,Scikit-learn,434\n9.3,TRUE,TRUE,FALSE,Keras,52109\n1.7,TRUE,FALSE,FALSE,PyTorch,10284\n20.5,TRUE,FALSE,FALSE,Keras,43906\n0.75,TRUE,FALSE,FALSE,None,67971\n0.98,TRUE,FALSE,TRUE,None,58465\n0.8,FALSE,TRUE,FALSE,None,64488\n1.3,TRUE,FALSE,FALSE,None,7709\n0.36,TRUE,FALSE,FALSE,Keras,1957\n1.2,TRUE,FALSE,TRUE,Scikit-learn,4131\n8.6,TRUE,FALSE,FALSE,Scikit-learn,26022\n18.4,TRUE,FALSE,TRUE,None,29926\n2.7,FALSE,FALSE,TRUE,None,62593\n24.3,TRUE,TRUE,TRUE,None,109543\n0.94,TRUE,FALSE,TRUE,None,107644\n1.4,FALSE,TRUE, ...

# %%
import csv

# %%
dir(csv)
# Out:
# ['Dialect',
#  'DictReader',
#  'DictWriter',
#  'Error',
#  'QUOTE_ALL',
#  'QUOTE_MINIMAL',
#  'QUOTE_NONE',
#  'QUOTE_NONNUMERIC',
#  'Sniffer',
#  'StringIO',
#  '_Dialect',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '__version__',
#  'excel',
#  'excel_tab',
#  'field_size_limit',
#  'get_dialect',
#  'list_dialects',
#  're',
#  'reader',
#  'register_dialect',
#  'unix_dialect',
#  'unregister_dialect',
#  'writer']

# %%
with open(file_name) as f:
    reader = csv.reader(f, delimiter = ",")
    print(reader)
# Out:
# <_csv.reader object at 0x000001F446AD36A0>

# %%
with open(file_name) as f:
    reader = csv.reader(f, delimiter = ",")
    data = list(reader)

# %%
type(data)
# Out:
# list

# %%
data
# Out:
# [['experience_coding',
#   'python_user',
#   'r_user',
#   'sql_user',
#   'most_used',
#   'compensation'],
#  ['6.1', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '124267'],
#  ['12.3', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '236889'],
#  ['2.2', 'TRUE', 'FALSE', 'FALSE', 'None', '74321'],
#  ['2.7', 'FALSE', 'FALSE', 'TRUE', 'None', '62593'],
#  ['1.2', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '36288'],
#  ['1', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '61302'],
#  ['1.8', 'FALSE', 'FALSE', 'FALSE', 'None', '68984'],
#  ['6.1', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '18858'],
#  ['4.5', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '55418'],
#  ['1.1', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '614'],
#  ['2.7', 'TRUE', 'TRUE', 'TRUE', 'None', '70564'],
#  ['0.93', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '55525'],
#  ['0.32', 'TRUE', 'FALSE', 'FALSE', 'None', '61005'],
#  ['9.9', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '2846'],
#  ['0.78', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '21'],
#  ['13.5', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '14699'],
#  ['26.5', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '2110'],
#  ['1.5', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '620'],
#  ['3.4', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '73527'],
#  ['0.6', 'FALSE', 'FALSE', 'FALSE', 'None', '6992'],
#  ['0.95', 'TRUE', 'FALSE', 'FALSE', 'None', '22311'],
#  ['4.6', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '1377'],
#  ['2.8', 'FALSE', 'TRUE', 'FALSE', 'None', '69174'],
#  ['28.2', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '117636'],
#  ['1.4', 'TRUE', 'TRUE', 'TRUE', 'TensorFlow', '65937'],
#  ['4.8', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '27856'],
#  ['0.37', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '903'],
#  ['4.5', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '50501'],
#  ['4.4', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '482'],
#  ['0.69', 'TRUE', 'FALSE', 'FALSE', 'None', '70407'],
#  ['1.5', 'TRUE', 'FALSE', 'FALSE', 'None', '8690'],
#  ['9.6', 'TRUE', 'TRUE', 'TRUE', 'None', '114648'],
#  ['0.31', 'FALSE', 'TRUE', 'FALSE', 'None', '73454'],
#  ['3.5', 'TRUE', 'FALSE', 'FALSE', 'None', '8075'],
#  ['1', 'TRUE', 'FALSE', 'FALSE', 'None', '59151'],
#  ['0.2', 'TRUE', 'TRUE', 'TRUE', 'None', '70112'],
#  ['0.39', 'TRUE', 'FALSE', 'TRUE', 'None', '70183'],
#  ['5', 'TRUE', 'FALSE', 'FALSE', 'None', '64502'],
#  ['4', 'TRUE', 'FALSE', 'TRUE', 'None', '2521'],
#  ['0.47', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '63616'],
#  ['8.1', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '59849'],
#  ['1.8', 'TRUE', 'FALSE', 'FALSE', 'None', '31516'],
#  ['17.1', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '18582'],
#  ['1.4', 'TRUE', 'FALSE', 'FALSE', 'Keras', '4187'],
#  ['1.3', 'TRUE', 'FALSE', 'FALSE', 'None', '64405'],
#  ['3.1', 'TRUE', 'FALSE', 'FALSE', 'Keras', '114807'],
#  ['0.26', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '632'],
#  ['2.1', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '61157'],
#  ['4.4', 'TRUE', 'FALSE', 'TRUE', 'Keras', '1194'],
#  ['5.2', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '28955'],
#  ['0.7', 'TRUE', 'TRUE', 'TRUE', 'TensorFlow', '56553'],
#  ['0.69', 'FALSE', 'FALSE', 'FALSE', 'None', '75177'],
#  ['1.3', 'FALSE', 'TRUE', 'TRUE', 'None', '28009'],
#  ['1.5', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '67074'],
#  ['2.2', 'FALSE', 'FALSE', 'TRUE', 'None', '50059'],
#  ['6.3', 'FALSE', 'FALSE', 'FALSE', 'TensorFlow', '7624'],
#  ['2.9', 'TRUE', 'FALSE', 'FALSE', 'None', '74321'],
#  ['1.2', 'TRUE', 'TRUE', 'FALSE', 'None', '671'],
#  ['1.5', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '837'],
#  ['1.8', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '2011'],
#  ['0.91', 'FALSE', 'FALSE', 'FALSE', 'Scikit-learn', '62937'],
#  ['4.5', 'TRUE', 'FALSE', 'FALSE', 'None', '685'],
#  ['1.6', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '41615'],
#  ['0.27', 'TRUE', 'FALSE', 'FALSE', 'None', '52572'],
#  ['2.6', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '51856'],
#  ['1.7', 'TRUE', 'FALSE', 'FALSE', 'Keras', '411'],
#  ['0.74', 'TRUE', 'FALSE', 'FALSE', 'None', '152'],
#  ['2.7', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '8181'],
#  ['0.99', 'TRUE', 'TRUE', 'FALSE', 'Keras', '2708'],
#  ['24.8', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '55041'],
#  ['0.32', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '68412'],
#  ['3.5', 'FALSE', 'FALSE', 'TRUE', 'TensorFlow', '6141'],
#  ['5.7', 'FALSE', 'FALSE', 'TRUE', 'None', '3979'],
#  ['22', 'TRUE', 'FALSE', 'FALSE', 'Keras', '3760'],
#  ['9.9', 'TRUE', 'FALSE', 'FALSE', 'Keras', '57465'],
#  ['3.9', 'TRUE', 'FALSE', 'FALSE', 'Keras', '3864'],
#  ['20.5', 'TRUE', 'FALSE', 'FALSE', 'None', '488487'],
#  ['0.81', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '24393'],
#  ['9.8', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '68624'],
#  ['1.5', 'TRUE', 'FALSE', 'TRUE', 'None', '70796'],
#  ['12.3', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '236889'],
#  ['6.6', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '57861'],
#  ['2.1', 'TRUE', 'FALSE', 'FALSE', 'None', '21055'],
#  ['2.5', 'TRUE', 'FALSE', 'FALSE', 'Keras', '59167'],
#  ['0', 'FALSE', 'FALSE', 'FALSE', 'None', '55882'],
#  ['1.7', 'FALSE', 'FALSE', 'FALSE', 'None', '73802'],
#  ['5.3', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '21206'],
#  ['1.4', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '79803'],
#  ['1.5', 'TRUE', 'FALSE', 'TRUE', 'None', '73043'],
#  ['28.2', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '268191'],
#  ['0.97', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '14298'],
#  ['1.1', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '68805'],
#  ['7', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '56003'],
#  ['1', 'TRUE', 'FALSE', 'TRUE', 'None', '73664'],
#  ['0.71', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '434'],
#  ['9.3', 'TRUE', 'TRUE', 'FALSE', 'Keras', '52109'],
#  ['1.7', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '10284'],
#  ['20.5', 'TRUE', 'FALSE', 'FALSE', 'Keras', '43906'],
#  ['0.75', 'TRUE', 'FALSE', 'FALSE', 'None', '67971'],
#  ['0.98', 'TRUE', 'FALSE', 'TRUE', 'None', '58465'],
#  ['0.8', 'FALSE', 'TRUE', 'FALSE', 'None', '64488'],
#  ['1.3', 'TRUE', 'FALSE', 'FALSE', 'None', '7709'],
#  ['0.36', 'TRUE', 'FALSE', 'FALSE', 'Keras', '1957'],
#  ['1.2', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '4131'],
#  ['8.6', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '26022'],
#  ['18.4', 'TRUE', 'FALSE', 'TRUE', 'None', '29926'],
#  ['2.7', 'FALSE', 'FALSE', 'TRUE', 'None', '62593'],
#  ['24.3', 'TRUE', 'TRUE', 'TRUE', 'None', '109543'],
#  ['0.94', 'TRUE', 'FALSE', 'TRUE', 'None', '107644'],
#  ['1.4', 'FALSE', 'TRUE', 'TRUE', 'None', '1047'],
#  ['3.3', 'TRUE', 'FALSE', 'FALSE', 'None', '59909'],
#  ['0.93', 'TRUE', 'FALSE', 'FALSE', 'None', '68344'],
#  ['2.3', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '54427'],
#  ['0.59', 'FALSE', 'FALSE', 'FALSE', 'None', '70930'],
#  ['1.2', 'TRUE', 'FALSE', 'FALSE', 'None', '50835'],
#  ['8.5', 'TRUE', 'TRUE', 'TRUE', 'Keras', '14151'],
#  ['3.3', 'FALSE', 'TRUE', 'FALSE', 'None', '11681'],
#  ['21.1', 'TRUE', 'FALSE', 'TRUE', 'None', '71808'],
#  ['1.2', 'FALSE', 'FALSE', 'FALSE', 'None', '70991'],
#  ['12.2', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '31626'],
#  ['3.8', 'FALSE', 'FALSE', 'FALSE', 'TensorFlow', '52416'],
#  ['4.3', 'TRUE', 'FALSE', 'FALSE', 'Keras', '288146'],
#  ['13.1', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '65143'],
#  ['24.3', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '34866'],
#  ['1.6', 'TRUE', 'TRUE', 'FALSE', 'Keras', '186'],
#  ['2.9', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '60065'],
#  ['9.4', 'TRUE', 'FALSE', 'FALSE', 'None', '40336'],
#  ['7.7', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '115654'],
#  ['0.3', 'TRUE', 'FALSE', 'TRUE', 'None', '431'],
#  ['9', 'TRUE', 'TRUE', 'FALSE', 'TensorFlow', '59814'],
#  ['4.2', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '45413'],
#  ['1.9', 'FALSE', 'FALSE', 'FALSE', 'None', '4196'],
#  ['8.3', 'TRUE', 'FALSE', 'FALSE', 'None', '55751'],
#  ['0.21', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '61912'],
#  ['18.8', 'TRUE', 'FALSE', 'FALSE', 'None', '49478'],
#  ['9.3', 'FALSE', 'FALSE', 'TRUE', 'Scikit-learn', '29139'],
#  ['1.8', 'TRUE', 'FALSE', 'FALSE', 'Keras', '67272'],
#  ['2.8', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '70264'],
#  ['2.4', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '264'],
#  ['15.3', 'TRUE', 'TRUE', 'TRUE', 'Keras', '14853'],
#  ['3.9', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '55482'],
#  ['0.3', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '26'],
#  ['0.8', 'FALSE', 'FALSE', 'TRUE', 'None', '250'],
#  ['0.79', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '66025'],
#  ['11.1', 'TRUE', 'FALSE', 'TRUE', 'None', '55906'],
#  ['0.24', 'TRUE', 'FALSE', 'FALSE', 'None', '63754'],
#  ['19.7', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '86855'],
#  ['8.5', 'TRUE', 'FALSE', 'FALSE', 'Keras', '63242'],
#  ['0.26', 'TRUE', 'FALSE', 'TRUE', 'None', '70448'],
#  ['0.75', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '68964'],
#  ['24.4', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '111583'],
#  ['6.8', 'TRUE', 'FALSE', 'FALSE', 'Keras', '52350'],
#  ['4.4', 'TRUE', 'FALSE', 'TRUE', 'None', '58574'],
#  ['3.2', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '330'],
#  ['0.84', 'TRUE', 'FALSE', 'TRUE', 'None', '64478'],
#  ['16', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '94273'],
#  ['4.9', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '62142'],
#  ['8.3', 'TRUE', 'FALSE', 'TRUE', 'Keras', '5857'],
#  ['6.6', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '194518'],
#  ['4', 'TRUE', 'FALSE', 'FALSE', 'None', '60873'],
#  ['23.9', 'TRUE', 'FALSE', 'TRUE', 'None', '55584'],
#  ['27', 'FALSE', 'FALSE', 'FALSE', 'PyTorch', '949'],
#  ['0.91', 'TRUE', 'FALSE', 'FALSE', 'None', '27748'],
#  ['2.2', 'TRUE', 'FALSE', 'TRUE', 'None', '239'],
#  ['13.9', 'FALSE', 'FALSE', 'TRUE', 'None', '120047'],
#  ['3.4', 'TRUE', 'FALSE', 'FALSE', 'None', '332'],
#  ['1.4', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '51428'],
#  ['6.6', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '256063'],
#  ['2.6', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '50783'],
#  ['8.5', 'TRUE', 'TRUE', 'TRUE', 'Keras', '109423'],
#  ['28.2', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '85525'],
#  ['2.7', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '226'],
#  ['8.6', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '13056'],
#  ['2.9', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '8015'],
#  ['2.6', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '450'],
#  ['7.5', 'FALSE', 'FALSE', 'TRUE', 'None', '55219'],
#  ['1.3', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '348'],
#  ['16.2', 'TRUE', 'FALSE', 'FALSE', 'None', '53685'],
#  ['2.7', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '59456'],
#  ['1.8', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '62821'],
#  ['7.1', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '13478'],
#  ['1.9', 'TRUE', 'FALSE', 'FALSE', 'None', '59666'],
#  ['0.41', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '57673'],
#  ['2.3', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '29472'],
#  ['11.8', 'TRUE', 'TRUE', 'TRUE', 'PyTorch', '276659'],
#  ['4', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '5119'],
#  ['5.4', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '27631'],
#  ['3.8', 'FALSE', 'FALSE', 'FALSE', 'None', '282'],
#  ['5.7', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '34238'],
#  ['0', 'FALSE', 'FALSE', 'FALSE', 'None', '106203'],
#  ['0', 'FALSE', 'FALSE', 'FALSE', 'None', '74289'],
#  ['21.4', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '226171'],
#  ['2.5', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '74445'],
#  ['7.6', 'TRUE', 'TRUE', 'FALSE', 'TensorFlow', '67863'],
#  ['22.8', 'FALSE', 'FALSE', 'TRUE', 'None', '65871'],
#  ['1.7', 'TRUE', 'FALSE', 'TRUE', 'None', '67736'],
#  ['2.6', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '785'],
#  ['2.1', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '28073'],
#  ['1.9', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '20390'],
#  ['3.2', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '4791'],
#  ['7.2', 'FALSE', 'FALSE', 'TRUE', 'None', '16059'],
#  ['14.1', 'TRUE', 'FALSE', 'FALSE', 'Keras', '62115'],
#  ['1.9', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '73319'],
#  ['0.93', 'FALSE', 'FALSE', 'FALSE', 'None', '44491'],
#  ['9.6', 'TRUE', 'FALSE', 'FALSE', 'None', '74588'],
#  ['1.4', 'TRUE', 'TRUE', 'FALSE', 'None', '74799'],
#  ['0.45', 'TRUE', 'FALSE', 'FALSE', 'None', '57207'],
#  ['3.2', 'TRUE', 'FALSE', 'FALSE', 'Keras', '14370'],
#  ['1', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '57816'],
#  ['4.4', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '62513'],
#  ['17.7', 'TRUE', 'FALSE', 'FALSE', 'Keras', '61763'],
#  ['8.7', 'FALSE', 'TRUE', 'FALSE', 'None', '50427'],
#  ['28.9', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '1129'],
#  ['0.58', 'TRUE', 'FALSE', 'FALSE', 'None', '59687'],
#  ['1.3', 'FALSE', 'FALSE', 'FALSE', 'None', '67959'],
#  ['11.3', 'FALSE', 'TRUE', 'FALSE', 'None', '62849'],
#  ['3.1', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '1337'],
#  ['2.5', 'TRUE', 'FALSE', 'FALSE', 'Keras', '72317'],
#  ['5.9', 'TRUE', 'FALSE', 'TRUE', 'Keras', '31044'],
#  ['2.7', 'TRUE', 'FALSE', 'TRUE', 'Keras', '66163'],
#  ['1.1', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '11165'],
#  ['16.5', 'FALSE', 'TRUE', 'FALSE', 'Scikit-learn', '68871'],
#  ['7.5', 'TRUE', 'FALSE', 'TRUE', 'Keras', '22332'],
#  ['25.2', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '6196'],
#  ['0.88', 'TRUE', 'FALSE', 'FALSE', 'None', '388'],
#  ['0.6', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '12925'],
#  ['4.1', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '3092'],
#  ['8.2', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '8880'],
#  ['5.7', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '65433'],
#  ['0.49', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '13423'],
#  ['2.6', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '4704'],
#  ['2.2', 'TRUE', 'FALSE', 'FALSE', 'Keras', '740'],
#  ['9.2', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '64640'],
#  ['4', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '63'],
#  ['28.6', 'TRUE', 'FALSE', 'TRUE', 'None', '79687'],
#  ['0.6', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '63155'],
#  ['2.9', 'TRUE', 'FALSE', 'TRUE', 'None', '54825'],
#  ['29.7', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '61352'],
#  ['1.7', 'TRUE', 'FALSE', 'FALSE', 'None', '64184'],
#  ['24', 'TRUE', 'FALSE', 'TRUE', 'Keras', '130578'],
#  ['1.7', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '57821'],
#  ['0.66', 'TRUE', 'TRUE', 'TRUE', 'None', '52061'],
#  ['3.2', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '2279'],
#  ['2.2', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '73945'],
#  ['0.97', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '62225'],
#  ['0.73', 'TRUE', 'FALSE', 'FALSE', 'None', '52153'],
#  ['6.1', 'TRUE', 'FALSE', 'TRUE', 'Keras', '32815'],
#  ['3.3', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '178'],
#  ['0.34', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '553'],
#  ['5.3', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '64796'],
#  ['0.93', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '51701'],
#  ['4.3', 'TRUE', 'FALSE', 'FALSE', 'None', '70917'],
#  ['2.7', 'FALSE', 'FALSE', 'FALSE', 'None', '1672'],
#  ['1.4', 'FALSE', 'FALSE', 'TRUE', 'None', '561'],
#  ['13.7', 'FALSE', 'FALSE', 'TRUE', 'None', '64214'],
#  ['3.6', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '32809'],
#  ['1.5', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '61430'],
#  ['0.42', 'FALSE', 'FALSE', 'TRUE', 'TensorFlow', '2852'],
#  ['29.1', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '124867'],
#  ['23.9', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '55354'],
#  ['0', 'FALSE', 'FALSE', 'FALSE', 'None', '341'],
#  ['2.2', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '3241'],
#  ['10', 'TRUE', 'FALSE', 'TRUE', 'Keras', '114569'],
#  ['0.93', 'TRUE', 'TRUE', 'TRUE', 'None', '5068'],
#  ['9.2', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '53406'],
#  ['15.1', 'TRUE', 'TRUE', 'TRUE', 'PyTorch', '67586'],
#  ['14.6', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '368'],
#  ['1.8', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '66719'],
#  ['9.6', 'TRUE', 'TRUE', 'TRUE', 'None', '61028'],
#  ['3.2', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '380'],
#  ['2.4', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '104'],
#  ['1.9', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '57262'],
#  ['0.98', 'FALSE', 'FALSE', 'FALSE', 'None', '72756'],
#  ['16.7', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '117471'],
#  ['6.6', 'TRUE', 'FALSE', 'TRUE', 'None', '948'],
#  ['1.6', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '3458'],
#  ['3.7', 'TRUE', 'TRUE', 'FALSE', 'TensorFlow', '62798'],
#  ['2.7', 'FALSE', 'FALSE', 'FALSE', 'None', '59402'],
#  ['0.53', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '54542'],
#  ['0.77', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '69584'],
#  ['0.76', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '2762'],
#  ['0.73', 'TRUE', 'FALSE', 'FALSE', 'None', '51493'],
#  ['0.34', 'TRUE', 'FALSE', 'TRUE', 'Keras', '397'],
#  ['24.7', 'TRUE', 'FALSE', 'FALSE', 'Keras', '268277'],
#  ['1.4', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '13504'],
#  ['11.7', 'FALSE', 'FALSE', 'FALSE', 'Scikit-learn', '236436'],
#  ['3.9', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '69429'],
#  ['15', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '183614'],
#  ['4.7', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '62053'],
#  ['0.41', 'FALSE', 'FALSE', 'FALSE', 'None', '20029'],
#  ['0', 'FALSE', 'FALSE', 'FALSE', 'None', '64'],
#  ['2.3', 'TRUE', 'FALSE', 'TRUE', 'None', '55068'],
#  ['2.2', 'TRUE', 'TRUE', 'TRUE', 'Keras', '2756'],
#  ['1', 'TRUE', 'FALSE', 'FALSE', 'Keras', '68080'],
#  ['1.9', 'TRUE', 'FALSE', 'TRUE', 'None', '51110'],
#  ['0.44', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '6055'],
#  ['0', 'FALSE', 'FALSE', 'FALSE', 'None', '566'],
#  ['2.9', 'TRUE', 'FALSE', 'TRUE', 'None', '57222'],
#  ['29', 'TRUE', 'TRUE', 'FALSE', 'TensorFlow', '30662'],
#  ['12', 'TRUE', 'FALSE', 'FALSE', 'None', '57836'],
#  ['3.2', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '8651'],
#  ['3.2', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '50354'],
#  ['1.5', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '67366'],
#  ['1.8', 'FALSE', 'FALSE', 'TRUE', 'None', '3181'],
#  ['0.75', 'TRUE', 'FALSE', 'FALSE', 'Keras', '50292'],
#  ['20.1', 'FALSE', 'TRUE', 'FALSE', 'None', '26892'],
#  ['19.2', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '70349'],
#  ['8.7', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '11195'],
#  ['0', 'FALSE', 'FALSE', 'FALSE', 'None', '51080'],
#  ['4.9', 'FALSE', 'FALSE', 'FALSE', 'None', '9638'],
#  ['21.5', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '441'],
#  ['1.6', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '15222'],
#  ['0.37', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '748'],
#  ['17.4', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '65215'],
#  ['4.6', 'TRUE', 'FALSE', 'FALSE', 'Keras', '25696'],
#  ['5.2', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '54268'],
#  ['9.5', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '62430'],
#  ['1.2', 'TRUE', 'TRUE', 'TRUE', 'None', '57599'],
#  ['2', 'TRUE', 'FALSE', 'FALSE', 'None', '61169'],
#  ['2.5', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '72278'],
#  ['1.6', 'TRUE', 'FALSE', 'FALSE', 'None', '56628'],
#  ['1.7', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '58598'],
#  ['18.3', 'TRUE', 'FALSE', 'TRUE', 'None', '104890'],
#  ['6.1', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '70778'],
#  ['0.48', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '1920'],
#  ['2.9', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '64650'],
#  ['2.9', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '61957'],
#  ['1.6', 'TRUE', 'TRUE', 'FALSE', 'PyTorch', '280'],
#  ['2.4', 'TRUE', 'FALSE', 'TRUE', 'None', '53807'],
#  ['5.1', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '4278'],
#  ['0.43', 'TRUE', 'FALSE', 'TRUE', 'None', '62815'],
#  ['0.81', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '55603'],
#  ['10.5', 'TRUE', 'FALSE', 'FALSE', 'None', '45474'],
#  ['0.22', 'TRUE', 'TRUE', 'TRUE', 'None', '59812'],
#  ['1.8', 'TRUE', 'FALSE', 'TRUE', 'Keras', '10176'],
#  ['9.1', 'TRUE', 'TRUE', 'TRUE', 'TensorFlow', '3449'],
#  ['4.3', 'TRUE', 'FALSE', 'FALSE', 'Keras', '330'],
#  ['7.7', 'TRUE', 'FALSE', 'FALSE', 'None', '50545'],
#  ['8.1', 'TRUE', 'TRUE', 'FALSE', 'TensorFlow', '303'],
#  ['4.1', 'FALSE', 'TRUE', 'FALSE', 'Keras', '64186'],
#  ['1.7', 'TRUE', 'TRUE', 'FALSE', 'None', '1426'],
#  ['1.4', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '750'],
#  ['22.9', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '74868'],
#  ['18.5', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '26708'],
#  ['2.2', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '64493'],
#  ['0.42', 'TRUE', 'TRUE', 'TRUE', 'TensorFlow', '79'],
#  ['24.1', 'FALSE', 'FALSE', 'TRUE', 'None', '72549'],
#  ['5.8', 'TRUE', 'FALSE', 'TRUE', 'Keras', '28039'],
#  ['0.93', 'FALSE', 'FALSE', 'FALSE', 'None', '59061'],
#  ['4.8', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '69723'],
#  ['2.6', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '69452'],
#  ['3.1', 'TRUE', 'FALSE', 'TRUE', 'Keras', '22665'],
#  ['4', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '214'],
#  ['9.9', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '2355'],
#  ['7.2', 'TRUE', 'TRUE', 'TRUE', 'Keras', '162385'],
#  ['5.4', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '5871'],
#  ['8.3', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '853'],
#  ['2.9', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '3929'],
#  ['0.54', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '58863'],
#  ['0.55', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '8009'],
#  ['0', 'FALSE', 'FALSE', 'FALSE', 'None', '68498'],
#  ['0.36', 'FALSE', 'FALSE', 'FALSE', 'None', '1948'],
#  ['1', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '69648'],
#  ['6.3', 'TRUE', 'TRUE', 'TRUE', 'None', '74877'],
#  ['2.3', 'TRUE', 'FALSE', 'FALSE', 'Keras', '65598'],
#  ['0.68', 'FALSE', 'FALSE', 'TRUE', 'None', '54524'],
#  ['1.6', 'TRUE', 'FALSE', 'TRUE', 'Keras', '66262'],
#  ['0', 'FALSE', 'FALSE', 'FALSE', 'None', '4427'],
#  ['0.58', 'FALSE', 'FALSE', 'FALSE', 'None', '31841'],
#  ['0.85', 'TRUE', 'FALSE', 'FALSE', 'None', '54481'],
#  ['2.9', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '57717'],
#  ['3.4', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '25721'],
#  ['25.4', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '64217'],
#  ['8.8', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '2203'],
#  ['5.5', 'TRUE', 'TRUE', 'FALSE', 'TensorFlow', '62142'],
#  ['4.2', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '12573'],
#  ['14.2', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '13212'],
#  ['2.8', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '71758'],
#  ['5.2', 'FALSE', 'FALSE', 'FALSE', 'None', '4306'],
#  ['1.6', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '835'],
#  ['1.3', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '601'],
#  ['4.9', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '61209'],
#  ['0', 'FALSE', 'FALSE', 'FALSE', 'None', '365'],
#  ['0.4', 'TRUE', 'FALSE', 'FALSE', 'None', '702'],
#  ['0.93', 'TRUE', 'TRUE', 'TRUE', 'None', '67436'],
#  ['2.4', 'TRUE', 'FALSE', 'FALSE', 'Keras', '73296'],
#  ['10.7', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '63999'],
#  ['2.1', 'TRUE', 'FALSE', 'TRUE', 'Keras', '58760'],
#  ['2.4', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '70522'],
#  ['14.8', 'FALSE', 'TRUE', 'TRUE', 'None', '78489'],
#  ['3.5', 'TRUE', 'FALSE', 'TRUE', 'None', '59768'],
#  ['21.8', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '53040'],
#  ['4.3', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '1894'],
#  ['12.9', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '124879'],
#  ['2.5', 'TRUE', 'TRUE', 'TRUE', 'PyTorch', '98886'],
#  ['0.96', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '797'],
#  ['1.9', 'FALSE', 'TRUE', 'FALSE', 'None', '67900'],
#  ['21.7', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '169111'],
#  ['0.27', 'TRUE', 'TRUE', 'FALSE', 'None', '69490'],
#  ['16.8', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '18059'],
#  ['1.8', 'TRUE', 'FALSE', 'FALSE', 'None', '61535'],
#  ['27.8', 'TRUE', 'TRUE', 'FALSE', 'TensorFlow', '279'],
#  ['1', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '4951'],
#  ['8.2', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '675'],
#  ['2.5', 'TRUE', 'TRUE', 'TRUE', 'None', '66662'],
#  ['2.2', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '5345'],
#  ['1.3', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '15827'],
#  ['7.1', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '268'],
#  ['10', 'FALSE', 'FALSE', 'FALSE', 'None', '63128'],
#  ['0.95', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '51943'],
#  ['6.3', 'FALSE', 'TRUE', 'FALSE', 'None', '7606'],
#  ['1.8', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '55361'],
#  ['0.29', 'TRUE', 'FALSE', 'FALSE', 'None', '2284'],
#  ['4.9', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '13232'],
#  ['0.73', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '70'],
#  ['3.7', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '51162'],
#  ['5.1', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '24490'],
#  ['1.9', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '58763'],
#  ['0.21', 'TRUE', 'TRUE', 'TRUE', 'None', '57140'],
#  ['0.36', 'TRUE', 'FALSE', 'FALSE', 'None', '53937'],
#  ['9.9', 'TRUE', 'TRUE', 'TRUE', 'Keras', '10720'],
#  ['1.3', 'TRUE', 'FALSE', 'TRUE', 'None', '55375'],
#  ['13.1', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '9526'],
#  ['0.33', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '74828'],
#  ['2.8', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '584'],
#  ['1.4', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '42097'],
#  ['2.7', 'TRUE', 'FALSE', 'FALSE', 'Keras', '62804'],
#  ['1.7', 'TRUE', 'FALSE', 'FALSE', 'None', '4296'],
#  ['1.1', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '60567'],
#  ['5.6', 'TRUE', 'TRUE', 'TRUE', 'None', '102894'],
#  ['0.7', 'FALSE', 'TRUE', 'TRUE', 'None', '29160'],
#  ['0.73', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '1491'],
#  ['2.8', 'FALSE', 'FALSE', 'FALSE', 'Keras', '614'],
#  ['9.4', 'TRUE', 'FALSE', 'TRUE', 'Keras', '37053'],
#  ['2.4', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '181179'],
#  ['3', 'TRUE', 'FALSE', 'FALSE', 'None', '55377'],
#  ['8.4', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '6947'],
#  ['3.4', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '21934'],
#  ['0.64', 'TRUE', 'FALSE', 'TRUE', 'None', '65'],
#  ['1.4', 'TRUE', 'FALSE', 'TRUE', 'None', '57123'],
#  ['2', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '1943'],
#  ['2.2', 'TRUE', 'FALSE', 'FALSE', 'Keras', '67032'],
#  ['3.8', 'TRUE', 'FALSE', 'TRUE', 'None', '63358'],
#  ['3.2', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '28'],
#  ['0.95', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '3519'],
#  ['2.6', 'FALSE', 'TRUE', 'FALSE', 'None', '356'],
#  ['14.2', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '158644'],
#  ['0.64', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '7226'],
#  ['16.7', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '12915'],
#  ['0.83', 'TRUE', 'TRUE', 'TRUE', 'PyTorch', '73268'],
#  ['2.9', 'TRUE', 'FALSE', 'TRUE', 'None', '57188'],
#  ['0.49', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '102'],
#  ['19.6', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '3032'],
#  ['1.1', 'TRUE', 'FALSE', 'FALSE', 'None', '123071'],
#  ['0.57', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '250388'],
#  ['2.1', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '70915'],
#  ['2.4', 'TRUE', 'FALSE', 'TRUE', 'None', '201'],
#  ['16.9', 'TRUE', 'TRUE', 'TRUE', 'None', '246015'],
#  ['2.9', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '11378'],
#  ['9', 'FALSE', 'TRUE', 'FALSE', 'Scikit-learn', '303'],
#  ['3.5', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '50638'],
#  ['0.91', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '20749'],
#  ['6.4', 'TRUE', 'FALSE', 'FALSE', 'None', '521'],
#  ['7', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '17911'],
#  ['2', 'FALSE', 'FALSE', 'TRUE', 'None', '70675'],
#  ['0.56', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '70432'],
#  ['0.67', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '78601'],
#  ['0.69', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '1282'],
#  ['9.1', 'TRUE', 'TRUE', 'FALSE', 'TensorFlow', '99399'],
#  ['1.8', 'FALSE', 'FALSE', 'FALSE', 'PyTorch', '1503'],
#  ['1.2', 'TRUE', 'FALSE', 'TRUE', 'Keras', '53171'],
#  ['9.6', 'FALSE', 'FALSE', 'FALSE', 'None', '57165'],
#  ['16.6', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '25114'],
#  ['1.1', 'TRUE', 'FALSE', 'FALSE', 'Keras', '26960'],
#  ['9', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '60063'],
#  ['0', 'FALSE', 'FALSE', 'FALSE', 'None', '610'],
#  ['4.5', 'TRUE', 'FALSE', 'FALSE', 'Keras', '69739'],
#  ['0', 'FALSE', 'FALSE', 'FALSE', 'None', '3134'],
#  ['6.8', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '66837'],
#  ['0.54', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '55165'],
#  ['3.6', 'FALSE', 'FALSE', 'FALSE', 'Keras', '988'],
#  ['14.6', 'FALSE', 'FALSE', 'FALSE', 'None', '55580'],
#  ['17', 'TRUE', 'TRUE', 'TRUE', 'TensorFlow', '76201'],
#  ['0.67', 'TRUE', 'FALSE', 'FALSE', 'Keras', '64966'],
#  ['0.92', 'FALSE', 'TRUE', 'FALSE', 'None', '6350'],
#  ['0.7', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '74951'],
#  ['6', 'TRUE', 'TRUE', 'FALSE', 'Keras', '51312'],
#  ['0.36', 'FALSE', 'TRUE', 'FALSE', 'None', '666'],
#  ['5.1', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '293904'],
#  ['4.8', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '106322'],
#  ['0.43', 'FALSE', 'FALSE', 'FALSE', 'None', '60814'],
#  ['0.39', 'TRUE', 'FALSE', 'FALSE', 'None', '70572'],
#  ['0.88', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '68837'],
#  ['0.55', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '62093'],
#  ['0.62', 'TRUE', 'FALSE', 'TRUE', 'None', '54114'],
#  ['2.8', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '979'],
#  ['0.96', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '2235'],
#  ['1.4', 'TRUE', 'FALSE', 'FALSE', 'Keras', '3303'],
#  ['25.8', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '71650'],
#  ['1.5', 'TRUE', 'FALSE', 'FALSE', 'None', '5145'],
#  ['0.98', 'TRUE', 'FALSE', 'FALSE', 'None', '56213'],
#  ['3.3', 'FALSE', 'FALSE', 'FALSE', 'None', '57850'],
#  ['2.1', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '62878'],
#  ['4.6', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '53195'],
#  ['9.6', 'FALSE', 'FALSE', 'TRUE', 'TensorFlow', '2312'],
#  ['1.3', 'FALSE', 'TRUE', 'TRUE', 'None', '163016'],
#  ['0.26', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '80274'],
#  ['9.6', 'TRUE', 'TRUE', 'FALSE', 'None', '34215'],
#  ['2.3', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '68870'],
#  ['1.7', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '245'],
#  ['11.1', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '92681'],
#  ['3.3', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '72998'],
#  ['0.84', 'TRUE', 'FALSE', 'FALSE', 'None', '61803'],
#  ['3.7', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '269443'],
#  ['1.5', 'TRUE', 'FALSE', 'TRUE', 'None', '58537'],
#  ['1.9', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '160989'],
#  ['2.9', 'TRUE', 'FALSE', 'TRUE', 'Keras', '21386'],
#  ['25.3', 'TRUE', 'FALSE', 'FALSE', 'Keras', '262267'],
#  ['11', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '40701'],
#  ['14.5', 'FALSE', 'FALSE', 'FALSE', 'PyTorch', '14184'],
#  ['0.91', 'TRUE', 'FALSE', 'FALSE', 'Keras', '51286'],
#  ['0.31', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '27246'],
#  ['2.1', 'TRUE', 'FALSE', 'TRUE', 'None', '894'],
#  ['2.6', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '55032'],
#  ['18.2', 'FALSE', 'FALSE', 'FALSE', 'PyTorch', '293074'],
#  ['1.2', 'TRUE', 'TRUE', 'FALSE', 'None', '62407'],
#  ['1.3', 'FALSE', 'FALSE', 'TRUE', 'Scikit-learn', '57986'],
#  ['27.7', 'TRUE', 'FALSE', 'TRUE', 'Keras', '197702'],
#  ['0.35', 'TRUE', 'FALSE', 'FALSE', 'None', '58495'],
#  ['2.6', 'FALSE', 'TRUE', 'TRUE', 'TensorFlow', '60397'],
#  ['0.43', 'TRUE', 'FALSE', 'TRUE', 'None', '51395'],
#  ['1.8', 'TRUE', 'FALSE', 'FALSE', 'None', '87556'],
#  ['3.7', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '4853'],
#  ['0.92', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '4795'],
#  ['7.7', 'TRUE', 'FALSE', 'TRUE', 'Keras', '10487'],
#  ['5.9', 'TRUE', 'TRUE', 'FALSE', 'Keras', '49634'],
#  ['4.4', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '85067'],
#  ['2.1', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '60649'],
#  ['4.5', 'FALSE', 'FALSE', 'FALSE', 'None', '29055'],
#  ['0.28', 'FALSE', 'TRUE', 'FALSE', 'None', '402'],
#  ['2.6', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '12966'],
#  ['0.82', 'TRUE', 'TRUE', 'TRUE', 'None', '55051'],
#  ['4.8', 'TRUE', 'FALSE', 'FALSE', 'None', '55936'],
#  ['0.53', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '72312'],
#  ['0.44', 'FALSE', 'TRUE', 'FALSE', 'None', '55815'],
#  ['19.8', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '85996'],
#  ['15.5', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '73483'],
#  ['0.95', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '57116'],
#  ['2.2', 'TRUE', 'FALSE', 'TRUE', 'Keras', '71248'],
#  ['0.51', 'TRUE', 'FALSE', 'FALSE', 'None', '2620'],
#  ['2.9', 'FALSE', 'FALSE', 'FALSE', 'None', '72617'],
#  ['2.7', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '5838'],
#  ['2.7', 'TRUE', 'FALSE', 'TRUE', 'None', '51572'],
#  ['1.9', 'TRUE', 'TRUE', 'FALSE', 'None', '70132'],
#  ['2.7', 'FALSE', 'TRUE', 'FALSE', 'None', '53668'],
#  ['0.33', 'FALSE', 'FALSE', 'FALSE', 'None', '59530'],
#  ['0.62', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '253920'],
#  ['1.9', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '549'],
#  ['0.32', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '755'],
#  ['3.3', 'TRUE', 'FALSE', 'FALSE', 'Keras', '38078'],
#  ['0.54', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '525'],
#  ['0.73', 'TRUE', 'FALSE', 'FALSE', 'None', '47261'],
#  ['0', 'FALSE', 'FALSE', 'FALSE', 'None', '24554'],
#  ['5.5', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '22085'],
#  ['1.2', 'TRUE', 'FALSE', 'FALSE', 'Keras', '17937'],
#  ['3.9', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '72360'],
#  ['15.1', 'TRUE', 'FALSE', 'TRUE', 'Keras', '18607'],
#  ['2.9', 'TRUE', 'FALSE', 'FALSE', 'Keras', '57700'],
#  ['0.83', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '1524'],
#  ['7.6', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '18712'],
#  ['1.4', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '53965'],
#  ['3.1', 'TRUE', 'FALSE', 'FALSE', 'None', '73004'],
#  ['1.5', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '50276'],
#  ['4.2', 'TRUE', 'FALSE', 'FALSE', 'None', '54145'],
#  ['0.34', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '322'],
#  ['0.82', 'TRUE', 'FALSE', 'TRUE', 'None', '574'],
#  ['16.5', 'FALSE', 'FALSE', 'FALSE', 'None', '12801'],
#  ['2.4', 'TRUE', 'FALSE', 'TRUE', 'Keras', '71045'],
#  ['0.66', 'TRUE', 'FALSE', 'FALSE', 'None', '69120'],
#  ['8', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '82527'],
#  ['6.6', 'TRUE', 'TRUE', 'TRUE', 'PyTorch', '60748'],
#  ['1', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '490'],
#  ['4', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '72533'],
#  ['5.5', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '4320'],
#  ['7.8', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '57114'],
#  ['2.2', 'TRUE', 'FALSE', 'FALSE', 'None', '250'],
#  ['1.3', 'TRUE', 'FALSE', 'FALSE', 'None', '54947'],
#  ['1.9', 'TRUE', 'TRUE', 'TRUE', 'None', '56963'],
#  ['1.3', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '8316'],
#  ['2.2', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '63330'],
#  ['0.94', 'FALSE', 'FALSE', 'FALSE', 'None', '67994'],
#  ['27.8', 'FALSE', 'TRUE', 'TRUE', 'None', '61608'],
#  ['1.6', 'TRUE', 'FALSE', 'TRUE', 'None', '60833'],
#  ['1.9', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '55193'],
#  ['3.9', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '1788'],
#  ['0.62', 'FALSE', 'FALSE', 'TRUE', 'Keras', '51397'],
#  ['9.5', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '80248'],
#  ['2.4', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '54401'],
#  ['3.7', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '72472'],
#  ['6.6', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '67690'],
#  ['0.94', 'FALSE', 'FALSE', 'FALSE', 'None', '52835'],
#  ['4.8', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '70275'],
#  ['2.9', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '1833'],
#  ['0.25', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '51048'],
#  ['0.56', 'FALSE', 'FALSE', 'FALSE', 'None', '12130'],
#  ['16.8', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '4441'],
#  ['3.4', 'TRUE', 'FALSE', 'TRUE', 'Keras', '660'],
#  ['3.3', 'FALSE', 'FALSE', 'FALSE', 'TensorFlow', '4356'],
#  ['0.98', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '48658'],
#  ['2.6', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '67022'],
#  ['2.7', 'TRUE', 'FALSE', 'FALSE', 'None', '55014'],
#  ['13.3', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '79549'],
#  ['17.3', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '61440'],
#  ['0.31', 'FALSE', 'FALSE', 'TRUE', 'None', '74808'],
#  ['1.7', 'TRUE', 'TRUE', 'FALSE', 'None', '69191'],
#  ['1.1', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '5414'],
#  ['2.5', 'TRUE', 'FALSE', 'FALSE', 'Keras', '8027'],
#  ['2.4', 'FALSE', 'TRUE', 'FALSE', 'None', '304'],
#  ['1.6', 'TRUE', 'FALSE', 'FALSE', 'Keras', '68620'],
#  ['2.3', 'FALSE', 'FALSE', 'FALSE', 'None', '68705'],
#  ['0.69', 'FALSE', 'FALSE', 'FALSE', 'None', '3266'],
#  ['1.9', 'FALSE', 'TRUE', 'FALSE', 'None', '56404'],
#  ['4.7', 'TRUE', 'FALSE', 'FALSE', 'Keras', '72267'],
#  ['6.9', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '15598'],
#  ['1.8', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '756'],
#  ['4.4', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '3064'],
#  ['0.44', 'TRUE', 'FALSE', 'FALSE', 'None', '53474'],
#  ['2.4', 'TRUE', 'FALSE', 'TRUE', 'None', '3446'],
#  ['0.64', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '50527'],
#  ['2.9', 'TRUE', 'TRUE', 'FALSE', 'None', '54821'],
#  ['26.6', 'TRUE', 'FALSE', 'TRUE', 'Keras', '154850'],
#  ['3.5', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '65435'],
#  ['0.5', 'TRUE', 'FALSE', 'FALSE', 'None', '73399'],
#  ['1.2', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '64946'],
#  ['1.5', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '18800'],
#  ['0.92', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '56757'],
#  ['4', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '2592'],
#  ['0.47', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '16612'],
#  ['4.7', 'TRUE', 'FALSE', 'FALSE', 'None', '19143'],
#  ['6.5', 'TRUE', 'FALSE', 'FALSE', 'Keras', '59359'],
#  ['0.5', 'FALSE', 'TRUE', 'FALSE', 'None', '120711'],
#  ['4.7', 'TRUE', 'TRUE', 'TRUE', 'PyTorch', '52082'],
#  ['0.75', 'TRUE', 'FALSE', 'TRUE', 'None', '67918'],
#  ['0.28', 'TRUE', 'TRUE', 'FALSE', 'None', '59017'],
#  ['2.8', 'FALSE', 'FALSE', 'TRUE', 'None', '864'],
#  ['2.1', 'FALSE', 'FALSE', 'TRUE', 'None', '664'],
#  ['7.3', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '19284'],
#  ['16.1', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '217677'],
#  ['0', 'FALSE', 'FALSE', 'FALSE', 'None', '475180'],
#  ['0', 'FALSE', 'FALSE', 'FALSE', 'None', '10746'],
#  ['4.8', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '56503'],
#  ['9.8', 'FALSE', 'FALSE', 'TRUE', 'Scikit-learn', '8359'],
#  ['1.7', 'TRUE', 'TRUE', 'TRUE', 'Keras', '378'],
#  ['23.9', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '70460'],
#  ['0.92', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '21123'],
#  ['0.7', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '62'],
#  ['0.68', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '11020'],
#  ['11.3', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '12529'],
#  ['23.9', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '1325993'],
#  ['3', 'TRUE', 'TRUE', 'FALSE', 'None', '64688'],
#  ['0.62', 'FALSE', 'FALSE', 'FALSE', 'Keras', '71694'],
#  ['4.5', 'FALSE', 'TRUE', 'FALSE', 'None', '62257'],
#  ['27.4', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '66467'],
#  ['0', 'FALSE', 'FALSE', 'FALSE', 'None', '57612'],
#  ['3.9', 'TRUE', 'TRUE', 'FALSE', 'TensorFlow', '17739'],
#  ['3.8', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '103218'],
#  ['2.4', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '1507'],
#  ['1.1', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '7254'],
#  ['8.5', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '54862'],
#  ['5.4', 'TRUE', 'FALSE', 'TRUE', 'Keras', '27111'],
#  ['10.8', 'TRUE', 'TRUE', 'FALSE', 'Keras', '20031'],
#  ['1.6', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '41563'],
#  ['1.7', 'TRUE', 'FALSE', 'FALSE', 'None', '67010'],
#  ['4.7', 'TRUE', 'FALSE', 'TRUE', 'Keras', '5784'],
#  ['16.8', 'FALSE', 'FALSE', 'FALSE', 'None', '72308'],
#  ['3.3', 'TRUE', 'TRUE', 'TRUE', 'None', '22030'],
#  ['3.3', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '67377'],
#  ['0.29', 'TRUE', 'FALSE', 'FALSE', 'Keras', '796'],
#  ['10.1', 'TRUE', 'FALSE', 'TRUE', 'None', '69368'],
#  ['1.1', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '72472'],
#  ['0.67', 'TRUE', 'FALSE', 'FALSE', 'None', '63048'],
#  ['0.21', 'FALSE', 'FALSE', 'TRUE', 'None', '9892'],
#  ['0.96', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '56203'],
#  ['22.9', 'TRUE', 'FALSE', 'FALSE', 'Keras', '48552'],
#  ['3.5', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '72018'],
#  ['0.56', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '13'],
#  ['0.64', 'TRUE', 'FALSE', 'FALSE', 'None', '60665'],
#  ['4.9', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '70969'],
#  ['3.7', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '37353'],
#  ['7.7', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '13483'],
#  ['2.6', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '73574'],
#  ['0.44', 'FALSE', 'FALSE', 'FALSE', 'None', '53506'],
#  ['3.9', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '26289'],
#  ['15.1', 'TRUE', 'FALSE', 'TRUE', 'None', '43464'],
#  ['4.2', 'TRUE', 'FALSE', 'TRUE', 'None', '5122'],
#  ['3.8', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '5330'],
#  ['3.7', 'TRUE', 'TRUE', 'TRUE', 'None', '8372'],
#  ['0.67', 'TRUE', 'FALSE', 'TRUE', 'None', '63035'],
#  ['10.9', 'TRUE', 'TRUE', 'FALSE', 'None', '287624'],
#  ['1.8', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '66297'],
#  ['2.7', 'TRUE', 'FALSE', 'FALSE', 'None', '74909'],
#  ['2.7', 'TRUE', 'TRUE', 'FALSE', 'None', '68897'],
#  ['1.1', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '55103'],
#  ['3.9', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '65436'],
#  ['12.2', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '83337'],
#  ['29.2', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '220415'],
#  ['0.31', 'FALSE', 'FALSE', 'FALSE', 'None', '68892'],
#  ['5.6', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '113998'],
#  ['0.76', 'TRUE', 'FALSE', 'FALSE', 'None', '61718'],
#  ['4.8', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '621'],
#  ['22.8', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '2830'],
#  ['22.1', 'FALSE', 'FALSE', 'TRUE', 'None', '174280'],
#  ['9.8', 'TRUE', 'FALSE', 'FALSE', 'Keras', '62136'],
#  ['27.1', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '80095'],
#  ['14.3', 'TRUE', 'FALSE', 'TRUE', 'None', '88209'],
#  ['3.5', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '64470'],
#  ['6.9', 'TRUE', 'FALSE', 'TRUE', 'Keras', '102277'],
#  ['1.6', 'FALSE', 'TRUE', 'FALSE', 'None', '53512'],
#  ['1.5', 'TRUE', 'FALSE', 'TRUE', 'None', '71858'],
#  ['0.95', 'TRUE', 'FALSE', 'TRUE', 'Keras', '1481'],
#  ['8.7', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '70758'],
#  ['2.4', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '508'],
#  ['17', 'FALSE', 'TRUE', 'FALSE', 'None', '17559'],
#  ['0.93', 'TRUE', 'FALSE', 'TRUE', 'None', '10373'],
#  ['3.8', 'TRUE', 'FALSE', 'FALSE', 'Keras', '57164'],
#  ['2.5', 'TRUE', 'TRUE', 'TRUE', 'PyTorch', '7724'],
#  ['7.1', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '54590'],
#  ['29.3', 'FALSE', 'TRUE', 'FALSE', 'None', '74891'],
#  ['4.1', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '325'],
#  ['0.65', 'TRUE', 'FALSE', 'FALSE', 'Keras', '554'],
#  ['2.8', 'FALSE', 'TRUE', 'TRUE', 'None', '39643'],
#  ['4.9', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '71105'],
#  ['3.6', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '5051'],
#  ['8.5', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '11048'],
#  ['0.41', 'TRUE', 'FALSE', 'TRUE', 'None', '74783'],
#  ['19.9', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '21353'],
#  ['4.2', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '682'],
#  ['26.5', 'TRUE', 'TRUE', 'TRUE', 'Keras', '429315'],
#  ['2.6', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '65441'],
#  ['5.4', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '72536'],
#  ['5.1', 'FALSE', 'TRUE', 'TRUE', 'None', '119762'],
#  ['23.1', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '195277'],
#  ['0.5', 'FALSE', 'FALSE', 'FALSE', 'None', '69484'],
#  ['7.7', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '185336'],
#  ['6.8', 'TRUE', 'FALSE', 'FALSE', 'Keras', '69491'],
#  ['27.8', 'FALSE', 'TRUE', 'FALSE', 'Keras', '714555'],
#  ['3.9', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '72595'],
#  ['16.5', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '872'],
#  ['3.4', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '141'],
#  ['20.3', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '268989'],
#  ['1.1', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '4006'],
#  ['19.5', 'TRUE', 'FALSE', 'TRUE', 'Keras', '9336'],
#  ['2', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '3085'],
#  ['6', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '62835'],
#  ['2.6', 'TRUE', 'TRUE', 'TRUE', 'Keras', '27020'],
#  ['2.3', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '76'],
#  ['0.6', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '38476'],
#  ['1', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '70504'],
#  ['1.1', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '6973'],
#  ['2.7', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '544'],
#  ['3.9', 'TRUE', 'FALSE', 'FALSE', 'None', '58032'],
#  ['0.43', 'TRUE', 'FALSE', 'TRUE', 'None', '325'],
#  ['15.1', 'TRUE', 'FALSE', 'FALSE', 'None', '74528'],
#  ['0.58', 'FALSE', 'TRUE', 'TRUE', 'None', '119'],
#  ['29.7', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '20426'],
#  ['6.1', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '41107'],
#  ['1.1', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '11114'],
#  ['4.2', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '31534'],
#  ['1.7', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '9606'],
#  ['2.5', 'TRUE', 'FALSE', 'TRUE', 'None', '62179'],
#  ['1.3', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '58568'],
#  ['4.7', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '9603'],
#  ['3.9', 'FALSE', 'FALSE', 'FALSE', 'None', '9078'],
#  ['1.6', 'TRUE', 'TRUE', 'FALSE', 'TensorFlow', '943'],
#  ['4.1', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '52653'],
#  ['0.3', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '221'],
#  ['3.6', 'TRUE', 'FALSE', 'FALSE', 'None', '53034'],
#  ['4.6', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '11002'],
#  ['2.1', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '53292'],
#  ['1.2', 'FALSE', 'FALSE', 'TRUE', 'Scikit-learn', '456'],
#  ['0.32', 'TRUE', 'FALSE', 'TRUE', 'None', '71624'],
#  ['1.1', 'TRUE', 'FALSE', 'TRUE', 'None', '73324'],
#  ['14.8', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '91644'],
#  ['1.9', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '11855'],
#  ['9', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '23530'],
#  ['2.1', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '12407'],
#  ['2.3', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '67512'],
#  ['3.9', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '968'],
#  ['0.47', 'FALSE', 'FALSE', 'FALSE', 'None', '69126'],
#  ['0.52', 'TRUE', 'FALSE', 'FALSE', 'Keras', '56472'],
#  ['0.74', 'TRUE', 'FALSE', 'FALSE', 'None', '63077'],
#  ['4.9', 'TRUE', 'TRUE', 'TRUE', 'TensorFlow', '52625'],
#  ['2.4', 'TRUE', 'FALSE', 'FALSE', 'Keras', '68695'],
#  ['1.4', 'TRUE', 'TRUE', 'TRUE', 'Keras', '6528'],
#  ['2.3', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '64466'],
#  ['2', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '57584'],
#  ['21.5', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '63587'],
#  ['1.5', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '64878'],
#  ['6.3', 'TRUE', 'FALSE', 'TRUE', 'Keras', '2220'],
#  ['4.5', 'TRUE', 'FALSE', 'FALSE', 'Keras', '65180'],
#  ['0.98', 'TRUE', 'FALSE', 'FALSE', 'None', '60218'],
#  ['2.2', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '4645'],
#  ['2.4', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '68252'],
#  ['0.86', 'TRUE', 'FALSE', 'TRUE', 'None', '70314'],
#  ['0.39', 'TRUE', 'FALSE', 'TRUE', 'None', '766'],
#  ['26.6', 'TRUE', 'TRUE', 'FALSE', 'TensorFlow', '2030'],
#  ['1.3', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '54022'],
#  ['0.3', 'TRUE', 'TRUE', 'FALSE', 'None', '53318'],
#  ['3.1', 'TRUE', 'FALSE', 'FALSE', 'None', '56645'],
#  ['4.7', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '52326'],
#  ['16.3', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '97'],
#  ['0', 'FALSE', 'FALSE', 'FALSE', 'None', '11425'],
#  ['5.2', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '36288'],
#  ['2.5', 'TRUE', 'FALSE', 'FALSE', 'Keras', '484'],
#  ['4.2', 'TRUE', 'FALSE', 'TRUE', 'Keras', '4893'],
#  ['29.1', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '104484'],
#  ['2.5', 'TRUE', 'FALSE', 'FALSE', 'None', '56945'],
#  ['1.1', 'TRUE', 'FALSE', 'FALSE', 'None', '52839'],
#  ['1.9', 'TRUE', 'FALSE', 'FALSE', 'None', '58164'],
#  ['4.2', 'TRUE', 'FALSE', 'TRUE', 'Keras', '14807'],
#  ['1.2', 'TRUE', 'FALSE', 'FALSE', 'None', '2789'],
#  ['1.7', 'TRUE', 'TRUE', 'FALSE', 'None', '73427'],
#  ['0.47', 'TRUE', 'FALSE', 'FALSE', 'None', '58350'],
#  ['0.84', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '16755'],
#  ['4.1', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '953'],
#  ['0.6', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '65157'],
#  ['0.48', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '67006'],
#  ['1.6', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '753'],
#  ['2', 'TRUE', 'FALSE', 'FALSE', 'Keras', '59231'],
#  ['6.2', 'TRUE', 'TRUE', 'FALSE', 'None', '69020'],
#  ['2.7', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '495'],
#  ['1.1', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '42047'],
#  ['0.9', 'TRUE', 'FALSE', 'FALSE', 'None', '64311'],
#  ['0.25', 'TRUE', 'FALSE', 'TRUE', 'None', '4314'],
#  ['0', 'FALSE', 'FALSE', 'FALSE', 'None', '623'],
#  ['3.4', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '472'],
#  ['1', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '2724'],
#  ['0.56', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '594'],
#  ['4.3', 'TRUE', 'FALSE', 'TRUE', 'Keras', '10808'],
#  ['10.6', 'TRUE', 'FALSE', 'FALSE', 'Keras', '69254'],
#  ['4.8', 'TRUE', 'FALSE', 'FALSE', 'Keras', '340'],
#  ['22.8', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '39388'],
#  ['4.9', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '837'],
#  ['2.1', 'TRUE', 'FALSE', 'FALSE', 'None', '65343'],
#  ['0.62', 'FALSE', 'FALSE', 'FALSE', 'Scikit-learn', '65800'],
#  ['0.41', 'TRUE', 'FALSE', 'FALSE', 'Keras', '639'],
#  ['3.7', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '378'],
#  ['9.7', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '248'],
#  ['10.6', 'TRUE', 'FALSE', 'TRUE', 'None', '84270'],
#  ['0.58', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '88125'],
#  ['1.1', 'TRUE', 'FALSE', 'FALSE', 'None', '47405'],
#  ['9.8', 'TRUE', 'FALSE', 'FALSE', 'None', '55049'],
#  ['2.9', 'TRUE', 'TRUE', 'FALSE', 'None', '61031'],
#  ['0', 'FALSE', 'FALSE', 'FALSE', 'None', '1869'],
#  ['21.7', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '4317'],
#  ['0.99', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '64635'],
#  ['0.33', 'FALSE', 'FALSE', 'FALSE', 'None', '51402'],
#  ['1.3', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '21777'],
#  ['3', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '50854'],
#  ['2.1', 'TRUE', 'FALSE', 'FALSE', 'None', '181181'],
#  ['0.72', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '56455'],
#  ['0.4', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '55947'],
#  ['8.7', 'FALSE', 'FALSE', 'TRUE', 'PyTorch', '1516'],
#  ['7.7', 'TRUE', 'TRUE', 'FALSE', 'PyTorch', '74963'],
#  ['20.7', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '283'],
#  ['4.6', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '24310'],
#  ['8.7', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '46410'],
#  ['0.94', 'TRUE', 'TRUE', 'TRUE', 'TensorFlow', '1773'],
#  ['0.84', 'TRUE', 'FALSE', 'FALSE', 'None', '63503'],
#  ['4.7', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '8517'],
#  ['2.7', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '677'],
#  ['2.3', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '95980'],
#  ['2.7', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '61704'],
#  ['2.7', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '2096'],
#  ['0.26', 'TRUE', 'FALSE', 'FALSE', 'None', '3332'],
#  ['21', 'TRUE', 'TRUE', 'TRUE', 'None', '74876'],
#  ['2.7', 'FALSE', 'FALSE', 'FALSE', 'None', '53241'],
#  ['3.3', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '65015'],
#  ['4.5', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '69794'],
#  ['1.1', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '1688'],
#  ['3.9', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '69211'],
#  ['0.82', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '66810'],
#  ['1.8', 'TRUE', 'FALSE', 'FALSE', 'None', '70512'],
#  ['4.4', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '70396'],
#  ['1.7', 'FALSE', 'FALSE', 'FALSE', 'TensorFlow', '54649'],
#  ['1', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '163626'],
#  ['26.7', 'TRUE', 'FALSE', 'TRUE', 'None', '20134'],
#  ['0.63', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '50557'],
#  ['11.3', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '67548'],
#  ['1.2', 'TRUE', 'FALSE', 'FALSE', 'None', '835'],
#  ['2.1', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '74524'],
#  ['0.68', 'FALSE', 'TRUE', 'FALSE', 'None', '55162'],
#  ['0.99', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '66597'],
#  ['2.4', 'TRUE', 'TRUE', 'TRUE', 'None', '73110'],
#  ['1.3', 'FALSE', 'FALSE', 'FALSE', 'None', '63709'],
#  ['3.4', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '181429'],
#  ['2.5', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '22534'],
#  ['2.7', 'TRUE', 'FALSE', 'FALSE', 'Keras', '67768'],
#  ['13.7', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '63167'],
#  ['0.74', 'TRUE', 'FALSE', 'TRUE', 'Keras', '211'],
#  ['2.9', 'TRUE', 'FALSE', 'FALSE', 'None', '68852'],
#  ['3.4', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '63195'],
#  ['24.8', 'TRUE', 'TRUE', 'FALSE', 'None', '51234'],
#  ['1.7', 'TRUE', 'FALSE', 'FALSE', 'Keras', '954'],
#  ['12.4', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '94385'],
#  ['2.7', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '67835'],
#  ['6.4', 'TRUE', 'TRUE', 'FALSE', 'PyTorch', '256979'],
#  ['0.41', 'TRUE', 'FALSE', 'FALSE', 'Keras', '67498'],
#  ['15.9', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '10541'],
#  ['4.9', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '2743'],
#  ['2.1', 'TRUE', 'FALSE', 'FALSE', 'Keras', '2000'],
#  ['0.91', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '52961'],
#  ['0.42', 'TRUE', 'TRUE', 'FALSE', 'PyTorch', '542'],
#  ['1.1', 'TRUE', 'FALSE', 'FALSE', 'Keras', '68699'],
#  ['4', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '270'],
#  ['0.99', 'TRUE', 'FALSE', 'TRUE', 'None', '73596'],
#  ['0.6', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '791'],
#  ['0.75', 'TRUE', 'FALSE', 'FALSE', 'None', '65499'],
#  ['1', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '9095'],
#  ['2.8', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '56712'],
#  ['0.88', 'TRUE', 'FALSE', 'FALSE', 'None', '64964'],
#  ['1.7', 'TRUE', 'TRUE', 'TRUE', 'TensorFlow', '304'],
#  ['2.6', 'TRUE', 'FALSE', 'FALSE', 'Keras', '27862'],
#  ['4.5', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '56429'],
#  ['29.5', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '56617'],
#  ['4.8', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '4377'],
#  ['0.68', 'TRUE', 'FALSE', 'FALSE', 'None', '66917'],
#  ['3.4', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '40909'],
#  ['11.9', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '30501'],
#  ['28', 'FALSE', 'FALSE', 'FALSE', 'None', '95918'],
#  ['0.46', 'TRUE', 'FALSE', 'FALSE', 'None', '52440'],
#  ['0.47', 'TRUE', 'FALSE', 'FALSE', 'None', '51'],
#  ['7.9', 'TRUE', 'FALSE', 'TRUE', 'Keras', '17570'],
#  ['2.3', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '26060'],
#  ['4.6', 'FALSE', 'TRUE', 'TRUE', 'None', '19404'],
#  ['25.6', 'FALSE', 'FALSE', 'TRUE', 'Scikit-learn', '20696'],
#  ['1.2', 'TRUE', 'FALSE', 'FALSE', 'None', '53072'],
#  ['5.9', 'TRUE', 'TRUE', 'TRUE', 'TensorFlow', '207422'],
#  ['0.36', 'TRUE', 'FALSE', 'TRUE', 'None', '54171'],
#  ['2.4', 'TRUE', 'FALSE', 'FALSE', 'None', '67687'],
#  ['0.74', 'TRUE', 'TRUE', 'TRUE', 'None', '61813'],
#  ['3.1', 'TRUE', 'FALSE', 'TRUE', 'None', '2910'],
#  ['0.98', 'TRUE', 'FALSE', 'FALSE', 'None', '851'],
#  ['1.5', 'TRUE', 'FALSE', 'FALSE', 'None', '552'],
#  ['24.8', 'FALSE', 'FALSE', 'FALSE', 'PyTorch', '64562'],
#  ['2.9', 'TRUE', 'TRUE', 'TRUE', 'None', '70663'],
#  ['5.8', 'TRUE', 'FALSE', 'TRUE', 'None', '474'],
#  ['2.2', 'FALSE', 'FALSE', 'FALSE', 'None', '64573'],
#  ['0.91', 'TRUE', 'FALSE', 'FALSE', 'None', '311'],
#  ['0.25', 'TRUE', 'FALSE', 'TRUE', 'None', '804'],
#  ['7.4', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '14315'],
#  ['3.3', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '44540'],
#  ['1.8', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '26130'],
#  ['27.3', 'FALSE', 'FALSE', 'TRUE', 'None', '66962'],
#  ['3.8', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '114075'],
#  ['0.48', 'TRUE', 'FALSE', 'FALSE', 'Keras', '285'],
#  ['2.2', 'TRUE', 'FALSE', 'TRUE', 'None', '52671'],
#  ['3.4', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '88205'],
#  ['0.71', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '31158'],
#  ['1.2', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '750'],
#  ['2.1', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '64017'],
#  ['12.5', 'FALSE', 'FALSE', 'TRUE', 'None', '71237'],
#  ['7', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '23040'],
#  ['9.1', 'TRUE', 'FALSE', 'TRUE', 'Keras', '30859'],
#  ['4.5', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '20431'],
#  ['1.1', 'TRUE', 'TRUE', 'TRUE', 'TensorFlow', '16710'],
#  ['19.9', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '12953'],
#  ['2.4', 'TRUE', 'FALSE', 'TRUE', 'Keras', '58403'],
#  ['25.9', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '237978'],
#  ['2', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '19659'],
#  ['3.4', 'FALSE', 'FALSE', 'TRUE', 'None', '2090'],
#  ['3.8', 'TRUE', 'TRUE', 'TRUE', 'TensorFlow', '44685'],
#  ['0', 'FALSE', 'FALSE', 'FALSE', 'None', '729'],
#  ['7.3', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '674'],
#  ['0.44', 'TRUE', 'FALSE', 'FALSE', 'None', '24801'],
#  ['0.66', 'TRUE', 'FALSE', 'TRUE', 'None', '59184'],
#  ['1.9', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '522'],
#  ['9.3', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '75691'],
#  ['1.4', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '12092'],
#  ['0.34', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '240163'],
#  ['0.47', 'TRUE', 'FALSE', 'FALSE', 'None', '993'],
#  ['9.1', 'TRUE', 'FALSE', 'TRUE', 'Keras', '51442'],
#  ['3.3', 'TRUE', 'TRUE', 'TRUE', 'PyTorch', '109344'],
#  ['3.5', 'TRUE', 'FALSE', 'TRUE', 'Keras', '922'],
#  ['0.93', 'FALSE', 'TRUE', 'FALSE', 'None', '68036'],
#  ['1.7', 'FALSE', 'FALSE', 'TRUE', 'Scikit-learn', '16529'],
#  ['2.8', 'TRUE', 'FALSE', 'FALSE', 'None', '53990'],
#  ['1.2', 'TRUE', 'FALSE', 'FALSE', 'None', '52974'],
#  ['2.2', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '66042'],
#  ['21.9', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '50591'],
#  ['13.6', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '72511'],
#  ['2.9', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '57331'],
#  ['8.4', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '33733'],
#  ['0.69', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '57104'],
#  ['4.7', 'TRUE', 'FALSE', 'FALSE', 'Keras', '83630'],
#  ['0.54', 'TRUE', 'FALSE', 'TRUE', 'None', '55929'],
#  ['0.22', 'TRUE', 'FALSE', 'FALSE', 'None', '68255'],
#  ['3.2', 'TRUE', 'FALSE', 'TRUE', 'None', '235'],
#  ['4.6', 'TRUE', 'TRUE', 'FALSE', 'Keras', '69649'],
#  ...]

# %%
data[:5]
# Out:
# [['experience_coding',
#   'python_user',
#   'r_user',
#   'sql_user',
#   'most_used',
#   'compensation'],
#  ['6.1', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '124267'],
#  ['12.3', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '236889'],
#  ['2.2', 'TRUE', 'FALSE', 'FALSE', 'None', '74321'],
#  ['2.7', 'FALSE', 'FALSE', 'TRUE', 'None', '62593']]

# %%
print(data[:5])
# Out:
# [['experience_coding', 'python_user', 'r_user', 'sql_user', 'most_used', 'compensation'], ['6.1', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '124267'], ['12.3', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '236889'], ['2.2', 'TRUE', 'FALSE', 'FALSE', 'None', '74321'], ['2.7', 'FALSE', 'FALSE', 'TRUE', 'None', '62593']]

# %%
headers = data[0]
headers
# Out:
# ['experience_coding',
#  'python_user',
#  'r_user',
#  'sql_user',
#  'most_used',
#  'compensation']

# %%
survey = data[1:]
survey
# Out:
# [['6.1', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '124267'],
#  ['12.3', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '236889'],
#  ['2.2', 'TRUE', 'FALSE', 'FALSE', 'None', '74321'],
#  ['2.7', 'FALSE', 'FALSE', 'TRUE', 'None', '62593'],
#  ['1.2', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '36288'],
#  ['1', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '61302'],
#  ['1.8', 'FALSE', 'FALSE', 'FALSE', 'None', '68984'],
#  ['6.1', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '18858'],
#  ['4.5', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '55418'],
#  ['1.1', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '614'],
#  ['2.7', 'TRUE', 'TRUE', 'TRUE', 'None', '70564'],
#  ['0.93', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '55525'],
#  ['0.32', 'TRUE', 'FALSE', 'FALSE', 'None', '61005'],
#  ['9.9', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '2846'],
#  ['0.78', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '21'],
#  ['13.5', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '14699'],
#  ['26.5', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '2110'],
#  ['1.5', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '620'],
#  ['3.4', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '73527'],
#  ['0.6', 'FALSE', 'FALSE', 'FALSE', 'None', '6992'],
#  ['0.95', 'TRUE', 'FALSE', 'FALSE', 'None', '22311'],
#  ['4.6', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '1377'],
#  ['2.8', 'FALSE', 'TRUE', 'FALSE', 'None', '69174'],
#  ['28.2', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '117636'],
#  ['1.4', 'TRUE', 'TRUE', 'TRUE', 'TensorFlow', '65937'],
#  ['4.8', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '27856'],
#  ['0.37', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '903'],
#  ['4.5', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '50501'],
#  ['4.4', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '482'],
#  ['0.69', 'TRUE', 'FALSE', 'FALSE', 'None', '70407'],
#  ['1.5', 'TRUE', 'FALSE', 'FALSE', 'None', '8690'],
#  ['9.6', 'TRUE', 'TRUE', 'TRUE', 'None', '114648'],
#  ['0.31', 'FALSE', 'TRUE', 'FALSE', 'None', '73454'],
#  ['3.5', 'TRUE', 'FALSE', 'FALSE', 'None', '8075'],
#  ['1', 'TRUE', 'FALSE', 'FALSE', 'None', '59151'],
#  ['0.2', 'TRUE', 'TRUE', 'TRUE', 'None', '70112'],
#  ['0.39', 'TRUE', 'FALSE', 'TRUE', 'None', '70183'],
#  ['5', 'TRUE', 'FALSE', 'FALSE', 'None', '64502'],
#  ['4', 'TRUE', 'FALSE', 'TRUE', 'None', '2521'],
#  ['0.47', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '63616'],
#  ['8.1', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '59849'],
#  ['1.8', 'TRUE', 'FALSE', 'FALSE', 'None', '31516'],
#  ['17.1', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '18582'],
#  ['1.4', 'TRUE', 'FALSE', 'FALSE', 'Keras', '4187'],
#  ['1.3', 'TRUE', 'FALSE', 'FALSE', 'None', '64405'],
#  ['3.1', 'TRUE', 'FALSE', 'FALSE', 'Keras', '114807'],
#  ['0.26', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '632'],
#  ['2.1', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '61157'],
#  ['4.4', 'TRUE', 'FALSE', 'TRUE', 'Keras', '1194'],
#  ['5.2', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '28955'],
#  ['0.7', 'TRUE', 'TRUE', 'TRUE', 'TensorFlow', '56553'],
#  ['0.69', 'FALSE', 'FALSE', 'FALSE', 'None', '75177'],
#  ['1.3', 'FALSE', 'TRUE', 'TRUE', 'None', '28009'],
#  ['1.5', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '67074'],
#  ['2.2', 'FALSE', 'FALSE', 'TRUE', 'None', '50059'],
#  ['6.3', 'FALSE', 'FALSE', 'FALSE', 'TensorFlow', '7624'],
#  ['2.9', 'TRUE', 'FALSE', 'FALSE', 'None', '74321'],
#  ['1.2', 'TRUE', 'TRUE', 'FALSE', 'None', '671'],
#  ['1.5', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '837'],
#  ['1.8', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '2011'],
#  ['0.91', 'FALSE', 'FALSE', 'FALSE', 'Scikit-learn', '62937'],
#  ['4.5', 'TRUE', 'FALSE', 'FALSE', 'None', '685'],
#  ['1.6', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '41615'],
#  ['0.27', 'TRUE', 'FALSE', 'FALSE', 'None', '52572'],
#  ['2.6', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '51856'],
#  ['1.7', 'TRUE', 'FALSE', 'FALSE', 'Keras', '411'],
#  ['0.74', 'TRUE', 'FALSE', 'FALSE', 'None', '152'],
#  ['2.7', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '8181'],
#  ['0.99', 'TRUE', 'TRUE', 'FALSE', 'Keras', '2708'],
#  ['24.8', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '55041'],
#  ['0.32', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '68412'],
#  ['3.5', 'FALSE', 'FALSE', 'TRUE', 'TensorFlow', '6141'],
#  ['5.7', 'FALSE', 'FALSE', 'TRUE', 'None', '3979'],
#  ['22', 'TRUE', 'FALSE', 'FALSE', 'Keras', '3760'],
#  ['9.9', 'TRUE', 'FALSE', 'FALSE', 'Keras', '57465'],
#  ['3.9', 'TRUE', 'FALSE', 'FALSE', 'Keras', '3864'],
#  ['20.5', 'TRUE', 'FALSE', 'FALSE', 'None', '488487'],
#  ['0.81', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '24393'],
#  ['9.8', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '68624'],
#  ['1.5', 'TRUE', 'FALSE', 'TRUE', 'None', '70796'],
#  ['12.3', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '236889'],
#  ['6.6', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '57861'],
#  ['2.1', 'TRUE', 'FALSE', 'FALSE', 'None', '21055'],
#  ['2.5', 'TRUE', 'FALSE', 'FALSE', 'Keras', '59167'],
#  ['0', 'FALSE', 'FALSE', 'FALSE', 'None', '55882'],
#  ['1.7', 'FALSE', 'FALSE', 'FALSE', 'None', '73802'],
#  ['5.3', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '21206'],
#  ['1.4', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '79803'],
#  ['1.5', 'TRUE', 'FALSE', 'TRUE', 'None', '73043'],
#  ['28.2', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '268191'],
#  ['0.97', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '14298'],
#  ['1.1', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '68805'],
#  ['7', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '56003'],
#  ['1', 'TRUE', 'FALSE', 'TRUE', 'None', '73664'],
#  ['0.71', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '434'],
#  ['9.3', 'TRUE', 'TRUE', 'FALSE', 'Keras', '52109'],
#  ['1.7', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '10284'],
#  ['20.5', 'TRUE', 'FALSE', 'FALSE', 'Keras', '43906'],
#  ['0.75', 'TRUE', 'FALSE', 'FALSE', 'None', '67971'],
#  ['0.98', 'TRUE', 'FALSE', 'TRUE', 'None', '58465'],
#  ['0.8', 'FALSE', 'TRUE', 'FALSE', 'None', '64488'],
#  ['1.3', 'TRUE', 'FALSE', 'FALSE', 'None', '7709'],
#  ['0.36', 'TRUE', 'FALSE', 'FALSE', 'Keras', '1957'],
#  ['1.2', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '4131'],
#  ['8.6', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '26022'],
#  ['18.4', 'TRUE', 'FALSE', 'TRUE', 'None', '29926'],
#  ['2.7', 'FALSE', 'FALSE', 'TRUE', 'None', '62593'],
#  ['24.3', 'TRUE', 'TRUE', 'TRUE', 'None', '109543'],
#  ['0.94', 'TRUE', 'FALSE', 'TRUE', 'None', '107644'],
#  ['1.4', 'FALSE', 'TRUE', 'TRUE', 'None', '1047'],
#  ['3.3', 'TRUE', 'FALSE', 'FALSE', 'None', '59909'],
#  ['0.93', 'TRUE', 'FALSE', 'FALSE', 'None', '68344'],
#  ['2.3', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '54427'],
#  ['0.59', 'FALSE', 'FALSE', 'FALSE', 'None', '70930'],
#  ['1.2', 'TRUE', 'FALSE', 'FALSE', 'None', '50835'],
#  ['8.5', 'TRUE', 'TRUE', 'TRUE', 'Keras', '14151'],
#  ['3.3', 'FALSE', 'TRUE', 'FALSE', 'None', '11681'],
#  ['21.1', 'TRUE', 'FALSE', 'TRUE', 'None', '71808'],
#  ['1.2', 'FALSE', 'FALSE', 'FALSE', 'None', '70991'],
#  ['12.2', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '31626'],
#  ['3.8', 'FALSE', 'FALSE', 'FALSE', 'TensorFlow', '52416'],
#  ['4.3', 'TRUE', 'FALSE', 'FALSE', 'Keras', '288146'],
#  ['13.1', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '65143'],
#  ['24.3', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '34866'],
#  ['1.6', 'TRUE', 'TRUE', 'FALSE', 'Keras', '186'],
#  ['2.9', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '60065'],
#  ['9.4', 'TRUE', 'FALSE', 'FALSE', 'None', '40336'],
#  ['7.7', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '115654'],
#  ['0.3', 'TRUE', 'FALSE', 'TRUE', 'None', '431'],
#  ['9', 'TRUE', 'TRUE', 'FALSE', 'TensorFlow', '59814'],
#  ['4.2', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '45413'],
#  ['1.9', 'FALSE', 'FALSE', 'FALSE', 'None', '4196'],
#  ['8.3', 'TRUE', 'FALSE', 'FALSE', 'None', '55751'],
#  ['0.21', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '61912'],
#  ['18.8', 'TRUE', 'FALSE', 'FALSE', 'None', '49478'],
#  ['9.3', 'FALSE', 'FALSE', 'TRUE', 'Scikit-learn', '29139'],
#  ['1.8', 'TRUE', 'FALSE', 'FALSE', 'Keras', '67272'],
#  ['2.8', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '70264'],
#  ['2.4', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '264'],
#  ['15.3', 'TRUE', 'TRUE', 'TRUE', 'Keras', '14853'],
#  ['3.9', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '55482'],
#  ['0.3', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '26'],
#  ['0.8', 'FALSE', 'FALSE', 'TRUE', 'None', '250'],
#  ['0.79', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '66025'],
#  ['11.1', 'TRUE', 'FALSE', 'TRUE', 'None', '55906'],
#  ['0.24', 'TRUE', 'FALSE', 'FALSE', 'None', '63754'],
#  ['19.7', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '86855'],
#  ['8.5', 'TRUE', 'FALSE', 'FALSE', 'Keras', '63242'],
#  ['0.26', 'TRUE', 'FALSE', 'TRUE', 'None', '70448'],
#  ['0.75', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '68964'],
#  ['24.4', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '111583'],
#  ['6.8', 'TRUE', 'FALSE', 'FALSE', 'Keras', '52350'],
#  ['4.4', 'TRUE', 'FALSE', 'TRUE', 'None', '58574'],
#  ['3.2', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '330'],
#  ['0.84', 'TRUE', 'FALSE', 'TRUE', 'None', '64478'],
#  ['16', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '94273'],
#  ['4.9', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '62142'],
#  ['8.3', 'TRUE', 'FALSE', 'TRUE', 'Keras', '5857'],
#  ['6.6', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '194518'],
#  ['4', 'TRUE', 'FALSE', 'FALSE', 'None', '60873'],
#  ['23.9', 'TRUE', 'FALSE', 'TRUE', 'None', '55584'],
#  ['27', 'FALSE', 'FALSE', 'FALSE', 'PyTorch', '949'],
#  ['0.91', 'TRUE', 'FALSE', 'FALSE', 'None', '27748'],
#  ['2.2', 'TRUE', 'FALSE', 'TRUE', 'None', '239'],
#  ['13.9', 'FALSE', 'FALSE', 'TRUE', 'None', '120047'],
#  ['3.4', 'TRUE', 'FALSE', 'FALSE', 'None', '332'],
#  ['1.4', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '51428'],
#  ['6.6', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '256063'],
#  ['2.6', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '50783'],
#  ['8.5', 'TRUE', 'TRUE', 'TRUE', 'Keras', '109423'],
#  ['28.2', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '85525'],
#  ['2.7', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '226'],
#  ['8.6', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '13056'],
#  ['2.9', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '8015'],
#  ['2.6', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '450'],
#  ['7.5', 'FALSE', 'FALSE', 'TRUE', 'None', '55219'],
#  ['1.3', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '348'],
#  ['16.2', 'TRUE', 'FALSE', 'FALSE', 'None', '53685'],
#  ['2.7', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '59456'],
#  ['1.8', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '62821'],
#  ['7.1', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '13478'],
#  ['1.9', 'TRUE', 'FALSE', 'FALSE', 'None', '59666'],
#  ['0.41', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '57673'],
#  ['2.3', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '29472'],
#  ['11.8', 'TRUE', 'TRUE', 'TRUE', 'PyTorch', '276659'],
#  ['4', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '5119'],
#  ['5.4', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '27631'],
#  ['3.8', 'FALSE', 'FALSE', 'FALSE', 'None', '282'],
#  ['5.7', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '34238'],
#  ['0', 'FALSE', 'FALSE', 'FALSE', 'None', '106203'],
#  ['0', 'FALSE', 'FALSE', 'FALSE', 'None', '74289'],
#  ['21.4', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '226171'],
#  ['2.5', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '74445'],
#  ['7.6', 'TRUE', 'TRUE', 'FALSE', 'TensorFlow', '67863'],
#  ['22.8', 'FALSE', 'FALSE', 'TRUE', 'None', '65871'],
#  ['1.7', 'TRUE', 'FALSE', 'TRUE', 'None', '67736'],
#  ['2.6', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '785'],
#  ['2.1', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '28073'],
#  ['1.9', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '20390'],
#  ['3.2', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '4791'],
#  ['7.2', 'FALSE', 'FALSE', 'TRUE', 'None', '16059'],
#  ['14.1', 'TRUE', 'FALSE', 'FALSE', 'Keras', '62115'],
#  ['1.9', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '73319'],
#  ['0.93', 'FALSE', 'FALSE', 'FALSE', 'None', '44491'],
#  ['9.6', 'TRUE', 'FALSE', 'FALSE', 'None', '74588'],
#  ['1.4', 'TRUE', 'TRUE', 'FALSE', 'None', '74799'],
#  ['0.45', 'TRUE', 'FALSE', 'FALSE', 'None', '57207'],
#  ['3.2', 'TRUE', 'FALSE', 'FALSE', 'Keras', '14370'],
#  ['1', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '57816'],
#  ['4.4', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '62513'],
#  ['17.7', 'TRUE', 'FALSE', 'FALSE', 'Keras', '61763'],
#  ['8.7', 'FALSE', 'TRUE', 'FALSE', 'None', '50427'],
#  ['28.9', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '1129'],
#  ['0.58', 'TRUE', 'FALSE', 'FALSE', 'None', '59687'],
#  ['1.3', 'FALSE', 'FALSE', 'FALSE', 'None', '67959'],
#  ['11.3', 'FALSE', 'TRUE', 'FALSE', 'None', '62849'],
#  ['3.1', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '1337'],
#  ['2.5', 'TRUE', 'FALSE', 'FALSE', 'Keras', '72317'],
#  ['5.9', 'TRUE', 'FALSE', 'TRUE', 'Keras', '31044'],
#  ['2.7', 'TRUE', 'FALSE', 'TRUE', 'Keras', '66163'],
#  ['1.1', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '11165'],
#  ['16.5', 'FALSE', 'TRUE', 'FALSE', 'Scikit-learn', '68871'],
#  ['7.5', 'TRUE', 'FALSE', 'TRUE', 'Keras', '22332'],
#  ['25.2', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '6196'],
#  ['0.88', 'TRUE', 'FALSE', 'FALSE', 'None', '388'],
#  ['0.6', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '12925'],
#  ['4.1', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '3092'],
#  ['8.2', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '8880'],
#  ['5.7', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '65433'],
#  ['0.49', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '13423'],
#  ['2.6', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '4704'],
#  ['2.2', 'TRUE', 'FALSE', 'FALSE', 'Keras', '740'],
#  ['9.2', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '64640'],
#  ['4', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '63'],
#  ['28.6', 'TRUE', 'FALSE', 'TRUE', 'None', '79687'],
#  ['0.6', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '63155'],
#  ['2.9', 'TRUE', 'FALSE', 'TRUE', 'None', '54825'],
#  ['29.7', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '61352'],
#  ['1.7', 'TRUE', 'FALSE', 'FALSE', 'None', '64184'],
#  ['24', 'TRUE', 'FALSE', 'TRUE', 'Keras', '130578'],
#  ['1.7', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '57821'],
#  ['0.66', 'TRUE', 'TRUE', 'TRUE', 'None', '52061'],
#  ['3.2', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '2279'],
#  ['2.2', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '73945'],
#  ['0.97', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '62225'],
#  ['0.73', 'TRUE', 'FALSE', 'FALSE', 'None', '52153'],
#  ['6.1', 'TRUE', 'FALSE', 'TRUE', 'Keras', '32815'],
#  ['3.3', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '178'],
#  ['0.34', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '553'],
#  ['5.3', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '64796'],
#  ['0.93', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '51701'],
#  ['4.3', 'TRUE', 'FALSE', 'FALSE', 'None', '70917'],
#  ['2.7', 'FALSE', 'FALSE', 'FALSE', 'None', '1672'],
#  ['1.4', 'FALSE', 'FALSE', 'TRUE', 'None', '561'],
#  ['13.7', 'FALSE', 'FALSE', 'TRUE', 'None', '64214'],
#  ['3.6', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '32809'],
#  ['1.5', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '61430'],
#  ['0.42', 'FALSE', 'FALSE', 'TRUE', 'TensorFlow', '2852'],
#  ['29.1', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '124867'],
#  ['23.9', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '55354'],
#  ['0', 'FALSE', 'FALSE', 'FALSE', 'None', '341'],
#  ['2.2', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '3241'],
#  ['10', 'TRUE', 'FALSE', 'TRUE', 'Keras', '114569'],
#  ['0.93', 'TRUE', 'TRUE', 'TRUE', 'None', '5068'],
#  ['9.2', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '53406'],
#  ['15.1', 'TRUE', 'TRUE', 'TRUE', 'PyTorch', '67586'],
#  ['14.6', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '368'],
#  ['1.8', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '66719'],
#  ['9.6', 'TRUE', 'TRUE', 'TRUE', 'None', '61028'],
#  ['3.2', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '380'],
#  ['2.4', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '104'],
#  ['1.9', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '57262'],
#  ['0.98', 'FALSE', 'FALSE', 'FALSE', 'None', '72756'],
#  ['16.7', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '117471'],
#  ['6.6', 'TRUE', 'FALSE', 'TRUE', 'None', '948'],
#  ['1.6', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '3458'],
#  ['3.7', 'TRUE', 'TRUE', 'FALSE', 'TensorFlow', '62798'],
#  ['2.7', 'FALSE', 'FALSE', 'FALSE', 'None', '59402'],
#  ['0.53', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '54542'],
#  ['0.77', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '69584'],
#  ['0.76', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '2762'],
#  ['0.73', 'TRUE', 'FALSE', 'FALSE', 'None', '51493'],
#  ['0.34', 'TRUE', 'FALSE', 'TRUE', 'Keras', '397'],
#  ['24.7', 'TRUE', 'FALSE', 'FALSE', 'Keras', '268277'],
#  ['1.4', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '13504'],
#  ['11.7', 'FALSE', 'FALSE', 'FALSE', 'Scikit-learn', '236436'],
#  ['3.9', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '69429'],
#  ['15', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '183614'],
#  ['4.7', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '62053'],
#  ['0.41', 'FALSE', 'FALSE', 'FALSE', 'None', '20029'],
#  ['0', 'FALSE', 'FALSE', 'FALSE', 'None', '64'],
#  ['2.3', 'TRUE', 'FALSE', 'TRUE', 'None', '55068'],
#  ['2.2', 'TRUE', 'TRUE', 'TRUE', 'Keras', '2756'],
#  ['1', 'TRUE', 'FALSE', 'FALSE', 'Keras', '68080'],
#  ['1.9', 'TRUE', 'FALSE', 'TRUE', 'None', '51110'],
#  ['0.44', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '6055'],
#  ['0', 'FALSE', 'FALSE', 'FALSE', 'None', '566'],
#  ['2.9', 'TRUE', 'FALSE', 'TRUE', 'None', '57222'],
#  ['29', 'TRUE', 'TRUE', 'FALSE', 'TensorFlow', '30662'],
#  ['12', 'TRUE', 'FALSE', 'FALSE', 'None', '57836'],
#  ['3.2', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '8651'],
#  ['3.2', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '50354'],
#  ['1.5', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '67366'],
#  ['1.8', 'FALSE', 'FALSE', 'TRUE', 'None', '3181'],
#  ['0.75', 'TRUE', 'FALSE', 'FALSE', 'Keras', '50292'],
#  ['20.1', 'FALSE', 'TRUE', 'FALSE', 'None', '26892'],
#  ['19.2', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '70349'],
#  ['8.7', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '11195'],
#  ['0', 'FALSE', 'FALSE', 'FALSE', 'None', '51080'],
#  ['4.9', 'FALSE', 'FALSE', 'FALSE', 'None', '9638'],
#  ['21.5', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '441'],
#  ['1.6', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '15222'],
#  ['0.37', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '748'],
#  ['17.4', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '65215'],
#  ['4.6', 'TRUE', 'FALSE', 'FALSE', 'Keras', '25696'],
#  ['5.2', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '54268'],
#  ['9.5', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '62430'],
#  ['1.2', 'TRUE', 'TRUE', 'TRUE', 'None', '57599'],
#  ['2', 'TRUE', 'FALSE', 'FALSE', 'None', '61169'],
#  ['2.5', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '72278'],
#  ['1.6', 'TRUE', 'FALSE', 'FALSE', 'None', '56628'],
#  ['1.7', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '58598'],
#  ['18.3', 'TRUE', 'FALSE', 'TRUE', 'None', '104890'],
#  ['6.1', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '70778'],
#  ['0.48', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '1920'],
#  ['2.9', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '64650'],
#  ['2.9', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '61957'],
#  ['1.6', 'TRUE', 'TRUE', 'FALSE', 'PyTorch', '280'],
#  ['2.4', 'TRUE', 'FALSE', 'TRUE', 'None', '53807'],
#  ['5.1', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '4278'],
#  ['0.43', 'TRUE', 'FALSE', 'TRUE', 'None', '62815'],
#  ['0.81', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '55603'],
#  ['10.5', 'TRUE', 'FALSE', 'FALSE', 'None', '45474'],
#  ['0.22', 'TRUE', 'TRUE', 'TRUE', 'None', '59812'],
#  ['1.8', 'TRUE', 'FALSE', 'TRUE', 'Keras', '10176'],
#  ['9.1', 'TRUE', 'TRUE', 'TRUE', 'TensorFlow', '3449'],
#  ['4.3', 'TRUE', 'FALSE', 'FALSE', 'Keras', '330'],
#  ['7.7', 'TRUE', 'FALSE', 'FALSE', 'None', '50545'],
#  ['8.1', 'TRUE', 'TRUE', 'FALSE', 'TensorFlow', '303'],
#  ['4.1', 'FALSE', 'TRUE', 'FALSE', 'Keras', '64186'],
#  ['1.7', 'TRUE', 'TRUE', 'FALSE', 'None', '1426'],
#  ['1.4', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '750'],
#  ['22.9', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '74868'],
#  ['18.5', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '26708'],
#  ['2.2', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '64493'],
#  ['0.42', 'TRUE', 'TRUE', 'TRUE', 'TensorFlow', '79'],
#  ['24.1', 'FALSE', 'FALSE', 'TRUE', 'None', '72549'],
#  ['5.8', 'TRUE', 'FALSE', 'TRUE', 'Keras', '28039'],
#  ['0.93', 'FALSE', 'FALSE', 'FALSE', 'None', '59061'],
#  ['4.8', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '69723'],
#  ['2.6', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '69452'],
#  ['3.1', 'TRUE', 'FALSE', 'TRUE', 'Keras', '22665'],
#  ['4', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '214'],
#  ['9.9', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '2355'],
#  ['7.2', 'TRUE', 'TRUE', 'TRUE', 'Keras', '162385'],
#  ['5.4', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '5871'],
#  ['8.3', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '853'],
#  ['2.9', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '3929'],
#  ['0.54', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '58863'],
#  ['0.55', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '8009'],
#  ['0', 'FALSE', 'FALSE', 'FALSE', 'None', '68498'],
#  ['0.36', 'FALSE', 'FALSE', 'FALSE', 'None', '1948'],
#  ['1', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '69648'],
#  ['6.3', 'TRUE', 'TRUE', 'TRUE', 'None', '74877'],
#  ['2.3', 'TRUE', 'FALSE', 'FALSE', 'Keras', '65598'],
#  ['0.68', 'FALSE', 'FALSE', 'TRUE', 'None', '54524'],
#  ['1.6', 'TRUE', 'FALSE', 'TRUE', 'Keras', '66262'],
#  ['0', 'FALSE', 'FALSE', 'FALSE', 'None', '4427'],
#  ['0.58', 'FALSE', 'FALSE', 'FALSE', 'None', '31841'],
#  ['0.85', 'TRUE', 'FALSE', 'FALSE', 'None', '54481'],
#  ['2.9', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '57717'],
#  ['3.4', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '25721'],
#  ['25.4', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '64217'],
#  ['8.8', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '2203'],
#  ['5.5', 'TRUE', 'TRUE', 'FALSE', 'TensorFlow', '62142'],
#  ['4.2', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '12573'],
#  ['14.2', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '13212'],
#  ['2.8', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '71758'],
#  ['5.2', 'FALSE', 'FALSE', 'FALSE', 'None', '4306'],
#  ['1.6', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '835'],
#  ['1.3', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '601'],
#  ['4.9', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '61209'],
#  ['0', 'FALSE', 'FALSE', 'FALSE', 'None', '365'],
#  ['0.4', 'TRUE', 'FALSE', 'FALSE', 'None', '702'],
#  ['0.93', 'TRUE', 'TRUE', 'TRUE', 'None', '67436'],
#  ['2.4', 'TRUE', 'FALSE', 'FALSE', 'Keras', '73296'],
#  ['10.7', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '63999'],
#  ['2.1', 'TRUE', 'FALSE', 'TRUE', 'Keras', '58760'],
#  ['2.4', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '70522'],
#  ['14.8', 'FALSE', 'TRUE', 'TRUE', 'None', '78489'],
#  ['3.5', 'TRUE', 'FALSE', 'TRUE', 'None', '59768'],
#  ['21.8', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '53040'],
#  ['4.3', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '1894'],
#  ['12.9', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '124879'],
#  ['2.5', 'TRUE', 'TRUE', 'TRUE', 'PyTorch', '98886'],
#  ['0.96', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '797'],
#  ['1.9', 'FALSE', 'TRUE', 'FALSE', 'None', '67900'],
#  ['21.7', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '169111'],
#  ['0.27', 'TRUE', 'TRUE', 'FALSE', 'None', '69490'],
#  ['16.8', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '18059'],
#  ['1.8', 'TRUE', 'FALSE', 'FALSE', 'None', '61535'],
#  ['27.8', 'TRUE', 'TRUE', 'FALSE', 'TensorFlow', '279'],
#  ['1', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '4951'],
#  ['8.2', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '675'],
#  ['2.5', 'TRUE', 'TRUE', 'TRUE', 'None', '66662'],
#  ['2.2', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '5345'],
#  ['1.3', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '15827'],
#  ['7.1', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '268'],
#  ['10', 'FALSE', 'FALSE', 'FALSE', 'None', '63128'],
#  ['0.95', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '51943'],
#  ['6.3', 'FALSE', 'TRUE', 'FALSE', 'None', '7606'],
#  ['1.8', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '55361'],
#  ['0.29', 'TRUE', 'FALSE', 'FALSE', 'None', '2284'],
#  ['4.9', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '13232'],
#  ['0.73', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '70'],
#  ['3.7', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '51162'],
#  ['5.1', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '24490'],
#  ['1.9', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '58763'],
#  ['0.21', 'TRUE', 'TRUE', 'TRUE', 'None', '57140'],
#  ['0.36', 'TRUE', 'FALSE', 'FALSE', 'None', '53937'],
#  ['9.9', 'TRUE', 'TRUE', 'TRUE', 'Keras', '10720'],
#  ['1.3', 'TRUE', 'FALSE', 'TRUE', 'None', '55375'],
#  ['13.1', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '9526'],
#  ['0.33', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '74828'],
#  ['2.8', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '584'],
#  ['1.4', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '42097'],
#  ['2.7', 'TRUE', 'FALSE', 'FALSE', 'Keras', '62804'],
#  ['1.7', 'TRUE', 'FALSE', 'FALSE', 'None', '4296'],
#  ['1.1', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '60567'],
#  ['5.6', 'TRUE', 'TRUE', 'TRUE', 'None', '102894'],
#  ['0.7', 'FALSE', 'TRUE', 'TRUE', 'None', '29160'],
#  ['0.73', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '1491'],
#  ['2.8', 'FALSE', 'FALSE', 'FALSE', 'Keras', '614'],
#  ['9.4', 'TRUE', 'FALSE', 'TRUE', 'Keras', '37053'],
#  ['2.4', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '181179'],
#  ['3', 'TRUE', 'FALSE', 'FALSE', 'None', '55377'],
#  ['8.4', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '6947'],
#  ['3.4', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '21934'],
#  ['0.64', 'TRUE', 'FALSE', 'TRUE', 'None', '65'],
#  ['1.4', 'TRUE', 'FALSE', 'TRUE', 'None', '57123'],
#  ['2', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '1943'],
#  ['2.2', 'TRUE', 'FALSE', 'FALSE', 'Keras', '67032'],
#  ['3.8', 'TRUE', 'FALSE', 'TRUE', 'None', '63358'],
#  ['3.2', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '28'],
#  ['0.95', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '3519'],
#  ['2.6', 'FALSE', 'TRUE', 'FALSE', 'None', '356'],
#  ['14.2', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '158644'],
#  ['0.64', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '7226'],
#  ['16.7', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '12915'],
#  ['0.83', 'TRUE', 'TRUE', 'TRUE', 'PyTorch', '73268'],
#  ['2.9', 'TRUE', 'FALSE', 'TRUE', 'None', '57188'],
#  ['0.49', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '102'],
#  ['19.6', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '3032'],
#  ['1.1', 'TRUE', 'FALSE', 'FALSE', 'None', '123071'],
#  ['0.57', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '250388'],
#  ['2.1', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '70915'],
#  ['2.4', 'TRUE', 'FALSE', 'TRUE', 'None', '201'],
#  ['16.9', 'TRUE', 'TRUE', 'TRUE', 'None', '246015'],
#  ['2.9', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '11378'],
#  ['9', 'FALSE', 'TRUE', 'FALSE', 'Scikit-learn', '303'],
#  ['3.5', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '50638'],
#  ['0.91', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '20749'],
#  ['6.4', 'TRUE', 'FALSE', 'FALSE', 'None', '521'],
#  ['7', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '17911'],
#  ['2', 'FALSE', 'FALSE', 'TRUE', 'None', '70675'],
#  ['0.56', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '70432'],
#  ['0.67', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '78601'],
#  ['0.69', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '1282'],
#  ['9.1', 'TRUE', 'TRUE', 'FALSE', 'TensorFlow', '99399'],
#  ['1.8', 'FALSE', 'FALSE', 'FALSE', 'PyTorch', '1503'],
#  ['1.2', 'TRUE', 'FALSE', 'TRUE', 'Keras', '53171'],
#  ['9.6', 'FALSE', 'FALSE', 'FALSE', 'None', '57165'],
#  ['16.6', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '25114'],
#  ['1.1', 'TRUE', 'FALSE', 'FALSE', 'Keras', '26960'],
#  ['9', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '60063'],
#  ['0', 'FALSE', 'FALSE', 'FALSE', 'None', '610'],
#  ['4.5', 'TRUE', 'FALSE', 'FALSE', 'Keras', '69739'],
#  ['0', 'FALSE', 'FALSE', 'FALSE', 'None', '3134'],
#  ['6.8', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '66837'],
#  ['0.54', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '55165'],
#  ['3.6', 'FALSE', 'FALSE', 'FALSE', 'Keras', '988'],
#  ['14.6', 'FALSE', 'FALSE', 'FALSE', 'None', '55580'],
#  ['17', 'TRUE', 'TRUE', 'TRUE', 'TensorFlow', '76201'],
#  ['0.67', 'TRUE', 'FALSE', 'FALSE', 'Keras', '64966'],
#  ['0.92', 'FALSE', 'TRUE', 'FALSE', 'None', '6350'],
#  ['0.7', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '74951'],
#  ['6', 'TRUE', 'TRUE', 'FALSE', 'Keras', '51312'],
#  ['0.36', 'FALSE', 'TRUE', 'FALSE', 'None', '666'],
#  ['5.1', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '293904'],
#  ['4.8', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '106322'],
#  ['0.43', 'FALSE', 'FALSE', 'FALSE', 'None', '60814'],
#  ['0.39', 'TRUE', 'FALSE', 'FALSE', 'None', '70572'],
#  ['0.88', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '68837'],
#  ['0.55', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '62093'],
#  ['0.62', 'TRUE', 'FALSE', 'TRUE', 'None', '54114'],
#  ['2.8', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '979'],
#  ['0.96', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '2235'],
#  ['1.4', 'TRUE', 'FALSE', 'FALSE', 'Keras', '3303'],
#  ['25.8', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '71650'],
#  ['1.5', 'TRUE', 'FALSE', 'FALSE', 'None', '5145'],
#  ['0.98', 'TRUE', 'FALSE', 'FALSE', 'None', '56213'],
#  ['3.3', 'FALSE', 'FALSE', 'FALSE', 'None', '57850'],
#  ['2.1', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '62878'],
#  ['4.6', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '53195'],
#  ['9.6', 'FALSE', 'FALSE', 'TRUE', 'TensorFlow', '2312'],
#  ['1.3', 'FALSE', 'TRUE', 'TRUE', 'None', '163016'],
#  ['0.26', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '80274'],
#  ['9.6', 'TRUE', 'TRUE', 'FALSE', 'None', '34215'],
#  ['2.3', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '68870'],
#  ['1.7', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '245'],
#  ['11.1', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '92681'],
#  ['3.3', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '72998'],
#  ['0.84', 'TRUE', 'FALSE', 'FALSE', 'None', '61803'],
#  ['3.7', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '269443'],
#  ['1.5', 'TRUE', 'FALSE', 'TRUE', 'None', '58537'],
#  ['1.9', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '160989'],
#  ['2.9', 'TRUE', 'FALSE', 'TRUE', 'Keras', '21386'],
#  ['25.3', 'TRUE', 'FALSE', 'FALSE', 'Keras', '262267'],
#  ['11', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '40701'],
#  ['14.5', 'FALSE', 'FALSE', 'FALSE', 'PyTorch', '14184'],
#  ['0.91', 'TRUE', 'FALSE', 'FALSE', 'Keras', '51286'],
#  ['0.31', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '27246'],
#  ['2.1', 'TRUE', 'FALSE', 'TRUE', 'None', '894'],
#  ['2.6', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '55032'],
#  ['18.2', 'FALSE', 'FALSE', 'FALSE', 'PyTorch', '293074'],
#  ['1.2', 'TRUE', 'TRUE', 'FALSE', 'None', '62407'],
#  ['1.3', 'FALSE', 'FALSE', 'TRUE', 'Scikit-learn', '57986'],
#  ['27.7', 'TRUE', 'FALSE', 'TRUE', 'Keras', '197702'],
#  ['0.35', 'TRUE', 'FALSE', 'FALSE', 'None', '58495'],
#  ['2.6', 'FALSE', 'TRUE', 'TRUE', 'TensorFlow', '60397'],
#  ['0.43', 'TRUE', 'FALSE', 'TRUE', 'None', '51395'],
#  ['1.8', 'TRUE', 'FALSE', 'FALSE', 'None', '87556'],
#  ['3.7', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '4853'],
#  ['0.92', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '4795'],
#  ['7.7', 'TRUE', 'FALSE', 'TRUE', 'Keras', '10487'],
#  ['5.9', 'TRUE', 'TRUE', 'FALSE', 'Keras', '49634'],
#  ['4.4', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '85067'],
#  ['2.1', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '60649'],
#  ['4.5', 'FALSE', 'FALSE', 'FALSE', 'None', '29055'],
#  ['0.28', 'FALSE', 'TRUE', 'FALSE', 'None', '402'],
#  ['2.6', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '12966'],
#  ['0.82', 'TRUE', 'TRUE', 'TRUE', 'None', '55051'],
#  ['4.8', 'TRUE', 'FALSE', 'FALSE', 'None', '55936'],
#  ['0.53', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '72312'],
#  ['0.44', 'FALSE', 'TRUE', 'FALSE', 'None', '55815'],
#  ['19.8', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '85996'],
#  ['15.5', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '73483'],
#  ['0.95', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '57116'],
#  ['2.2', 'TRUE', 'FALSE', 'TRUE', 'Keras', '71248'],
#  ['0.51', 'TRUE', 'FALSE', 'FALSE', 'None', '2620'],
#  ['2.9', 'FALSE', 'FALSE', 'FALSE', 'None', '72617'],
#  ['2.7', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '5838'],
#  ['2.7', 'TRUE', 'FALSE', 'TRUE', 'None', '51572'],
#  ['1.9', 'TRUE', 'TRUE', 'FALSE', 'None', '70132'],
#  ['2.7', 'FALSE', 'TRUE', 'FALSE', 'None', '53668'],
#  ['0.33', 'FALSE', 'FALSE', 'FALSE', 'None', '59530'],
#  ['0.62', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '253920'],
#  ['1.9', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '549'],
#  ['0.32', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '755'],
#  ['3.3', 'TRUE', 'FALSE', 'FALSE', 'Keras', '38078'],
#  ['0.54', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '525'],
#  ['0.73', 'TRUE', 'FALSE', 'FALSE', 'None', '47261'],
#  ['0', 'FALSE', 'FALSE', 'FALSE', 'None', '24554'],
#  ['5.5', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '22085'],
#  ['1.2', 'TRUE', 'FALSE', 'FALSE', 'Keras', '17937'],
#  ['3.9', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '72360'],
#  ['15.1', 'TRUE', 'FALSE', 'TRUE', 'Keras', '18607'],
#  ['2.9', 'TRUE', 'FALSE', 'FALSE', 'Keras', '57700'],
#  ['0.83', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '1524'],
#  ['7.6', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '18712'],
#  ['1.4', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '53965'],
#  ['3.1', 'TRUE', 'FALSE', 'FALSE', 'None', '73004'],
#  ['1.5', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '50276'],
#  ['4.2', 'TRUE', 'FALSE', 'FALSE', 'None', '54145'],
#  ['0.34', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '322'],
#  ['0.82', 'TRUE', 'FALSE', 'TRUE', 'None', '574'],
#  ['16.5', 'FALSE', 'FALSE', 'FALSE', 'None', '12801'],
#  ['2.4', 'TRUE', 'FALSE', 'TRUE', 'Keras', '71045'],
#  ['0.66', 'TRUE', 'FALSE', 'FALSE', 'None', '69120'],
#  ['8', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '82527'],
#  ['6.6', 'TRUE', 'TRUE', 'TRUE', 'PyTorch', '60748'],
#  ['1', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '490'],
#  ['4', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '72533'],
#  ['5.5', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '4320'],
#  ['7.8', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '57114'],
#  ['2.2', 'TRUE', 'FALSE', 'FALSE', 'None', '250'],
#  ['1.3', 'TRUE', 'FALSE', 'FALSE', 'None', '54947'],
#  ['1.9', 'TRUE', 'TRUE', 'TRUE', 'None', '56963'],
#  ['1.3', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '8316'],
#  ['2.2', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '63330'],
#  ['0.94', 'FALSE', 'FALSE', 'FALSE', 'None', '67994'],
#  ['27.8', 'FALSE', 'TRUE', 'TRUE', 'None', '61608'],
#  ['1.6', 'TRUE', 'FALSE', 'TRUE', 'None', '60833'],
#  ['1.9', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '55193'],
#  ['3.9', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '1788'],
#  ['0.62', 'FALSE', 'FALSE', 'TRUE', 'Keras', '51397'],
#  ['9.5', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '80248'],
#  ['2.4', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '54401'],
#  ['3.7', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '72472'],
#  ['6.6', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '67690'],
#  ['0.94', 'FALSE', 'FALSE', 'FALSE', 'None', '52835'],
#  ['4.8', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '70275'],
#  ['2.9', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '1833'],
#  ['0.25', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '51048'],
#  ['0.56', 'FALSE', 'FALSE', 'FALSE', 'None', '12130'],
#  ['16.8', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '4441'],
#  ['3.4', 'TRUE', 'FALSE', 'TRUE', 'Keras', '660'],
#  ['3.3', 'FALSE', 'FALSE', 'FALSE', 'TensorFlow', '4356'],
#  ['0.98', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '48658'],
#  ['2.6', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '67022'],
#  ['2.7', 'TRUE', 'FALSE', 'FALSE', 'None', '55014'],
#  ['13.3', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '79549'],
#  ['17.3', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '61440'],
#  ['0.31', 'FALSE', 'FALSE', 'TRUE', 'None', '74808'],
#  ['1.7', 'TRUE', 'TRUE', 'FALSE', 'None', '69191'],
#  ['1.1', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '5414'],
#  ['2.5', 'TRUE', 'FALSE', 'FALSE', 'Keras', '8027'],
#  ['2.4', 'FALSE', 'TRUE', 'FALSE', 'None', '304'],
#  ['1.6', 'TRUE', 'FALSE', 'FALSE', 'Keras', '68620'],
#  ['2.3', 'FALSE', 'FALSE', 'FALSE', 'None', '68705'],
#  ['0.69', 'FALSE', 'FALSE', 'FALSE', 'None', '3266'],
#  ['1.9', 'FALSE', 'TRUE', 'FALSE', 'None', '56404'],
#  ['4.7', 'TRUE', 'FALSE', 'FALSE', 'Keras', '72267'],
#  ['6.9', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '15598'],
#  ['1.8', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '756'],
#  ['4.4', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '3064'],
#  ['0.44', 'TRUE', 'FALSE', 'FALSE', 'None', '53474'],
#  ['2.4', 'TRUE', 'FALSE', 'TRUE', 'None', '3446'],
#  ['0.64', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '50527'],
#  ['2.9', 'TRUE', 'TRUE', 'FALSE', 'None', '54821'],
#  ['26.6', 'TRUE', 'FALSE', 'TRUE', 'Keras', '154850'],
#  ['3.5', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '65435'],
#  ['0.5', 'TRUE', 'FALSE', 'FALSE', 'None', '73399'],
#  ['1.2', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '64946'],
#  ['1.5', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '18800'],
#  ['0.92', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '56757'],
#  ['4', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '2592'],
#  ['0.47', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '16612'],
#  ['4.7', 'TRUE', 'FALSE', 'FALSE', 'None', '19143'],
#  ['6.5', 'TRUE', 'FALSE', 'FALSE', 'Keras', '59359'],
#  ['0.5', 'FALSE', 'TRUE', 'FALSE', 'None', '120711'],
#  ['4.7', 'TRUE', 'TRUE', 'TRUE', 'PyTorch', '52082'],
#  ['0.75', 'TRUE', 'FALSE', 'TRUE', 'None', '67918'],
#  ['0.28', 'TRUE', 'TRUE', 'FALSE', 'None', '59017'],
#  ['2.8', 'FALSE', 'FALSE', 'TRUE', 'None', '864'],
#  ['2.1', 'FALSE', 'FALSE', 'TRUE', 'None', '664'],
#  ['7.3', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '19284'],
#  ['16.1', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '217677'],
#  ['0', 'FALSE', 'FALSE', 'FALSE', 'None', '475180'],
#  ['0', 'FALSE', 'FALSE', 'FALSE', 'None', '10746'],
#  ['4.8', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '56503'],
#  ['9.8', 'FALSE', 'FALSE', 'TRUE', 'Scikit-learn', '8359'],
#  ['1.7', 'TRUE', 'TRUE', 'TRUE', 'Keras', '378'],
#  ['23.9', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '70460'],
#  ['0.92', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '21123'],
#  ['0.7', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '62'],
#  ['0.68', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '11020'],
#  ['11.3', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '12529'],
#  ['23.9', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '1325993'],
#  ['3', 'TRUE', 'TRUE', 'FALSE', 'None', '64688'],
#  ['0.62', 'FALSE', 'FALSE', 'FALSE', 'Keras', '71694'],
#  ['4.5', 'FALSE', 'TRUE', 'FALSE', 'None', '62257'],
#  ['27.4', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '66467'],
#  ['0', 'FALSE', 'FALSE', 'FALSE', 'None', '57612'],
#  ['3.9', 'TRUE', 'TRUE', 'FALSE', 'TensorFlow', '17739'],
#  ['3.8', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '103218'],
#  ['2.4', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '1507'],
#  ['1.1', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '7254'],
#  ['8.5', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '54862'],
#  ['5.4', 'TRUE', 'FALSE', 'TRUE', 'Keras', '27111'],
#  ['10.8', 'TRUE', 'TRUE', 'FALSE', 'Keras', '20031'],
#  ['1.6', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '41563'],
#  ['1.7', 'TRUE', 'FALSE', 'FALSE', 'None', '67010'],
#  ['4.7', 'TRUE', 'FALSE', 'TRUE', 'Keras', '5784'],
#  ['16.8', 'FALSE', 'FALSE', 'FALSE', 'None', '72308'],
#  ['3.3', 'TRUE', 'TRUE', 'TRUE', 'None', '22030'],
#  ['3.3', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '67377'],
#  ['0.29', 'TRUE', 'FALSE', 'FALSE', 'Keras', '796'],
#  ['10.1', 'TRUE', 'FALSE', 'TRUE', 'None', '69368'],
#  ['1.1', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '72472'],
#  ['0.67', 'TRUE', 'FALSE', 'FALSE', 'None', '63048'],
#  ['0.21', 'FALSE', 'FALSE', 'TRUE', 'None', '9892'],
#  ['0.96', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '56203'],
#  ['22.9', 'TRUE', 'FALSE', 'FALSE', 'Keras', '48552'],
#  ['3.5', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '72018'],
#  ['0.56', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '13'],
#  ['0.64', 'TRUE', 'FALSE', 'FALSE', 'None', '60665'],
#  ['4.9', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '70969'],
#  ['3.7', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '37353'],
#  ['7.7', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '13483'],
#  ['2.6', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '73574'],
#  ['0.44', 'FALSE', 'FALSE', 'FALSE', 'None', '53506'],
#  ['3.9', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '26289'],
#  ['15.1', 'TRUE', 'FALSE', 'TRUE', 'None', '43464'],
#  ['4.2', 'TRUE', 'FALSE', 'TRUE', 'None', '5122'],
#  ['3.8', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '5330'],
#  ['3.7', 'TRUE', 'TRUE', 'TRUE', 'None', '8372'],
#  ['0.67', 'TRUE', 'FALSE', 'TRUE', 'None', '63035'],
#  ['10.9', 'TRUE', 'TRUE', 'FALSE', 'None', '287624'],
#  ['1.8', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '66297'],
#  ['2.7', 'TRUE', 'FALSE', 'FALSE', 'None', '74909'],
#  ['2.7', 'TRUE', 'TRUE', 'FALSE', 'None', '68897'],
#  ['1.1', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '55103'],
#  ['3.9', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '65436'],
#  ['12.2', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '83337'],
#  ['29.2', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '220415'],
#  ['0.31', 'FALSE', 'FALSE', 'FALSE', 'None', '68892'],
#  ['5.6', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '113998'],
#  ['0.76', 'TRUE', 'FALSE', 'FALSE', 'None', '61718'],
#  ['4.8', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '621'],
#  ['22.8', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '2830'],
#  ['22.1', 'FALSE', 'FALSE', 'TRUE', 'None', '174280'],
#  ['9.8', 'TRUE', 'FALSE', 'FALSE', 'Keras', '62136'],
#  ['27.1', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '80095'],
#  ['14.3', 'TRUE', 'FALSE', 'TRUE', 'None', '88209'],
#  ['3.5', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '64470'],
#  ['6.9', 'TRUE', 'FALSE', 'TRUE', 'Keras', '102277'],
#  ['1.6', 'FALSE', 'TRUE', 'FALSE', 'None', '53512'],
#  ['1.5', 'TRUE', 'FALSE', 'TRUE', 'None', '71858'],
#  ['0.95', 'TRUE', 'FALSE', 'TRUE', 'Keras', '1481'],
#  ['8.7', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '70758'],
#  ['2.4', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '508'],
#  ['17', 'FALSE', 'TRUE', 'FALSE', 'None', '17559'],
#  ['0.93', 'TRUE', 'FALSE', 'TRUE', 'None', '10373'],
#  ['3.8', 'TRUE', 'FALSE', 'FALSE', 'Keras', '57164'],
#  ['2.5', 'TRUE', 'TRUE', 'TRUE', 'PyTorch', '7724'],
#  ['7.1', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '54590'],
#  ['29.3', 'FALSE', 'TRUE', 'FALSE', 'None', '74891'],
#  ['4.1', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '325'],
#  ['0.65', 'TRUE', 'FALSE', 'FALSE', 'Keras', '554'],
#  ['2.8', 'FALSE', 'TRUE', 'TRUE', 'None', '39643'],
#  ['4.9', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '71105'],
#  ['3.6', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '5051'],
#  ['8.5', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '11048'],
#  ['0.41', 'TRUE', 'FALSE', 'TRUE', 'None', '74783'],
#  ['19.9', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '21353'],
#  ['4.2', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '682'],
#  ['26.5', 'TRUE', 'TRUE', 'TRUE', 'Keras', '429315'],
#  ['2.6', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '65441'],
#  ['5.4', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '72536'],
#  ['5.1', 'FALSE', 'TRUE', 'TRUE', 'None', '119762'],
#  ['23.1', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '195277'],
#  ['0.5', 'FALSE', 'FALSE', 'FALSE', 'None', '69484'],
#  ['7.7', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '185336'],
#  ['6.8', 'TRUE', 'FALSE', 'FALSE', 'Keras', '69491'],
#  ['27.8', 'FALSE', 'TRUE', 'FALSE', 'Keras', '714555'],
#  ['3.9', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '72595'],
#  ['16.5', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '872'],
#  ['3.4', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '141'],
#  ['20.3', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '268989'],
#  ['1.1', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '4006'],
#  ['19.5', 'TRUE', 'FALSE', 'TRUE', 'Keras', '9336'],
#  ['2', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '3085'],
#  ['6', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '62835'],
#  ['2.6', 'TRUE', 'TRUE', 'TRUE', 'Keras', '27020'],
#  ['2.3', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '76'],
#  ['0.6', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '38476'],
#  ['1', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '70504'],
#  ['1.1', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '6973'],
#  ['2.7', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '544'],
#  ['3.9', 'TRUE', 'FALSE', 'FALSE', 'None', '58032'],
#  ['0.43', 'TRUE', 'FALSE', 'TRUE', 'None', '325'],
#  ['15.1', 'TRUE', 'FALSE', 'FALSE', 'None', '74528'],
#  ['0.58', 'FALSE', 'TRUE', 'TRUE', 'None', '119'],
#  ['29.7', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '20426'],
#  ['6.1', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '41107'],
#  ['1.1', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '11114'],
#  ['4.2', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '31534'],
#  ['1.7', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '9606'],
#  ['2.5', 'TRUE', 'FALSE', 'TRUE', 'None', '62179'],
#  ['1.3', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '58568'],
#  ['4.7', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '9603'],
#  ['3.9', 'FALSE', 'FALSE', 'FALSE', 'None', '9078'],
#  ['1.6', 'TRUE', 'TRUE', 'FALSE', 'TensorFlow', '943'],
#  ['4.1', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '52653'],
#  ['0.3', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '221'],
#  ['3.6', 'TRUE', 'FALSE', 'FALSE', 'None', '53034'],
#  ['4.6', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '11002'],
#  ['2.1', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '53292'],
#  ['1.2', 'FALSE', 'FALSE', 'TRUE', 'Scikit-learn', '456'],
#  ['0.32', 'TRUE', 'FALSE', 'TRUE', 'None', '71624'],
#  ['1.1', 'TRUE', 'FALSE', 'TRUE', 'None', '73324'],
#  ['14.8', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '91644'],
#  ['1.9', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '11855'],
#  ['9', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '23530'],
#  ['2.1', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '12407'],
#  ['2.3', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '67512'],
#  ['3.9', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '968'],
#  ['0.47', 'FALSE', 'FALSE', 'FALSE', 'None', '69126'],
#  ['0.52', 'TRUE', 'FALSE', 'FALSE', 'Keras', '56472'],
#  ['0.74', 'TRUE', 'FALSE', 'FALSE', 'None', '63077'],
#  ['4.9', 'TRUE', 'TRUE', 'TRUE', 'TensorFlow', '52625'],
#  ['2.4', 'TRUE', 'FALSE', 'FALSE', 'Keras', '68695'],
#  ['1.4', 'TRUE', 'TRUE', 'TRUE', 'Keras', '6528'],
#  ['2.3', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '64466'],
#  ['2', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '57584'],
#  ['21.5', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '63587'],
#  ['1.5', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '64878'],
#  ['6.3', 'TRUE', 'FALSE', 'TRUE', 'Keras', '2220'],
#  ['4.5', 'TRUE', 'FALSE', 'FALSE', 'Keras', '65180'],
#  ['0.98', 'TRUE', 'FALSE', 'FALSE', 'None', '60218'],
#  ['2.2', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '4645'],
#  ['2.4', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '68252'],
#  ['0.86', 'TRUE', 'FALSE', 'TRUE', 'None', '70314'],
#  ['0.39', 'TRUE', 'FALSE', 'TRUE', 'None', '766'],
#  ['26.6', 'TRUE', 'TRUE', 'FALSE', 'TensorFlow', '2030'],
#  ['1.3', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '54022'],
#  ['0.3', 'TRUE', 'TRUE', 'FALSE', 'None', '53318'],
#  ['3.1', 'TRUE', 'FALSE', 'FALSE', 'None', '56645'],
#  ['4.7', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '52326'],
#  ['16.3', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '97'],
#  ['0', 'FALSE', 'FALSE', 'FALSE', 'None', '11425'],
#  ['5.2', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '36288'],
#  ['2.5', 'TRUE', 'FALSE', 'FALSE', 'Keras', '484'],
#  ['4.2', 'TRUE', 'FALSE', 'TRUE', 'Keras', '4893'],
#  ['29.1', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '104484'],
#  ['2.5', 'TRUE', 'FALSE', 'FALSE', 'None', '56945'],
#  ['1.1', 'TRUE', 'FALSE', 'FALSE', 'None', '52839'],
#  ['1.9', 'TRUE', 'FALSE', 'FALSE', 'None', '58164'],
#  ['4.2', 'TRUE', 'FALSE', 'TRUE', 'Keras', '14807'],
#  ['1.2', 'TRUE', 'FALSE', 'FALSE', 'None', '2789'],
#  ['1.7', 'TRUE', 'TRUE', 'FALSE', 'None', '73427'],
#  ['0.47', 'TRUE', 'FALSE', 'FALSE', 'None', '58350'],
#  ['0.84', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '16755'],
#  ['4.1', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '953'],
#  ['0.6', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '65157'],
#  ['0.48', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '67006'],
#  ['1.6', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '753'],
#  ['2', 'TRUE', 'FALSE', 'FALSE', 'Keras', '59231'],
#  ['6.2', 'TRUE', 'TRUE', 'FALSE', 'None', '69020'],
#  ['2.7', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '495'],
#  ['1.1', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '42047'],
#  ['0.9', 'TRUE', 'FALSE', 'FALSE', 'None', '64311'],
#  ['0.25', 'TRUE', 'FALSE', 'TRUE', 'None', '4314'],
#  ['0', 'FALSE', 'FALSE', 'FALSE', 'None', '623'],
#  ['3.4', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '472'],
#  ['1', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '2724'],
#  ['0.56', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '594'],
#  ['4.3', 'TRUE', 'FALSE', 'TRUE', 'Keras', '10808'],
#  ['10.6', 'TRUE', 'FALSE', 'FALSE', 'Keras', '69254'],
#  ['4.8', 'TRUE', 'FALSE', 'FALSE', 'Keras', '340'],
#  ['22.8', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '39388'],
#  ['4.9', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '837'],
#  ['2.1', 'TRUE', 'FALSE', 'FALSE', 'None', '65343'],
#  ['0.62', 'FALSE', 'FALSE', 'FALSE', 'Scikit-learn', '65800'],
#  ['0.41', 'TRUE', 'FALSE', 'FALSE', 'Keras', '639'],
#  ['3.7', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '378'],
#  ['9.7', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '248'],
#  ['10.6', 'TRUE', 'FALSE', 'TRUE', 'None', '84270'],
#  ['0.58', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '88125'],
#  ['1.1', 'TRUE', 'FALSE', 'FALSE', 'None', '47405'],
#  ['9.8', 'TRUE', 'FALSE', 'FALSE', 'None', '55049'],
#  ['2.9', 'TRUE', 'TRUE', 'FALSE', 'None', '61031'],
#  ['0', 'FALSE', 'FALSE', 'FALSE', 'None', '1869'],
#  ['21.7', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '4317'],
#  ['0.99', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '64635'],
#  ['0.33', 'FALSE', 'FALSE', 'FALSE', 'None', '51402'],
#  ['1.3', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '21777'],
#  ['3', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '50854'],
#  ['2.1', 'TRUE', 'FALSE', 'FALSE', 'None', '181181'],
#  ['0.72', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '56455'],
#  ['0.4', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '55947'],
#  ['8.7', 'FALSE', 'FALSE', 'TRUE', 'PyTorch', '1516'],
#  ['7.7', 'TRUE', 'TRUE', 'FALSE', 'PyTorch', '74963'],
#  ['20.7', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '283'],
#  ['4.6', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '24310'],
#  ['8.7', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '46410'],
#  ['0.94', 'TRUE', 'TRUE', 'TRUE', 'TensorFlow', '1773'],
#  ['0.84', 'TRUE', 'FALSE', 'FALSE', 'None', '63503'],
#  ['4.7', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '8517'],
#  ['2.7', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '677'],
#  ['2.3', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '95980'],
#  ['2.7', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '61704'],
#  ['2.7', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '2096'],
#  ['0.26', 'TRUE', 'FALSE', 'FALSE', 'None', '3332'],
#  ['21', 'TRUE', 'TRUE', 'TRUE', 'None', '74876'],
#  ['2.7', 'FALSE', 'FALSE', 'FALSE', 'None', '53241'],
#  ['3.3', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '65015'],
#  ['4.5', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '69794'],
#  ['1.1', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '1688'],
#  ['3.9', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '69211'],
#  ['0.82', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '66810'],
#  ['1.8', 'TRUE', 'FALSE', 'FALSE', 'None', '70512'],
#  ['4.4', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '70396'],
#  ['1.7', 'FALSE', 'FALSE', 'FALSE', 'TensorFlow', '54649'],
#  ['1', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '163626'],
#  ['26.7', 'TRUE', 'FALSE', 'TRUE', 'None', '20134'],
#  ['0.63', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '50557'],
#  ['11.3', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '67548'],
#  ['1.2', 'TRUE', 'FALSE', 'FALSE', 'None', '835'],
#  ['2.1', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '74524'],
#  ['0.68', 'FALSE', 'TRUE', 'FALSE', 'None', '55162'],
#  ['0.99', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '66597'],
#  ['2.4', 'TRUE', 'TRUE', 'TRUE', 'None', '73110'],
#  ['1.3', 'FALSE', 'FALSE', 'FALSE', 'None', '63709'],
#  ['3.4', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '181429'],
#  ['2.5', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '22534'],
#  ['2.7', 'TRUE', 'FALSE', 'FALSE', 'Keras', '67768'],
#  ['13.7', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '63167'],
#  ['0.74', 'TRUE', 'FALSE', 'TRUE', 'Keras', '211'],
#  ['2.9', 'TRUE', 'FALSE', 'FALSE', 'None', '68852'],
#  ['3.4', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '63195'],
#  ['24.8', 'TRUE', 'TRUE', 'FALSE', 'None', '51234'],
#  ['1.7', 'TRUE', 'FALSE', 'FALSE', 'Keras', '954'],
#  ['12.4', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '94385'],
#  ['2.7', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '67835'],
#  ['6.4', 'TRUE', 'TRUE', 'FALSE', 'PyTorch', '256979'],
#  ['0.41', 'TRUE', 'FALSE', 'FALSE', 'Keras', '67498'],
#  ['15.9', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '10541'],
#  ['4.9', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '2743'],
#  ['2.1', 'TRUE', 'FALSE', 'FALSE', 'Keras', '2000'],
#  ['0.91', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '52961'],
#  ['0.42', 'TRUE', 'TRUE', 'FALSE', 'PyTorch', '542'],
#  ['1.1', 'TRUE', 'FALSE', 'FALSE', 'Keras', '68699'],
#  ['4', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '270'],
#  ['0.99', 'TRUE', 'FALSE', 'TRUE', 'None', '73596'],
#  ['0.6', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '791'],
#  ['0.75', 'TRUE', 'FALSE', 'FALSE', 'None', '65499'],
#  ['1', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '9095'],
#  ['2.8', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '56712'],
#  ['0.88', 'TRUE', 'FALSE', 'FALSE', 'None', '64964'],
#  ['1.7', 'TRUE', 'TRUE', 'TRUE', 'TensorFlow', '304'],
#  ['2.6', 'TRUE', 'FALSE', 'FALSE', 'Keras', '27862'],
#  ['4.5', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '56429'],
#  ['29.5', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '56617'],
#  ['4.8', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '4377'],
#  ['0.68', 'TRUE', 'FALSE', 'FALSE', 'None', '66917'],
#  ['3.4', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '40909'],
#  ['11.9', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '30501'],
#  ['28', 'FALSE', 'FALSE', 'FALSE', 'None', '95918'],
#  ['0.46', 'TRUE', 'FALSE', 'FALSE', 'None', '52440'],
#  ['0.47', 'TRUE', 'FALSE', 'FALSE', 'None', '51'],
#  ['7.9', 'TRUE', 'FALSE', 'TRUE', 'Keras', '17570'],
#  ['2.3', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '26060'],
#  ['4.6', 'FALSE', 'TRUE', 'TRUE', 'None', '19404'],
#  ['25.6', 'FALSE', 'FALSE', 'TRUE', 'Scikit-learn', '20696'],
#  ['1.2', 'TRUE', 'FALSE', 'FALSE', 'None', '53072'],
#  ['5.9', 'TRUE', 'TRUE', 'TRUE', 'TensorFlow', '207422'],
#  ['0.36', 'TRUE', 'FALSE', 'TRUE', 'None', '54171'],
#  ['2.4', 'TRUE', 'FALSE', 'FALSE', 'None', '67687'],
#  ['0.74', 'TRUE', 'TRUE', 'TRUE', 'None', '61813'],
#  ['3.1', 'TRUE', 'FALSE', 'TRUE', 'None', '2910'],
#  ['0.98', 'TRUE', 'FALSE', 'FALSE', 'None', '851'],
#  ['1.5', 'TRUE', 'FALSE', 'FALSE', 'None', '552'],
#  ['24.8', 'FALSE', 'FALSE', 'FALSE', 'PyTorch', '64562'],
#  ['2.9', 'TRUE', 'TRUE', 'TRUE', 'None', '70663'],
#  ['5.8', 'TRUE', 'FALSE', 'TRUE', 'None', '474'],
#  ['2.2', 'FALSE', 'FALSE', 'FALSE', 'None', '64573'],
#  ['0.91', 'TRUE', 'FALSE', 'FALSE', 'None', '311'],
#  ['0.25', 'TRUE', 'FALSE', 'TRUE', 'None', '804'],
#  ['7.4', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '14315'],
#  ['3.3', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '44540'],
#  ['1.8', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '26130'],
#  ['27.3', 'FALSE', 'FALSE', 'TRUE', 'None', '66962'],
#  ['3.8', 'TRUE', 'TRUE', 'TRUE', 'Scikit-learn', '114075'],
#  ['0.48', 'TRUE', 'FALSE', 'FALSE', 'Keras', '285'],
#  ['2.2', 'TRUE', 'FALSE', 'TRUE', 'None', '52671'],
#  ['3.4', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '88205'],
#  ['0.71', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '31158'],
#  ['1.2', 'TRUE', 'FALSE', 'FALSE', 'TensorFlow', '750'],
#  ['2.1', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '64017'],
#  ['12.5', 'FALSE', 'FALSE', 'TRUE', 'None', '71237'],
#  ['7', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '23040'],
#  ['9.1', 'TRUE', 'FALSE', 'TRUE', 'Keras', '30859'],
#  ['4.5', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '20431'],
#  ['1.1', 'TRUE', 'TRUE', 'TRUE', 'TensorFlow', '16710'],
#  ['19.9', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '12953'],
#  ['2.4', 'TRUE', 'FALSE', 'TRUE', 'Keras', '58403'],
#  ['25.9', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '237978'],
#  ['2', 'TRUE', 'FALSE', 'TRUE', 'TensorFlow', '19659'],
#  ['3.4', 'FALSE', 'FALSE', 'TRUE', 'None', '2090'],
#  ['3.8', 'TRUE', 'TRUE', 'TRUE', 'TensorFlow', '44685'],
#  ['0', 'FALSE', 'FALSE', 'FALSE', 'None', '729'],
#  ['7.3', 'TRUE', 'FALSE', 'FALSE', 'PyTorch', '674'],
#  ['0.44', 'TRUE', 'FALSE', 'FALSE', 'None', '24801'],
#  ['0.66', 'TRUE', 'FALSE', 'TRUE', 'None', '59184'],
#  ['1.9', 'TRUE', 'FALSE', 'TRUE', 'PyTorch', '522'],
#  ['9.3', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '75691'],
#  ['1.4', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '12092'],
#  ['0.34', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '240163'],
#  ['0.47', 'TRUE', 'FALSE', 'FALSE', 'None', '993'],
#  ['9.1', 'TRUE', 'FALSE', 'TRUE', 'Keras', '51442'],
#  ['3.3', 'TRUE', 'TRUE', 'TRUE', 'PyTorch', '109344'],
#  ['3.5', 'TRUE', 'FALSE', 'TRUE', 'Keras', '922'],
#  ['0.93', 'FALSE', 'TRUE', 'FALSE', 'None', '68036'],
#  ['1.7', 'FALSE', 'FALSE', 'TRUE', 'Scikit-learn', '16529'],
#  ['2.8', 'TRUE', 'FALSE', 'FALSE', 'None', '53990'],
#  ['1.2', 'TRUE', 'FALSE', 'FALSE', 'None', '52974'],
#  ['2.2', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '66042'],
#  ['21.9', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '50591'],
#  ['13.6', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '72511'],
#  ['2.9', 'TRUE', 'FALSE', 'FALSE', 'Scikit-learn', '57331'],
#  ['8.4', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '33733'],
#  ['0.69', 'TRUE', 'TRUE', 'FALSE', 'Scikit-learn', '57104'],
#  ['4.7', 'TRUE', 'FALSE', 'FALSE', 'Keras', '83630'],
#  ['0.54', 'TRUE', 'FALSE', 'TRUE', 'None', '55929'],
#  ['0.22', 'TRUE', 'FALSE', 'FALSE', 'None', '68255'],
#  ['3.2', 'TRUE', 'FALSE', 'TRUE', 'None', '235'],
#  ['4.6', 'TRUE', 'TRUE', 'FALSE', 'Keras', '69649'],
#  ['4.9', 'TRUE', 'FALSE', 'FALSE', 'None', '71502'],
#  ...]

# %%
survey[0]
# Out:
# ['6.1', 'TRUE', 'FALSE', 'TRUE', 'Scikit-learn', '124267']

# %%
type(None)
# Out:
# NoneType

# %%
for col in survey:
    first_element = col[0]
    # print(first_element)

    second_element = col[1]
    # print(second_element)

    third_element = col[2]
    fourth_element = col[3]
    fifth_element = col[4]

    # print(fifth_element)

    sixth_element = col[5]

    col[0]= float(first_element)
    # print(type(col[0]))

    if second_element == "TRUE":
        col[1] = True
    else:
        col[1] = False

    if third_element == "TRUE":
        col[2] = True
    else:
        col[2] = False

    if fourth_element == "TRUE":
        col[3] = True
    else:
        col[3] = False

    if fifth_element == "None":
        col[4] = None
    else:
          col[4] = col[4]
          continue
    col[5]= float(col[5])
    # print(type(col[5]))

# %%
print(survey[:3])
# Out:
# [[6.1, True, False, True, 'Scikit-learn', '124267'], [12.3, True, True, True, 'Scikit-learn', '236889'], [2.2, True, False, False, None, 74321.0]]

# %%
list1 = [1,2,3]
list1
# Out:
# [1, 2, 3]

# %%
sum(list1)
# Out:
# 6

# %%
for i in survey:
    print(i[5])
# Out:
# 124267
# 236889
# 74321.0
# 62593.0
# 36288
# 61302
# 68984.0
# 18858
# 55418
# 614
# 70564.0
# 55525
# 61005.0
# 2846
# 21
# 14699
# 2110
# 620
# 73527
# 6992.0
# 22311.0
# 1377
# 69174.0
# 117636
# 65937
# 27856
# 903
# 50501
# 482
# 70407.0
# 8690.0
# 114648.0
# 73454.0
# 8075.0
# 59151.0
# 70112.0
# 70183.0
# 64502.0
# 2521.0
# 63616
# 59849
# 31516.0
# 18582
# 4187
# 64405.0
# 114807
# 632
# 61157
# 1194
# 28955
# 56553
# 75177.0
# 28009.0
# 67074
# 50059.0
# 7624
# 74321.0
# 671.0
# 837
# 2011
# 62937
# 685.0
# 41615
# 52572.0
# 51856
# 411
# 152.0
# 8181
# 2708
# 55041
# 68412
# 6141
# 3979.0
# 3760
# 57465
# 3864
# 488487.0
# 24393
# 68624
# 70796.0
# 236889
# 57861
# 21055.0
# 59167
# 55882.0
# 73802.0
# 21206
# 79803
# 73043.0
# 268191
# 14298
# 68805
# 56003
# 73664.0
# 434
# 52109
# 10284
# 43906
# 67971.0
# 58465.0
# 64488.0
# 7709.0
# 1957
# 4131
# 26022
# 29926.0
# 62593.0
# 109543.0
# 107644.0
# 1047.0
# 59909.0
# 68344.0
# 54427
# 70930.0
# 50835.0
# 14151
# 11681.0
# 71808.0
# 70991.0
# 31626
# 52416
# 288146
# 65143
# 34866
# 186
# 60065
# 40336.0
# 115654
# 431.0
# 59814
# 45413
# 4196.0
# 55751.0
# 61912
# 49478.0
# 29139
# 67272
# 70264
# 264
# 14853
# 55482
# 26
# 250.0
# 66025
# 55906.0
# 63754.0
# 86855
# 63242
# 70448.0
# 68964
# 111583
# 52350
# 58574.0
# 330
# 64478.0
# 94273
# 62142
# 5857
# 194518
# 60873.0
# 55584.0
# 949
# 27748.0
# 239.0
# 120047.0
# 332.0
# 51428
# 256063
# 50783
# 109423
# 85525
# 226
# 13056
# 8015
# 450
# 67947
# 1161
# 51347
# 60385.0
# 77828
# 2171
# 52319.0
# 57822.0
# 3270.0
# 65136.0
# 69438.0
# 40207
# 2028
# 6202
# 7710.0
# 70193
# 65437.0
# 50063
# 68660
# 239
# 66331
# 2638
# 948
# 14940.0
# 55702
# 64258.0
# 78011.0
# 54275
# 14296
# 34960
# 73344
# 52677.0
# 45872
# 73335
# 22820.0
# 86447
# 65474
# 69215.0
# 71083.0
# 288
# 68685.0
# 667.0
# 1533
# 13668
# 72266
# 69875.0
# 64099.0
# 15531
# 14191.0
# 21341
# 63593
# 6927
# 77444
# 6928
# 3594
# 70633.0
# 1955.0
# 50391.0
# 57925
# 72763.0
# 59786
# 37438
# 1854
# 53438
# 1400
# 2102
# 69422.0
# 64100
# 7531.0
# 69874.0
# 967.0
# 66706.0
# 211674
# 53429
# 3296.0
# 59837.0
# 69047
# 268004.0
# 40997
# 362
# 20153
# 70537
# 7341
# 158084
# 121539
# 67979.0
# 10850
# 71669.0
# 52598
# 65845
# 71478.0
# 62525.0
# 442.0
# 59998.0
# 56633
# 61555
# 9166
# 28345
# 53179
# 57490.0
# 5126.0
# 53908
# 68613
# 102759.0
# 30028
# 12585.0
# 317
# 47331
# 70052.0
# 18689
# 67691
# 67855
# 4550
# 4559.0
# 2942
# 51483.0
# 59181.0
# 5898.0
# 72425
# 82283.0
# 528.0
# 52915
# 151202
# 4003
# 117943
# 74964
# 57388
# 71002
# 492.0
# 58238
# 9870
# 60240
# 59030.0
# 109811.0
# 110080
# 67524.0
# 63940.0
# 64798
# 42609.0
# 737
# 9046
# 52974
# 66485
# 67404.0
# 73197.0
# 62920
# 57329.0
# 180877
# 1276062
# 13151.0
# 55848
# 245371
# 709
# 5114.0
# 65445.0
# 77273.0
# 68401.0
# 13711
# 24614
# 66616
# 70561.0
# 58445
# 90245
# 65868
# 59396.0
# 51571.0
# 23895
# 13588
# 297.0
# 11546
# 56222.0
# 24021
# 69439
# 10858
# 61988.0
# 2099
# 71138
# 74748.0
# 59805
# 206
# 62664
# 67263
# 2152
# 417
# 60620
# 27907
# 90950
# 55703.0
# 54883
# 17757
# 948.0
# 775.0
# 2570
# 51978.0
# 23671.0
# 844
# 534
# 41513
# 65027
# 763
# 483648
# 50180
# 69047
# 3932
# 80090
# 15800
# 62456
# 923.0
# 60609
# 493.0

# %%
for i in survey:
    i[5] = int(i[5])

# %%
print(survey[:3])
# Out:
# [[6.1, True, False, True, 'Scikit-learn', 124267], [12.3, True, True, True, 'Scikit-learn', 236889], [2.2, True, False, False, None, 74321]]

# %%
print(survey[:3])
# Out:
# [[6.1, True, False, True, 'Scikit-learn', 124267], [12.3, True, True, True, 'Scikit-learn', 236889], [2.2, True, False, False, None, 74321]]

# %%
len(survey)
# Out:
# 25973

# %%
python_user = 0
r_user = 0
sql_user = 0


for i in survey:
    python = i[1]
    r = i[2]
    sql = i[3]

    if python:
        python_user += 1

    if r:
        r_user += 1

    if sql:
        sql_user += 1

# %%
print(python_user)
print(r_user)
print(sql_user)
# Out:
# 21860
# %%
print(compensation[:10])
# Out:
# [124267, 236889, 74321, 62593, 36288, 61302, 68984, 18858, 55418, 614]

# %%
print(min(experience))   
print(max(experience))
# Out:
# 0.0
# 30.0

# %%
sum(experience)/len(experience)
# Out:
# 5.297231740653729

# %%
print(min(compensation))
print(max(compensation))
# Out:
# 0
# 1492951

# %%
sum(compensation)/len(experience)  # cal average
# Out:
# 53252.81696377007

# %%
for i in survey:
    if i[0] < 5:
        i.append(" < 5 Years")
    elif 5<= i[0] < 10:            
        i.append("5-10 Years")
    elif 10<= i[0] < 15:
        i.append("10-15 Years")
    elif 15<= i[0] < 20:
        i.append("15-20 Years")
    elif 20<= i[0] < 25:
        i.append("20-25 Years")
    else:
        i.append("25+ Years")

# %%
survey[:10]
# Out:
# [[6.1, True, False, True, 'Scikit-learn', 124267, '5-10 Years'],
#  [12.3, True, True, True, 'Scikit-learn', 236889, '10-15 Years'],
#  [2.2, True, False, False, None, 74321, ' < 5 Years'],
#  [2.7, False, False, True, None, 62593, ' < 5 Years'],
#  [1.2, True, False, False, 'Scikit-learn', 36288, ' < 5 Years'],
#  [1.0, True, False, False, 'PyTorch', 61302, ' < 5 Years'],
#  [1.8, False, False, False, None, 68984, ' < 5 Years'],
#  [6.1, True, False, False, 'TensorFlow', 18858, '5-10 Years'],
#  [4.5, True, False, True, 'Scikit-learn', 55418, ' < 5 Years'],
#  [1.1, True, False, True, 'TensorFlow', 614, ' < 5 Years']]

# %%
survey[500:]
# Out:
# [[0.98, True, False, False, None, 56213, ' < 5 Years'],
#  [3.3, False, False, False, None, 57850, ' < 5 Years'],
#  [2.1, True, False, False, 'Scikit-learn', 62878, ' < 5 Years'],
#  [4.6, True, True, False, 'Scikit-learn', 53195, ' < 5 Years'],
#  [9.6, False, False, True, 'TensorFlow', 2312, '5-10 Years'],
#  [1.3, False, True, True, None, 163016, ' < 5 Years'],
#  [0.26, True, False, False, 'TensorFlow', 80274, ' < 5 Years'],
#  [9.6, True, True, False, None, 34215, '5-10 Years'],
#  [2.3, True, False, False, 'Scikit-learn', 68870, ' < 5 Years'],
#  [1.7, True, False, True, 'TensorFlow', 245, ' < 5 Years'],
#  [11.1, True, False, True, 'Scikit-learn', 92681, '10-15 Years'],
#  [3.3, True, False, False, 'Scikit-learn', 72998, ' < 5 Years'],
#  [0.84, True, False, False, None, 61803, ' < 5 Years'],
#  [3.7, True, False, False, 'Scikit-learn', 269443, ' < 5 Years'],
#  [1.5, True, False, True, None, 58537, ' < 5 Years'],
#  [1.9, True, True, True, 'Scikit-learn', 160989, ' < 5 Years'],
#  [2.9, True, False, True, 'Keras', 21386, ' < 5 Years'],
#  [25.3, True, False, False, 'Keras', 262267, '25+ Years'],
#  [11.0, True, True, False, 'Scikit-learn', 40701, '10-15 Years'],
#  [14.5, False, False, False, 'PyTorch', 14184, '10-15 Years'],
#  [0.91, True, False, False, 'Keras', 51286, ' < 5 Years'],
#  [0.31, True, False, False, 'Scikit-learn', 27246, ' < 5 Years'],
#  [2.1, True, False, True, None, 894, ' < 5 Years'],
#  [2.6, True, False, False, 'PyTorch', 55032, ' < 5 Years'],
#  [18.2, False, False, False, 'PyTorch', 293074, '15-20 Years'],
#  [1.2, True, True, False, None, 62407, ' < 5 Years'],
#  [1.3, False, False, True, 'Scikit-learn', 57986, ' < 5 Years'],
#  [27.7, True, False, True, 'Keras', 197702, '25+ Years'],
#  [0.35, True, False, False, None, 58495, ' < 5 Years'],
#  [2.6, False, True, True, 'TensorFlow', 60397, ' < 5 Years'],
#  [0.43, True, False, True, None, 51395, ' < 5 Years'],
#  [1.8, True, False, False, None, 87556, ' < 5 Years'],
#  [3.7, True, False, False, 'PyTorch', 4853, ' < 5 Years'],
#  [0.92, True, False, True, 'Scikit-learn', 4795, ' < 5 Years'],
#  [7.7, True, False, True, 'Keras', 10487, '5-10 Years'],
#  [5.9, True, True, False, 'Keras', 49634, '5-10 Years'],
#  [4.4, True, True, True, 'Scikit-learn', 85067, ' < 5 Years'],
#  [2.1, True, False, True, 'TensorFlow', 60649, ' < 5 Years'],
#  [4.5, False, False, False, None, 29055, ' < 5 Years'],
#  [0.28, False, True, False, None, 402, ' < 5 Years'],
#  [2.6, True, False, False, 'TensorFlow', 12966, ' < 5 Years'],
#  [0.82, True, True, True, None, 55051, ' < 5 Years'],
#  [4.8, True, False, False, None, 55936, ' < 5 Years'],
#  [0.53, True, False, False, 'TensorFlow', 72312, ' < 5 Years'],
#  [0.44, False, True, False, None, 55815, ' < 5 Years'],
#  [19.8, True, False, False, 'PyTorch', 85996, '15-20 Years'],
#  [15.5, True, False, False, 'Scikit-learn', 73483, '15-20 Years'],
#  [0.95, True, False, False, 'TensorFlow', 57116, ' < 5 Years'],
#  [2.2, True, False, True, 'Keras', 71248, ' < 5 Years'],
#  [0.51, True, False, False, None, 2620, ' < 5 Years'],
#  [2.9, False, False, False, None, 72617, ' < 5 Years'],
#  [2.7, True, False, True, 'Scikit-learn', 5838, ' < 5 Years'],
#  [2.7, True, False, True, None, 51572, ' < 5 Years'],
#  [1.9, True, True, False, None, 70132, ' < 5 Years'],
#  [2.7, False, True, False, None, 53668, ' < 5 Years'],
#  [0.33, False, False, False, None, 59530, ' < 5 Years'],
#  [0.62, True, False, False, 'Scikit-learn', 253920, ' < 5 Years'],
#  [1.9, True, False, False, 'TensorFlow', 549, ' < 5 Years'],
#  [0.32, True, False, True, 'PyTorch', 755, ' < 5 Years'],
#  [3.3, True, False, False, 'Keras', 38078, ' < 5 Years'],
#  [0.54, True, False, False, 'Scikit-learn', 525, ' < 5 Years'],
#  [0.73, True, False, False, None, 47261, ' < 5 Years'],
#  [0.0, False, False, False, None, 24554, ' < 5 Years'],
#  [5.5, True, False, False, 'PyTorch', 22085, '5-10 Years'],
#  [1.2, True, False, False, 'Keras', 17937, ' < 5 Years'],
#  [3.9, True, False, False, 'Scikit-learn', 72360, ' < 5 Years'],
#  [15.1, True, False, True, 'Keras', 18607, '15-20 Years'],
#  [2.9, True, False, False, 'Keras', 57700, ' < 5 Years'],
#  [0.83, True, False, True, 'Scikit-learn', 1524, ' < 5 Years'],
#  [7.6, True, False, False, 'PyTorch', 18712, '5-10 Years'],
#  [1.4, True, False, True, 'PyTorch', 53965, ' < 5 Years'],
#  [3.1, True, False, False, None, 73004, ' < 5 Years'],
#  [1.5, True, False, True, 'TensorFlow', 50276, ' < 5 Years'],
#  [4.2, True, False, False, None, 54145, ' < 5 Years'],
#  [0.34, True, True, False, 'Scikit-learn', 322, ' < 5 Years'],
#  [0.82, True, False, True, None, 574, ' < 5 Years'],
#  [16.5, False, False, False, None, 12801, '15-20 Years'],
#  [2.4, True, False, True, 'Keras', 71045, ' < 5 Years'],
#  [0.66, True, False, False, None, 69120, ' < 5 Years'],
#  [8.0, True, False, True, 'PyTorch', 82527, '5-10 Years'],
#  [6.6, True, True, True, 'PyTorch', 60748, '5-10 Years'],
#  [1.0, True, False, True, 'Scikit-learn', 490, ' < 5 Years'],
#  [4.0, True, False, False, 'Scikit-learn', 72533, ' < 5 Years'],
#  [5.5, True, False, True, 'Scikit-learn', 4320, '5-10 Years'],
#  [7.8, True, False, True, 'Scikit-learn', 57114, '5-10 Years'],
#  [2.2, True, False, False, None, 250, ' < 5 Years'],
#  [1.3, True, False, False, None, 54947, ' < 5 Years'],
#  [1.9, True, True, True, None, 56963, ' < 5 Years'],
#  [1.3, True, False, True, 'Scikit-learn', 8316, ' < 5 Years'],
#  [2.2, True, False, False, 'Scikit-learn', 63330, ' < 5 Years'],
#  [0.94, False, False, False, None, 67994, ' < 5 Years'],
#  [27.8, False, True, True, None, 61608, '25+ Years'],
#  [1.6, True, False, True, None, 60833, ' < 5 Years'],
#  [1.9, True, False, False, 'TensorFlow', 55193, ' < 5 Years'],
#  [3.9, True, False, True, 'TensorFlow', 1788, ' < 5 Years'],
#  [0.62, False, False, True, 'Keras', 51397, ' < 5 Years'],
#  [9.5, True, False, True, 'TensorFlow', 80248, '5-10 Years'],
#  [2.4, True, False, False, 'TensorFlow', 54401, ' < 5 Years'],
#  [3.7, True, False, True, 'Scikit-learn', 72472, ' < 5 Years'],
#  [6.6, True, False, False, 'TensorFlow', 67690, '5-10 Years'],
#  [0.94, False, False, False, None, 52835, ' < 5 Years'],
#  [4.8, True, False, False, 'Scikit-learn', 70275, ' < 5 Years'],
#  [2.9, True, False, False, 'TensorFlow', 1833, ' < 5 Years'],
#  [0.25, True, False, False, 'TensorFlow', 51048, ' < 5 Years'],
#  [0.56, False, False, False, None, 12130, ' < 5 Years'],
#  [16.8, True, False, False, 'TensorFlow', 4441, '15-20 Years'],
#  [3.4, True, False, True, 'Keras', 660, ' < 5 Years'],
#  [3.3, False, False, False, 'TensorFlow', 4356, ' < 5 Years'],
#  [0.98, True, False, True, 'Scikit-learn', 48658, ' < 5 Years'],
#  [2.6, True, False, False, 'Scikit-learn', 67022, ' < 5 Years'],
#  [2.7, True, False, False, None, 55014, ' < 5 Years'],
#  [13.3, True, False, False, 'PyTorch', 79549, '10-15 Years'],
#  [17.3, True, False, True, 'TensorFlow', 61440, '15-20 Years'],
#  [0.31, False, False, True, None, 74808, ' < 5 Years'],
#  [1.7, True, True, False, None, 69191, ' < 5 Years'],
#  [1.1, True, False, False, 'Scikit-learn', 5414, ' < 5 Years'],
#  [2.5, True, False, False, 'Keras', 8027, ' < 5 Years'],
#  [2.4, False, True, False, None, 304, ' < 5 Years'],
#  [1.6, True, False, False, 'Keras', 68620, ' < 5 Years'],
#  [2.3, False, False, False, None, 68705, ' < 5 Years'],
#  [0.69, False, False, False, None, 3266, ' < 5 Years'],
#  [1.9, False, True, False, None, 56404, ' < 5 Years'],
#  [4.7, True, False, False, 'Keras', 72267, ' < 5 Years'],
#  [6.9, True, False, False, 'Scikit-learn', 15598, '5-10 Years'],
#  [1.8, True, False, False, 'TensorFlow', 756, ' < 5 Years'],
#  [4.4, True, False, False, 'Scikit-learn', 3064, ' < 5 Years'],
#  [0.44, True, False, False, None, 53474, ' < 5 Years'],
#  [2.4, True, False, True, None, 3446, ' < 5 Years'],
#  [0.64, True, False, True, 'TensorFlow', 50527, ' < 5 Years'],
#  [2.9, True, True, False, None, 54821, ' < 5 Years'],
#  [26.6, True, False, True, 'Keras', 154850, '25+ Years'],
#  [3.5, True, False, True, 'Scikit-learn', 65435, ' < 5 Years'],
#  [0.5, True, False, False, None, 73399, ' < 5 Years'],
#  [1.2, True, True, False, 'Scikit-learn', 64946, ' < 5 Years'],
#  [1.5, True, True, False, 'Scikit-learn', 18800, ' < 5 Years'],
#  [0.92, True, False, False, 'TensorFlow', 56757, ' < 5 Years'],
#  [4.0, True, False, True, 'TensorFlow', 2592, ' < 5 Years'],
#  [0.47, True, False, False, 'Scikit-learn', 16612, ' < 5 Years'],
#  [4.7, True, False, False, None, 19143, ' < 5 Years'],
#  [6.5, True, False, False, 'Keras', 59359, '5-10 Years'],
#  [0.5, False, True, False, None, 120711, ' < 5 Years'],
#  [4.7, True, True, True, 'PyTorch', 52082, ' < 5 Years'],
#  [0.75, True, False, True, None, 67918, ' < 5 Years'],
#  [0.28, True, True, False, None, 59017, ' < 5 Years'],
#  [2.8, False, False, True, None, 864, ' < 5 Years'],
#  [2.1, False, False, True, None, 664, ' < 5 Years'],
#  [7.3, True, False, True, 'Scikit-learn', 19284, '5-10 Years'],
#  [16.1, True, True, True, 'Scikit-learn', 217677, '15-20 Years'],
#  [0.0, False, False, False, None, 475180, ' < 5 Years'],
#  [0.0, False, False, False, None, 10746, ' < 5 Years'],
#  [4.8, True, False, False, 'Scikit-learn', 56503, ' < 5 Years'],
#  [9.8, False, False, True, 'Scikit-learn', 8359, '5-10 Years'],
#  [1.7, True, True, True, 'Keras', 378, ' < 5 Years'],
#  [23.9, True, False, False, 'TensorFlow', 70460, '20-25 Years'],
#  [0.92, True, False, True, 'Scikit-learn', 21123, ' < 5 Years'],
#  [0.7, True, False, True, 'TensorFlow', 62, ' < 5 Years'],
#  [0.68, True, False, True, 'TensorFlow', 11020, ' < 5 Years'],
#  [11.3, True, False, True, 'Scikit-learn', 12529, '10-15 Years'],
#  [23.9, True, False, False, 'PyTorch', 1325993, '20-25 Years'],
#  [3.0, True, True, False, None, 64688, ' < 5 Years'],
#  [0.62, False, False, False, 'Keras', 71694, ' < 5 Years'],
#  [4.5, False, True, False, None, 62257, ' < 5 Years'],
#  [27.4, True, False, True, 'TensorFlow', 66467, '25+ Years'],
#  [0.0, False, False, False, None, 57612, ' < 5 Years'],
#  [3.9, True, True, False, 'TensorFlow', 17739, ' < 5 Years'],
#  [3.8, True, False, True, 'TensorFlow', 103218, ' < 5 Years'],
#  [2.4, True, False, True, 'Scikit-learn', 1507, ' < 5 Years'],
#  [1.1, True, False, True, 'Scikit-learn', 7254, ' < 5 Years'],
#  [8.5, True, False, False, 'Scikit-learn', 54862, '5-10 Years'],
#  [5.4, True, False, True, 'Keras', 27111, '5-10 Years'],
#  [10.8, True, True, False, 'Keras', 20031, '10-15 Years'],
#  [1.6, True, False, True, 'Scikit-learn', 41563, ' < 5 Years'],
#  [1.7, True, False, False, None, 67010, ' < 5 Years'],
#  [4.7, True, False, True, 'Keras', 5784, ' < 5 Years'],
#  [16.8, False, False, False, None, 72308, '15-20 Years'],
#  [3.3, True, True, True, None, 22030, ' < 5 Years'],
#  [3.3, True, False, False, 'Scikit-learn', 67377, ' < 5 Years'],
#  [0.29, True, False, False, 'Keras', 796, ' < 5 Years'],
#  [10.1, True, False, True, None, 69368, '10-15 Years'],
#  [1.1, True, False, True, 'Scikit-learn', 72472, ' < 5 Years'],
#  [0.67, True, False, False, None, 63048, ' < 5 Years'],
#  [0.21, False, False, True, None, 9892, ' < 5 Years'],
#  [0.96, True, False, True, 'Scikit-learn', 56203, ' < 5 Years'],
#  [22.9, True, False, False, 'Keras', 48552, '20-25 Years'],
#  [3.5, True, False, False, 'TensorFlow', 72018, ' < 5 Years'],
#  [0.56, True, False, False, 'Scikit-learn', 13, ' < 5 Years'],
#  [0.64, True, False, False, None, 60665, ' < 5 Years'],
#  [4.9, True, False, True, 'PyTorch', 70969, ' < 5 Years'],
#  [3.7, True, False, True, 'Scikit-learn', 37353, ' < 5 Years'],
#  [7.7, True, False, True, 'TensorFlow', 13483, '5-10 Years'],
#  [2.6, True, False, True, 'Scikit-learn', 73574, ' < 5 Years'],
#  [0.44, False, False, False, None, 53506, ' < 5 Years'],
#  [3.9, True, False, True, 'TensorFlow', 26289, ' < 5 Years'],
#  [15.1, True, False, True, None, 43464, '15-20 Years'],
#  [4.2, True, False, True, None, 5122, ' < 5 Years'],
#  [3.8, True, False, False, 'TensorFlow', 5330, ' < 5 Years'],
#  [3.7, True, True, True, None, 8372, ' < 5 Years'],
#  [0.67, True, False, True, None, 63035, ' < 5 Years'],
#  [10.9, True, True, False, None, 287624, '10-15 Years'],
#  [1.8, True, False, False, 'PyTorch', 66297, ' < 5 Years'],
#  [2.7, True, False, False, None, 74909, ' < 5 Years'],
#  [2.7, True, True, False, None, 68897, ' < 5 Years'],
#  [1.1, True, False, False, 'TensorFlow', 55103, ' < 5 Years'],
#  [3.9, True, True, True, 'Scikit-learn', 65436, ' < 5 Years'],
#  [12.2, True, False, False, 'Scikit-learn', 83337, '10-15 Years'],
#  [29.2, True, False, True, 'Scikit-learn', 220415, '25+ Years'],
#  [0.31, False, False, False, None, 68892, ' < 5 Years'],
#  [5.6, True, True, True, 'Scikit-learn', 113998, '5-10 Years'],
#  [0.76, True, False, False, None, 61718, ' < 5 Years'],
#  [4.8, True, False, False, 'PyTorch', 621, ' < 5 Years'],
#  [22.8, True, True, True, 'Scikit-learn', 2830, '20-25 Years'],
#  [22.1, False, False, True, None, 174280, '20-25 Years'],
#  [9.8, True, False, False, 'Keras', 62136, '5-10 Years'],
#  [27.1, True, True, False, 'Scikit-learn', 80095, '25+ Years'],
#  [14.3, True, False, True, None, 88209, '10-15 Years'],
#  [3.5, True, False, False, 'Scikit-learn', 64470, ' < 5 Years'],
#  [6.9, True, False, True, 'Keras', 102277, '5-10 Years'],
#  [1.6, False, True, False, None, 53512, ' < 5 Years'],
#  [1.5, True, False, True, None, 71858, ' < 5 Years'],
#  [0.95, True, False, True, 'Keras', 1481, ' < 5 Years'],
#  [8.7, True, True, True, 'Scikit-learn', 70758, '5-10 Years'],
#  [2.4, True, False, False, 'Scikit-learn', 508, ' < 5 Years'],
#  [17.0, False, True, False, None, 17559, '15-20 Years'],
#  [0.93, True, False, True, None, 10373, ' < 5 Years'],
#  [3.8, True, False, False, 'Keras', 57164, ' < 5 Years'],
#  [2.5, True, True, True, 'PyTorch', 7724, ' < 5 Years'],
#  [7.1, True, False, False, 'TensorFlow', 54590, '5-10 Years'],
#  [29.3, False, True, False, None, 74891, '25+ Years'],
#  [4.1, True, False, True, 'PyTorch', 325, ' < 5 Years'],
#  [0.65, True, False, False, 'Keras', 554, ' < 5 Years'],
#  [2.8, False, True, True, None, 39643, ' < 5 Years'],
#  [4.9, True, False, True, 'Scikit-learn', 71105, ' < 5 Years'],
#  [3.6, True, False, True, 'Scikit-learn', 5051, ' < 5 Years'],
#  [8.5, True, False, True, 'PyTorch', 11048, '5-10 Years'],
#  [0.41, True, False, True, None, 74783, ' < 5 Years'],
#  [19.9, True, False, True, 'TensorFlow', 21353, '15-20 Years'],
#  [4.2, True, False, False, 'Scikit-learn', 682, ' < 5 Years'],
#  [26.5, True, True, True, 'Keras', 429315, '25+ Years'],
#  [2.6, True, False, True, 'Scikit-learn', 65441, ' < 5 Years'],
#  [5.4, True, False, False, 'PyTorch', 72536, '5-10 Years'],
#  [5.1, False, True, True, None, 119762, '5-10 Years'],
#  [23.1, True, True, False, 'Scikit-learn', 195277, '20-25 Years'],
#  [0.5, False, False, False, None, 69484, ' < 5 Years'],
#  [7.7, True, False, False, 'Scikit-learn', 185336, '5-10 Years'],
#  [6.8, True, False, False, 'Keras', 69491, '5-10 Years'],
#  [27.8, False, True, False, 'Keras', 714555, '25+ Years'],
#  [3.9, True, True, True, 'Scikit-learn', 72595, ' < 5 Years'],
#  [16.5, True, False, False, 'Scikit-learn', 872, '15-20 Years'],
#  [3.4, True, False, True, 'Scikit-learn', 141, ' < 5 Years'],
#  [20.3, True, False, True, 'TensorFlow', 268989, '20-25 Years'],
#  [1.1, True, False, True, 'TensorFlow', 4006, ' < 5 Years'],
#  [19.5, True, False, True, 'Keras', 9336, '15-20 Years'],
#  [2.0, True, False, True, 'TensorFlow', 3085, ' < 5 Years'],
#  [6.0, True, False, False, 'Scikit-learn', 62835, '5-10 Years'],
#  [2.6, True, True, True, 'Keras', 27020, ' < 5 Years'],
#  [2.3, True, False, False, 'Scikit-learn', 76, ' < 5 Years'],
#  [0.6, True, True, False, 'Scikit-learn', 38476, ' < 5 Years'],
#  [1.0, True, False, False, 'PyTorch', 70504, ' < 5 Years'],
#  [1.1, True, False, True, 'Scikit-learn', 6973, ' < 5 Years'],
#  [2.7, True, False, False, 'PyTorch', 544, ' < 5 Years'],
#  [3.9, True, False, False, None, 58032, ' < 5 Years'],
#  [0.43, True, False, True, None, 325, ' < 5 Years'],
#  [15.1, True, False, False, None, 74528, '15-20 Years'],
#  [0.58, False, True, True, None, 119, ' < 5 Years'],
#  [29.7, True, False, False, 'Scikit-learn', 20426, '25+ Years'],
#  [6.1, True, False, True, 'Scikit-learn', 41107, '5-10 Years'],
#  [1.1, True, False, False, 'TensorFlow', 11114, ' < 5 Years'],
#  [4.2, True, True, True, 'Scikit-learn', 31534, ' < 5 Years'],
#  [1.7, True, False, True, 'TensorFlow', 9606, ' < 5 Years'],
#  [2.5, True, False, True, None, 62179, ' < 5 Years'],
#  [1.3, True, False, True, 'TensorFlow', 58568, ' < 5 Years'],
#  [4.7, True, True, True, 'Scikit-learn', 9603, ' < 5 Years'],
#  [3.9, False, False, False, None, 9078, ' < 5 Years'],
#  [1.6, True, True, False, 'TensorFlow', 943, ' < 5 Years'],
#  [4.1, True, False, False, 'PyTorch', 52653, ' < 5 Years'],
#  [0.3, True, False, False, 'PyTorch', 221, ' < 5 Years'],
#  [3.6, True, False, False, None, 53034, ' < 5 Years'],
#  [4.6, True, False, True, 'TensorFlow', 11002, ' < 5 Years'],
#  [2.1, True, False, True, 'PyTorch', 53292, ' < 5 Years'],
#  [1.2, False, False, True, 'Scikit-learn', 456, ' < 5 Years'],
#  [0.32, True, False, True, None, 71624, ' < 5 Years'],
#  [1.1, True, False, True, None, 73324, ' < 5 Years'],
#  [14.8, True, True, True, 'Scikit-learn', 91644, '10-15 Years'],
#  [1.9, True, False, False, 'TensorFlow', 11855, ' < 5 Years'],
#  [9.0, True, False, True, 'Scikit-learn', 23530, '5-10 Years'],
#  [2.1, True, False, False, 'TensorFlow', 12407, ' < 5 Years'],
#  [2.3, True, False, False, 'Scikit-learn', 67512, ' < 5 Years'],
#  [3.9, True, False, True, 'TensorFlow', 968, ' < 5 Years'],
#  [0.47, False, False, False, None, 69126, ' < 5 Years'],
#  [0.52, True, False, False, 'Keras', 56472, ' < 5 Years'],
#  [0.74, True, False, False, None, 63077, ' < 5 Years'],
#  [4.9, True, True, True, 'TensorFlow', 52625, ' < 5 Years'],
#  [2.4, True, False, False, 'Keras', 68695, ' < 5 Years'],
#  [1.4, True, True, True, 'Keras', 6528, ' < 5 Years'],
#  [2.3, True, False, False, 'Scikit-learn', 64466, ' < 5 Years'],
#  [2.0, True, False, False, 'TensorFlow', 57584, ' < 5 Years'],
#  [21.5, True, True, True, 'Scikit-learn', 63587, '20-25 Years'],
#  [1.5, True, False, False, 'Scikit-learn', 64878, ' < 5 Years'],
#  [6.3, True, False, True, 'Keras', 2220, '5-10 Years'],
#  [4.5, True, False, False, 'Keras', 65180, ' < 5 Years'],
#  [0.98, True, False, False, None, 60218, ' < 5 Years'],
#  [2.2, True, False, True, 'Scikit-learn', 4645, ' < 5 Years'],
#  [2.4, True, False, False, 'Scikit-learn', 68252, ' < 5 Years'],
#  [0.86, True, False, True, None, 70314, ' < 5 Years'],
#  [0.39, True, False, True, None, 766, ' < 5 Years'],
#  [26.6, True, True, False, 'TensorFlow', 2030, '25+ Years'],
#  [1.3, True, False, False, 'TensorFlow', 54022, ' < 5 Years'],
#  [0.3, True, True, False, None, 53318, ' < 5 Years'],
#  [3.1, True, False, False, None, 56645, ' < 5 Years'],
#  [4.7, True, False, False, 'PyTorch', 52326, ' < 5 Years'],
#  [16.3, True, False, False, 'PyTorch', 97, '15-20 Years'],
#  [0.0, False, False, False, None, 11425, ' < 5 Years'],
#  [5.2, True, True, True, 'Scikit-learn', 36288, '5-10 Years'],
#  [2.5, True, False, False, 'Keras', 484, ' < 5 Years'],
#  [4.2, True, False, True, 'Keras', 4893, ' < 5 Years'],
#  [29.1, True, False, True, 'TensorFlow', 104484, '25+ Years'],
#  [2.5, True, False, False, None, 56945, ' < 5 Years'],
#  [1.1, True, False, False, None, 52839, ' < 5 Years'],
#  [1.9, True, False, False, None, 58164, ' < 5 Years'],
#  [4.2, True, False, True, 'Keras', 14807, ' < 5 Years'],
#  [1.2, True, False, False, None, 2789, ' < 5 Years'],
#  [1.7, True, True, False, None, 73427, ' < 5 Years'],
#  [0.47, True, False, False, None, 58350, ' < 5 Years'],
#  [0.84, True, False, True, 'Scikit-learn', 16755, ' < 5 Years'],
#  [4.1, True, False, True, 'Scikit-learn', 953, ' < 5 Years'],
#  [0.6, True, False, False, 'PyTorch', 65157, ' < 5 Years'],
#  [0.48, True, False, False, 'PyTorch', 67006, ' < 5 Years'],
#  [1.6, True, False, False, 'TensorFlow', 753, ' < 5 Years'],
#  [2.0, True, False, False, 'Keras', 59231, ' < 5 Years'],
#  [6.2, True, True, False, None, 69020, '5-10 Years'],
#  [2.7, True, False, False, 'Scikit-learn', 495, ' < 5 Years'],
#  [1.1, True, False, False, 'PyTorch', 42047, ' < 5 Years'],
#  [0.9, True, False, False, None, 64311, ' < 5 Years'],
#  [0.25, True, False, True, None, 4314, ' < 5 Years'],
#  [0.0, False, False, False, None, 623, ' < 5 Years'],
#  [3.4, True, False, True, 'PyTorch', 472, ' < 5 Years'],
#  [1.0, True, False, False, 'TensorFlow', 2724, ' < 5 Years'],
#  [0.56, True, False, True, 'Scikit-learn', 594, ' < 5 Years'],
#  [4.3, True, False, True, 'Keras', 10808, ' < 5 Years'],
#  [10.6, True, False, False, 'Keras', 69254, '10-15 Years'],
#  [4.8, True, False, False, 'Keras', 340, ' < 5 Years'],
#  [22.8, True, False, False, 'Scikit-learn', 39388, '20-25 Years'],
#  [4.9, True, False, False, 'PyTorch', 837, ' < 5 Years'],
#  [2.1, True, False, False, None, 65343, ' < 5 Years'],
#  [0.62, False, False, False, 'Scikit-learn', 65800, ' < 5 Years'],
#  [0.41, True, False, False, 'Keras', 639, ' < 5 Years'],
#  [3.7, True, False, True, 'TensorFlow', 378, ' < 5 Years'],
#  [9.7, True, True, False, 'Scikit-learn', 248, '5-10 Years'],
#  [10.6, True, False, True, None, 84270, '10-15 Years'],
#  [0.58, True, False, True, 'Scikit-learn', 88125, ' < 5 Years'],
#  [1.1, True, False, False, None, 47405, ' < 5 Years'],
#  [9.8, True, False, False, None, 55049, '5-10 Years'],
#  [2.9, True, True, False, None, 61031, ' < 5 Years'],
#  [0.0, False, False, False, None, 1869, ' < 5 Years'],
#  [21.7, True, False, True, 'Scikit-learn', 4317, '20-25 Years'],
#  [0.99, True, True, False, 'Scikit-learn', 64635, ' < 5 Years'],
#  [0.33, False, False, False, None, 51402, ' < 5 Years'],
#  [1.3, True, False, False, 'PyTorch', 21777, ' < 5 Years'],
#  [3.0, True, False, False, 'Scikit-learn', 50854, ' < 5 Years'],
#  [2.1, True, False, False, None, 181181, ' < 5 Years'],
#  [0.72, True, False, False, 'Scikit-learn', 56455, ' < 5 Years'],
#  [0.4, True, False, False, 'Scikit-learn', 55947, ' < 5 Years'],
#  [8.7, False, False, True, 'PyTorch', 1516, '5-10 Years'],
#  [7.7, True, True, False, 'PyTorch', 74963, '5-10 Years'],
#  [20.7, True, False, True, 'Scikit-learn', 283, '20-25 Years'],
#  [4.6, True, False, True, 'PyTorch', 24310, ' < 5 Years'],
#  [8.7, True, False, False, 'Scikit-learn', 46410, '5-10 Years'],
#  [0.94, True, True, True, 'TensorFlow', 1773, ' < 5 Years'],
#  [0.84, True, False, False, None, 63503, ' < 5 Years'],
#  [4.7, True, False, False, 'PyTorch', 8517, ' < 5 Years'],
#  [2.7, True, False, True, 'Scikit-learn', 677, ' < 5 Years'],
#  [2.3, True, False, False, 'Scikit-learn', 95980, ' < 5 Years'],
#  [2.7, True, False, False, 'Scikit-learn', 61704, ' < 5 Years'],
#  [2.7, True, False, True, 'TensorFlow', 2096, ' < 5 Years'],
#  [0.26, True, False, False, None, 3332, ' < 5 Years'],
#  [21.0, True, True, True, None, 74876, '20-25 Years'],
#  [2.7, False, False, False, None, 53241, ' < 5 Years'],
#  [3.3, True, False, True, 'Scikit-learn', 65015, ' < 5 Years'],
#  [4.5, True, False, True, 'PyTorch', 69794, ' < 5 Years'],
#  [1.1, True, False, True, 'Scikit-learn', 1688, ' < 5 Years'],
#  [3.9, True, False, False, 'PyTorch', 69211, ' < 5 Years'],
#  [0.82, True, False, False, 'PyTorch', 66810, ' < 5 Years'],
#  [1.8, True, False, False, None, 70512, ' < 5 Years'],
#  [4.4, True, False, False, 'PyTorch', 70396, ' < 5 Years'],
#  [1.7, False, False, False, 'TensorFlow', 54649, ' < 5 Years'],
#  [1.0, True, False, True, 'Scikit-learn', 163626, ' < 5 Years'],
#  [26.7, True, False, True, None, 20134, '25+ Years'],
#  [0.63, True, True, True, 'Scikit-learn', 50557, ' < 5 Years'],
#  [11.3, True, False, False, 'TensorFlow', 67548, '10-15 Years'],
#  [1.2, True, False, False, None, 835, ' < 5 Years'],
#  [2.1, True, False, False, 'TensorFlow', 74524, ' < 5 Years'],
#  [0.68, False, True, False, None, 55162, ' < 5 Years'],
#  [0.99, True, False, True, 'Scikit-learn', 66597, ' < 5 Years'],
#  [2.4, True, True, True, None, 73110, ' < 5 Years'],
#  [1.3, False, False, False, None, 63709, ' < 5 Years'],
#  [3.4, True, False, True, 'PyTorch', 181429, ' < 5 Years'],
#  [2.5, True, False, True, 'TensorFlow', 22534, ' < 5 Years'],
#  [2.7, True, False, False, 'Keras', 67768, ' < 5 Years'],
#  [13.7, True, False, True, 'Scikit-learn', 63167, '10-15 Years'],
#  [0.74, True, False, True, 'Keras', 211, ' < 5 Years'],
#  [2.9, True, False, False, None, 68852, ' < 5 Years'],
#  [3.4, True, True, False, 'Scikit-learn', 63195, ' < 5 Years'],
#  [24.8, True, True, False, None, 51234, '20-25 Years'],
#  [1.7, True, False, False, 'Keras', 954, ' < 5 Years'],
#  [12.4, True, False, True, 'PyTorch', 94385, '10-15 Years'],
#  [2.7, True, True, True, 'Scikit-learn', 67835, ' < 5 Years'],
#  [6.4, True, True, False, 'PyTorch', 256979, '5-10 Years'],
#  [0.41, True, False, False, 'Keras', 67498, ' < 5 Years'],
#  [15.9, True, True, True, 'Scikit-learn', 10541, '15-20 Years'],
#  [4.9, True, False, False, 'Scikit-learn', 2743, ' < 5 Years'],
#  [2.1, True, False, False, 'Keras', 2000, ' < 5 Years'],
#  [0.91, True, False, True, 'Scikit-learn', 52961, ' < 5 Years'],
#  [0.42, True, True, False, 'PyTorch', 542, ' < 5 Years'],
#  [1.1, True, False, False, 'Keras', 68699, ' < 5 Years'],
#  [4.0, True, False, False, 'TensorFlow', 270, ' < 5 Years'],
#  [0.99, True, False, True, None, 73596, ' < 5 Years'],
#  [0.6, True, False, False, 'Scikit-learn', 791, ' < 5 Years'],
#  [0.75, True, False, False, None, 65499, ' < 5 Years'],
#  [1.0, True, False, True, 'Scikit-learn', 9095, ' < 5 Years'],
#  [2.8, True, False, True, 'Scikit-learn', 56712, ' < 5 Years'],
#  [0.88, True, False, False, None, 64964, ' < 5 Years'],
#  [1.7, True, True, True, 'TensorFlow', 304, ' < 5 Years'],
#  [2.6, True, False, False, 'Keras', 27862, ' < 5 Years'],
#  [4.5, True, False, False, 'PyTorch', 56429, ' < 5 Years'],
#  [29.5, True, True, True, 'Scikit-learn', 56617, '25+ Years'],
#  [4.8, True, False, True, 'Scikit-learn', 4377, ' < 5 Years'],
#  [0.68, True, False, False, None, 66917, ' < 5 Years'],
#  [3.4, True, False, True, 'Scikit-learn', 40909, ' < 5 Years'],
#  [11.9, True, False, True, 'TensorFlow', 30501, '10-15 Years'],
#  [28.0, False, False, False, None, 95918, '25+ Years'],
#  [0.46, True, False, False, None, 52440, ' < 5 Years'],
#  [0.47, True, False, False, None, 51, ' < 5 Years'],
#  [7.9, True, False, True, 'Keras', 17570, '5-10 Years'],
#  [2.3, True, False, True, 'Scikit-learn', 26060, ' < 5 Years'],
#  [4.6, False, True, True, None, 19404, ' < 5 Years'],
#  [25.6, False, False, True, 'Scikit-learn', 20696, '25+ Years'],
#  [1.2, True, False, False, None, 53072, ' < 5 Years'],
#  [5.9, True, True, True, 'TensorFlow', 207422, '5-10 Years'],
#  [0.36, True, False, True, None, 54171, ' < 5 Years'],
#  [2.4, True, False, False, None, 67687, ' < 5 Years'],
#  [0.74, True, True, True, None, 61813, ' < 5 Years'],
#  [3.1, True, False, True, None, 2910, ' < 5 Years'],
#  [0.98, True, False, False, None, 851, ' < 5 Years'],
#  [1.5, True, False, False, None, 552, ' < 5 Years'],
#  [24.8, False, False, False, 'PyTorch', 64562, '20-25 Years'],
#  [2.9, True, True, True, None, 70663, ' < 5 Years'],
#  [5.8, True, False, True, None, 474, '5-10 Years'],
#  [2.2, False, False, False, None, 64573, ' < 5 Years'],
#  [0.91, True, False, False, None, 311, ' < 5 Years'],
#  [0.25, True, False, True, None, 804, ' < 5 Years'],
#  [7.4, True, False, True, 'TensorFlow', 14315, '5-10 Years'],
#  [3.3, True, False, True, 'Scikit-learn', 44540, ' < 5 Years'],
#  [1.8, True, False, False, 'Scikit-learn', 26130, ' < 5 Years'],
#  [27.3, False, False, True, None, 66962, '25+ Years'],
#  [3.8, True, True, True, 'Scikit-learn', 114075, ' < 5 Years'],
#  [0.48, True, False, False, 'Keras', 285, ' < 5 Years'],
#  [2.2, True, False, True, None, 52671, ' < 5 Years'],
#  [3.4, True, False, False, 'PyTorch', 88205, ' < 5 Years'],
#  [0.71, True, False, False, 'Scikit-learn', 31158, ' < 5 Years'],
#  [1.2, True, False, False, 'TensorFlow', 750, ' < 5 Years'],
#  [2.1, True, False, False, 'Scikit-learn', 64017, ' < 5 Years'],
#  [12.5, False, False, True, None, 71237, '10-15 Years'],
#  [7.0, True, False, False, 'PyTorch', 23040, '5-10 Years'],
#  [9.1, True, False, True, 'Keras', 30859, '5-10 Years'],
#  [4.5, True, False, True, 'Scikit-learn', 20431, ' < 5 Years'],
#  [1.1, True, True, True, 'TensorFlow', 16710, ' < 5 Years'],
#  [19.9, True, False, True, 'PyTorch', 12953, '15-20 Years'],
#  [2.4, True, False, True, 'Keras', 58403, ' < 5 Years'],
#  [25.9, True, False, True, 'TensorFlow', 237978, '25+ Years'],
#  [2.0, True, False, True, 'TensorFlow', 19659, ' < 5 Years'],
#  [3.4, False, False, True, None, 2090, ' < 5 Years'],
#  [3.8, True, True, True, 'TensorFlow', 44685, ' < 5 Years'],
#  [0.0, False, False, False, None, 729, ' < 5 Years'],
#  [7.3, True, False, False, 'PyTorch', 674, '5-10 Years'],
#  [0.44, True, False, False, None, 24801, ' < 5 Years'],
#  [0.66, True, False, True, None, 59184, ' < 5 Years'],
#  [1.9, True, False, True, 'PyTorch', 522, ' < 5 Years'],
#  [9.3, True, False, False, 'Scikit-learn', 75691, '5-10 Years'],
#  [1.4, True, False, True, 'Scikit-learn', 12092, ' < 5 Years'],
#  [0.34, True, False, True, 'Scikit-learn', 240163, ' < 5 Years'],
#  [0.47, True, False, False, None, 993, ' < 5 Years'],
#  [9.1, True, False, True, 'Keras', 51442, '5-10 Years'],
#  [3.3, True, True, True, 'PyTorch', 109344, ' < 5 Years'],
#  [3.5, True, False, True, 'Keras', 922, ' < 5 Years'],
#  [0.93, False, True, False, None, 68036, ' < 5 Years'],
#  [1.7, False, False, True, 'Scikit-learn', 16529, ' < 5 Years'],
#  [2.8, True, False, False, None, 53990, ' < 5 Years'],
#  [1.2, True, False, False, None, 52974, ' < 5 Years'],
#  [2.2, True, False, False, 'Scikit-learn', 66042, ' < 5 Years'],
#  [21.9, True, True, False, 'Scikit-learn', 50591, '20-25 Years'],
#  [13.6, True, False, False, 'Scikit-learn', 72511, '10-15 Years'],
#  [2.9, True, False, False, 'Scikit-learn', 57331, ' < 5 Years'],
#  [8.4, True, False, True, 'Scikit-learn', 33733, '5-10 Years'],
#  [0.69, True, True, False, 'Scikit-learn', 57104, ' < 5 Years'],
#  [4.7, True, False, False, 'Keras', 83630, ' < 5 Years'],
#  [0.54, True, False, True, None, 55929, ' < 5 Years'],
#  [0.22, True, False, False, None, 68255, ' < 5 Years'],
#  [3.2, True, False, True, None, 235, ' < 5 Years'],
#  [4.6, True, True, False, 'Keras', 69649, ' < 5 Years'],
#  [4.9, True, False, False, None, 71502, ' < 5 Years'],
#  [0.0, False, False, False, None, 52610, ' < 5 Years'],
#  [0.85, True, False, False, None, 62294, ' < 5 Years'],
#  [4.1, True, False, True, 'Keras', 1930, ' < 5 Years'],
#  [3.5, True, False, False, 'Scikit-learn', 4433, ' < 5 Years'],
#  [1.6, True, False, False, None, 62465, ' < 5 Years'],
#  [1.2, True, False, False, 'PyTorch', 54577, ' < 5 Years'],
#  [21.5, True, False, False, 'Scikit-learn', 54741, '20-25 Years'],
#  [4.6, True, True, True, 'TensorFlow', 68372, ' < 5 Years'],
#  [0.46, True, True, False, 'PyTorch', 1678, ' < 5 Years'],
#  [1.2, True, False, False, 'PyTorch', 51937, ' < 5 Years'],
#  [3.5, True, False, False, None, 50259, ' < 5 Years'],
#  [11.9, True, True, True, None, 43105, '10-15 Years'],
#  [0.67, False, False, True, 'Scikit-learn', 74182, ' < 5 Years'],
#  [3.7, True, False, False, 'Scikit-learn', 435, ' < 5 Years'],
#  [4.1, True, False, False, None, 61823, ' < 5 Years'],
#  [2.4, True, False, False, None, 64756, ' < 5 Years'],
#  [8.1, True, False, True, 'Scikit-learn', 32515, '5-10 Years'],
#  [2.5, True, False, True, 'TensorFlow', 53237, ' < 5 Years'],
#  [4.7, True, False, True, 'Scikit-learn', 73060, ' < 5 Years'],
#  [10.8, False, False, True, None, 1952, '10-15 Years'],
#  [1.1, True, False, False, 'Keras', 62007, ' < 5 Years'],
#  [3.4, True, False, True, 'Scikit-learn', 40814, ' < 5 Years'],
#  [7.4, True, False, True, 'TensorFlow', 7342, '5-10 Years'],
#  [3.6, True, False, True, 'Keras', 51046, ' < 5 Years'],
#  [4.5, True, True, True, 'Scikit-learn', 81841, ' < 5 Years'],
#  [29.3, True, False, True, 'PyTorch', 199761, '25+ Years'],
#  [4.5, True, False, False, 'PyTorch', 16697, ' < 5 Years'],
#  [1.3, True, True, False, 'PyTorch', 69434, ' < 5 Years'],
#  [8.0, True, False, True, 'Scikit-learn', 448, '5-10 Years'],
#  [0.37, True, True, False, None, 50606, ' < 5 Years'],
#  [2.2, True, False, False, None, 53658, ' < 5 Years'],
#  [0.0, False, False, False, None, 72, ' < 5 Years'],
#  [1.9, False, False, False, 'Scikit-learn', 2490, ' < 5 Years'],
#  [1.2, True, True, True, 'Scikit-learn', 94693, ' < 5 Years'],
#  [3.3, True, True, True, 'Scikit-learn', 228, ' < 5 Years'],
#  [4.2, True, False, False, 'TensorFlow', 70227, ' < 5 Years'],
#  [0.4, True, False, True, 'Scikit-learn', 55834, ' < 5 Years'],
#  [8.3, True, False, False, 'PyTorch', 68502, '5-10 Years'],
#  [2.1, True, False, True, 'Scikit-learn', 54306, ' < 5 Years'],
#  [7.2, True, False, True, 'Scikit-learn', 74862, '5-10 Years'],
#  [1.8, True, False, True, 'Scikit-learn', 8148, ' < 5 Years'],
#  [3.6, True, True, True, 'TensorFlow', 49765, ' < 5 Years'],
#  [2.2, True, False, False, 'Keras', 67123, ' < 5 Years'],
#  [20.0, True, True, True, 'Scikit-learn', 56786, '20-25 Years'],
#  [2.5, True, False, False, None, 67552, ' < 5 Years'],
#  [7.2, True, False, True, None, 29085, '5-10 Years'],
#  [28.9, True, True, True, 'Keras', 1605, '25+ Years'],
#  [0.37, True, False, False, None, 1051, ' < 5 Years'],
#  [0.32, True, True, True, None, 66, ' < 5 Years'],
#  [1.2, True, False, False, 'Scikit-learn', 58950, ' < 5 Years'],
#  [0.79, False, False, False, None, 53478, ' < 5 Years'],
#  [3.6, True, False, False, 'Scikit-learn', 94589, ' < 5 Years'],
#  [1.2, False, True, True, None, 63952, ' < 5 Years'],
#  [2.9, True, False, False, None, 74401, ' < 5 Years'],
#  [1.1, True, False, False, None, 55406, ' < 5 Years'],
#  [3.7, True, True, False, 'Scikit-learn', 1884, ' < 5 Years'],
#  [0.45, True, False, False, None, 668, ' < 5 Years'],
#  [0.65, True, False, True, 'Scikit-learn', 249, ' < 5 Years'],
#  [7.6, True, True, True, 'Scikit-learn', 4084, '5-10 Years'],
#  [1.2, True, False, True, None, 52869, ' < 5 Years'],
#  [1.8, True, False, True, None, 66135, ' < 5 Years'],
#  [0.82, False, True, False, None, 3158, ' < 5 Years'],
#  [0.36, True, False, False, 'Keras', 928, ' < 5 Years'],
#  [2.3, True, False, True, 'Scikit-learn', 5691, ' < 5 Years'],
#  [10.2, True, False, True, 'Scikit-learn', 37539, '10-15 Years'],
#  [27.7, True, False, True, None, 51024, '25+ Years'],
#  [0.79, True, False, True, 'Scikit-learn', 50807, ' < 5 Years'],
#  [9.2, False, True, False, None, 50326, '5-10 Years'],
#  [0.0, False, False, False, None, 285370, ' < 5 Years'],
#  [28.3, True, True, True, 'Keras', 33396, '25+ Years'],
#  [2.5, True, True, False, 'Scikit-learn', 449, ' < 5 Years'],
#  [0.28, True, True, True, 'Scikit-learn', 10908, ' < 5 Years'],
#  [1.5, True, True, False, 'PyTorch', 64432, ' < 5 Years'],
#  [2.6, True, False, False, 'PyTorch', 58564, ' < 5 Years'],
#  [3.0, True, False, False, 'Scikit-learn', 1836, ' < 5 Years'],
#  [2.5, True, False, False, 'Keras', 7811, ' < 5 Years'],
#  [1.2, True, True, False, 'TensorFlow', 231692, ' < 5 Years'],
#  [2.7, True, False, True, None, 55004, ' < 5 Years'],
#  [1.5, True, False, False, 'PyTorch', 61434, ' < 5 Years'],
#  [0.52, True, False, False, None, 8021, ' < 5 Years'],
#  [2.1, True, False, True, 'Scikit-learn', 71260, ' < 5 Years'],
#  [7.2, True, False, False, 'Scikit-learn', 67418, '5-10 Years'],
#  [0.0, False, False, False, None, 1658, ' < 5 Years'],
#  [26.1, True, False, False, 'Scikit-learn', 60604, '25+ Years'],
#  [5.8, True, False, True, 'TensorFlow', 50793, '5-10 Years'],
#  [1.2, True, False, False, 'Scikit-learn', 58006, ' < 5 Years'],
#  [1.1, True, False, False, 'PyTorch', 62797, ' < 5 Years'],
#  [19.7, True, False, False, 'Scikit-learn', 136952, '15-20 Years'],
#  [8.3, True, False, False, 'Scikit-learn', 20697, '5-10 Years'],
#  [2.2, True, True, True, None, 65569, ' < 5 Years'],
#  [7.0, True, True, True, 'TensorFlow', 65103, '5-10 Years'],
#  [3.6, True, False, True, 'Scikit-learn', 53249, ' < 5 Years'],
#  [0.69, True, False, True, 'Scikit-learn', 68526, ' < 5 Years'],
#  [1.9, True, False, False, None, 58783, ' < 5 Years'],
#  [0.23, True, True, False, 'Scikit-learn', 15653, ' < 5 Years'],
#  [2.2, True, False, True, 'Scikit-learn', 69180, ' < 5 Years'],
#  [5.1, True, False, False, 'Scikit-learn', 10107, '5-10 Years'],
#  [8.1, False, False, True, None, 18081, '5-10 Years'],
#  [0.0, False, False, False, None, 17145, ' < 5 Years'],
#  [4.3, True, False, True, 'Scikit-learn', 88001, ' < 5 Years'],
#  [2.3, False, False, True, None, 62331, ' < 5 Years'],
#  [21.3, True, True, True, None, 7735, '20-25 Years'],
#  [6.0, True, False, False, 'Scikit-learn', 4270, '5-10 Years'],
#  [8.0, True, False, True, 'Scikit-learn', 632, '5-10 Years'],
#  [25.9, True, False, True, 'Keras', 119802, '25+ Years'],
#  [3.7, False, True, True, None, 106198, ' < 5 Years'],
#  [2.2, True, False, False, 'PyTorch', 72387, ' < 5 Years'],
#  [4.8, False, False, False, None, 314, ' < 5 Years'],
#  [2.4, True, False, False, 'PyTorch', 64134, ' < 5 Years'],
#  [3.8, True, False, False, 'TensorFlow', 3838, ' < 5 Years'],
#  [0.0, False, False, False, None, 48741, ' < 5 Years'],
#  [0.87, True, False, False, None, 70982, ' < 5 Years'],
#  [10.6, True, True, True, 'TensorFlow', 82300, '10-15 Years'],
#  [1.1, True, False, True, 'Scikit-learn', 59359, ' < 5 Years'],
#  [1.2, True, False, True, 'PyTorch', 5371, ' < 5 Years'],
#  [4.0, True, False, False, 'PyTorch', 31675, ' < 5 Years'],
#  [4.3, False, False, False, None, 14342, ' < 5 Years'],
#  [1.8, True, False, True, 'Scikit-learn', 22274, ' < 5 Years'],
#  [6.8, True, False, True, 'Scikit-learn', 65291, '5-10 Years'],
#  [9.6, True, True, True, 'TensorFlow', 103779, '5-10 Years'],
#  [6.8, True, False, True, 'Scikit-learn', 205, '5-10 Years'],
#  [0.47, True, False, True, 'Scikit-learn', 4466, ' < 5 Years'],
#  [0.28, True, False, True, None, 69763, ' < 5 Years'],
#  [2.5, True, True, False, 'Scikit-learn', 94683, ' < 5 Years'],
#  [0.0, False, False, False, None, 385, ' < 5 Years'],
#  [0.0, False, False, False, None, 1327, ' < 5 Years'],
#  [1.2, True, False, False, 'Scikit-learn', 50663, ' < 5 Years'],
#  [8.1, True, False, False, 'TensorFlow', 784, '5-10 Years'],
#  [1.3, True, False, False, None, 61170, ' < 5 Years'],
#  [13.2, True, True, True, 'Keras', 467347, '10-15 Years'],
#  [17.7, True, False, False, 'Scikit-learn', 22412, '15-20 Years'],
#  [4.1, True, False, False, 'Scikit-learn', 55408, ' < 5 Years'],
#  [0.0, False, False, False, None, 6549, ' < 5 Years'],
#  [12.5, True, False, False, None, 88588, '10-15 Years'],
#  [0.46, True, False, False, 'Scikit-learn', 15108, ' < 5 Years'],
#  [0.37, True, True, True, None, 55108, ' < 5 Years'],
#  [1.7, True, False, False, 'Scikit-learn', 13784, ' < 5 Years'],
#  [8.6, True, False, True, 'Scikit-learn', 5432, '5-10 Years'],
#  [0.4, True, False, False, 'Scikit-learn', 700, ' < 5 Years'],
#  [1.5, True, True, True, 'Scikit-learn', 74964, ' < 5 Years'],
#  [1.5, True, False, False, 'TensorFlow', 64080, ' < 5 Years'],
#  [3.0, True, True, True, 'PyTorch', 67484, ' < 5 Years'],
#  [1.8, True, False, True, 'Keras', 957, ' < 5 Years'],
#  [0.86, False, True, False, None, 3874, ' < 5 Years'],
#  [1.0, True, False, True, 'Scikit-learn', 3548, ' < 5 Years'],
#  [3.7, True, False, False, 'TensorFlow', 29614, ' < 5 Years'],
#  [6.7, True, False, False, 'PyTorch', 15974, '5-10 Years'],
#  [4.2, True, False, True, None, 40734, ' < 5 Years'],
#  [12.2, True, False, False, 'Scikit-learn', 40187, '10-15 Years'],
#  [21.3, True, False, True, 'Scikit-learn', 2435, '20-25 Years'],
#  [4.7, True, False, False, 'Keras', 58695, ' < 5 Years'],
#  [29.3, True, False, False, 'TensorFlow', 131, '25+ Years'],
#  [1.2, True, False, True, 'Scikit-learn', 586, ' < 5 Years'],
#  [3.5, True, True, True, 'Keras', 60706, ' < 5 Years'],
#  [0.8, True, False, False, None, 65369, ' < 5 Years'],
#  [1.6, True, False, True, 'Scikit-learn', 70851, ' < 5 Years'],
#  [0.63, True, False, True, 'TensorFlow', 45383, ' < 5 Years'],
#  [7.8, True, True, True, 'Keras', 47719, '5-10 Years'],
#  [0.44, True, False, False, 'PyTorch', 55089, ' < 5 Years'],
#  [0.94, True, False, False, 'Keras', 160, ' < 5 Years'],
#  [6.6, True, True, False, 'TensorFlow', 5075, '5-10 Years'],
#  [4.1, True, False, False, 'Keras', 68860, ' < 5 Years'],
#  [28.0, True, False, True, 'Scikit-learn', 30081, '25+ Years'],
#  [4.5, True, False, False, 'TensorFlow', 242, ' < 5 Years'],
#  [2.9, True, False, False, None, 53412, ' < 5 Years'],
#  [0.88, True, False, True, None, 16074, ' < 5 Years'],
#  [2.4, True, False, False, None, 64949, ' < 5 Years'],
#  [4.6, True, True, False, 'Scikit-learn', 54879, ' < 5 Years'],
#  [0.27, True, False, False, 'TensorFlow', 13946, ' < 5 Years'],
#  [23.5, True, True, False, 'Scikit-learn', 11458, '20-25 Years'],
#  [4.4, False, True, False, None, 2133, ' < 5 Years'],
#  [0.3, False, False, False, None, 2464, ' < 5 Years'],
#  [10.1, True, False, True, 'Scikit-learn', 6851, '10-15 Years'],
#  [3.0, True, False, False, 'Scikit-learn', 52783, ' < 5 Years'],
#  [1.3, True, False, True, 'Scikit-learn', 2835, ' < 5 Years'],
#  [29.9, False, True, False, None, 87401, '25+ Years'],
#  [0.0, False, False, False, None, 5231, ' < 5 Years'],
#  [0.88, True, True, True, 'PyTorch', 72843, ' < 5 Years'],
#  [9.7, False, False, True, 'Scikit-learn', 57120, '5-10 Years'],
#  [10.4, True, False, False, 'Scikit-learn', 66116, '10-15 Years'],
#  [4.4, True, False, False, 'TensorFlow', 65177, ' < 5 Years'],
#  [13.4, False, False, True, 'TensorFlow', 55038, '10-15 Years'],
#  [2.2, True, True, True, 'Scikit-learn', 5974, ' < 5 Years'],
#  [0.59, True, False, False, 'Scikit-learn', 50939, ' < 5 Years'],
#  [1.5, True, False, False, 'Scikit-learn', 72461, ' < 5 Years'],
#  [4.5, True, False, False, 'Keras', 73525, ' < 5 Years'],
#  [4.8, True, False, True, None, 66489, ' < 5 Years'],
#  [6.1, True, False, False, 'Keras', 96275, '5-10 Years'],
#  [0.0, False, False, False, None, 36491, ' < 5 Years'],
#  [1.3, True, True, True, 'PyTorch', 72234, ' < 5 Years'],
#  [0.0, False, False, False, None, 105548, ' < 5 Years'],
#  [0.81, False, False, False, None, 63967, ' < 5 Years'],
#  [0.59, True, True, False, None, 691, ' < 5 Years'],
#  [2.3, True, False, True, 'PyTorch', 2842, ' < 5 Years'],
#  [2.4, True, False, False, 'PyTorch', 61426, ' < 5 Years'],
#  [25.6, True, False, False, None, 121443, '25+ Years'],
#  [4.1, True, False, True, 'PyTorch', 102677, ' < 5 Years'],
#  [5.7, True, False, False, 'TensorFlow', 2212, '5-10 Years'],
#  [2.7, True, False, False, 'Scikit-learn', 4674, ' < 5 Years'],
#  [14.0, False, False, False, None, 60794, '10-15 Years'],
#  [2.8, True, False, False, 'Scikit-learn', 51166, ' < 5 Years'],
#  [18.4, True, False, True, 'Scikit-learn', 97080, '15-20 Years'],
#  [4.2, True, False, True, None, 73558, ' < 5 Years'],
#  [1.6, True, False, False, 'TensorFlow', 14303, ' < 5 Years'],
#  [0.98, True, True, False, None, 53876, ' < 5 Years'],
#  [2.3, True, False, True, 'TensorFlow', 222, ' < 5 Years'],
#  [0.3, True, False, True, None, 65517, ' < 5 Years'],
#  [12.1, False, False, True, 'TensorFlow', 57106, '10-15 Years'],
#  [0.81, True, True, True, 'TensorFlow', 3113, ' < 5 Years'],
#  [0.33, True, False, False, 'TensorFlow', 51398, ' < 5 Years'],
#  [1.0, True, False, True, None, 59888, ' < 5 Years'],
#  [0.0, False, False, False, None, 61552, ' < 5 Years'],
#  [2.2, True, False, False, 'PyTorch', 330, ' < 5 Years'],
#  [3.2, True, False, True, None, 73091, ' < 5 Years'],
#  [4.9, True, True, True, 'TensorFlow', 348857, ' < 5 Years'],
#  [1.1, True, False, True, 'Scikit-learn', 34922, ' < 5 Years'],
#  [7.3, False, False, True, None, 28946, '5-10 Years'],
#  [1.6, True, False, True, 'Scikit-learn', 251, ' < 5 Years'],
#  [28.1, True, False, False, 'Scikit-learn', 127954, '25+ Years'],
#  [0.48, False, False, False, None, 42979, ' < 5 Years'],
#  [0.87, True, False, True, 'TensorFlow', 2857, ' < 5 Years'],
#  [1.2, True, True, False, None, 62429, ' < 5 Years'],
#  [0.45, False, False, False, 'Scikit-learn', 67300, ' < 5 Years'],
#  [19.1, False, True, False, None, 37878, '15-20 Years'],
#  [5.3, True, True, True, 'TensorFlow', 20461, '5-10 Years'],
#  [4.5, True, False, False, 'Scikit-learn', 63320, ' < 5 Years'],
#  [4.0, True, False, False, None, 58092, ' < 5 Years'],
#  [3.5, True, False, False, 'Keras', 60398, ' < 5 Years'],
#  [26.8, True, False, True, 'Scikit-learn', 99635, '25+ Years'],
#  [3.3, True, False, True, 'Scikit-learn', 60076, ' < 5 Years'],
#  [0.36, True, True, True, None, 6994, ' < 5 Years'],
#  [0.6, True, False, False, 'Scikit-learn', 9061, ' < 5 Years'],
#  [5.8, True, True, False, 'Scikit-learn', 4818, '5-10 Years'],
#  [1.0, True, False, True, 'Scikit-learn', 2899, ' < 5 Years'],
#  [1.7, True, False, False, 'Scikit-learn', 72529, ' < 5 Years'],
#  [0.38, True, False, True, 'Scikit-learn', 5952, ' < 5 Years'],
#  [0.82, True, False, False, None, 6170, ' < 5 Years'],
#  [0.63, False, False, False, None, 55022, ' < 5 Years'],
#  [3.3, True, False, True, 'Scikit-learn', 59462, ' < 5 Years'],
#  [0.22, False, False, False, None, 4151, ' < 5 Years'],
#  [0.61, True, True, False, 'PyTorch', 37957, ' < 5 Years'],
#  [0.86, True, False, False, 'Scikit-learn', 51120, ' < 5 Years'],
#  [0.72, True, True, False, None, 63950, ' < 5 Years'],
#  [21.9, True, False, False, 'TensorFlow', 54378, '20-25 Years'],
#  [0.35, True, False, False, 'PyTorch', 26655, ' < 5 Years'],
#  [1.4, True, False, False, 'Keras', 950, ' < 5 Years'],
#  [3.9, True, True, True, 'Scikit-learn', 43498, ' < 5 Years'],
#  [15.3, True, False, False, 'PyTorch', 12734, '15-20 Years'],
#  [0.0, False, False, False, None, 85, ' < 5 Years'],
#  [0.62, True, False, False, None, 1474, ' < 5 Years'],
#  [3.6, True, False, False, 'PyTorch', 54752, ' < 5 Years'],
#  [1.6, True, True, True, 'Keras', 68531, ' < 5 Years'],
#  [0.43, False, False, False, None, 68821, ' < 5 Years'],
#  [1.4, True, False, False, 'Scikit-learn', 73079, ' < 5 Years'],
#  [0.2, True, True, False, 'TensorFlow', 68161, ' < 5 Years'],
#  [1.3, True, False, False, 'TensorFlow', 56379, ' < 5 Years'],
#  [5.0, True, False, True, 'Scikit-learn', 20484, '5-10 Years'],
#  [1.8, True, False, False, 'Scikit-learn', 55935, ' < 5 Years'],
#  [22.8, False, True, False, 'TensorFlow', 15762, '20-25 Years'],
#  [0.89, True, False, False, None, 32, ' < 5 Years'],
#  [7.6, False, False, False, None, 63251, '5-10 Years'],
#  [0.0, False, False, False, None, 23805, ' < 5 Years'],
#  [17.6, True, True, True, 'Scikit-learn', 156337, '15-20 Years'],
#  [4.1, True, False, True, 'PyTorch', 166358, ' < 5 Years'],
#  [1.7, True, True, False, None, 67212, ' < 5 Years'],
#  [0.0, False, False, False, None, 1056, ' < 5 Years'],
#  [2.8, True, False, True, None, 59988, ' < 5 Years'],
#  [5.9, True, False, False, 'TensorFlow', 64018, '5-10 Years'],
#  [6.3, False, False, True, None, 50790, '5-10 Years'],
#  [6.8, True, True, False, 'Keras', 53074, '5-10 Years'],
#  [1.1, True, True, True, None, 2283, ' < 5 Years'],
#  [0.89, True, False, True, None, 62082, ' < 5 Years'],
#  [1.6, True, False, False, None, 73361, ' < 5 Years'],
#  [0.0, False, False, False, None, 313, ' < 5 Years'],
#  [8.7, True, False, True, 'Scikit-learn', 62075, '5-10 Years'],
#  [0.74, True, False, False, 'Scikit-learn', 50879, ' < 5 Years'],
#  [3.0, True, True, True, 'TensorFlow', 70120, ' < 5 Years'],
#  [2.3, True, False, False, 'TensorFlow', 694, ' < 5 Years'],
#  [0.38, False, False, False, None, 69857, ' < 5 Years'],
#  [0.48, True, False, False, None, 73213, ' < 5 Years'],
#  [12.2, True, True, False, 'Keras', 199185, '10-15 Years'],
#  [11.1, True, True, True, 'PyTorch', 393, '10-15 Years'],
#  [4.8, True, False, False, 'Keras', 1851, ' < 5 Years'],
#  [1.5, True, False, False, 'Scikit-learn', 64086, ' < 5 Years'],
#  [2.6, True, False, True, 'Scikit-learn', 59888, ' < 5 Years'],
#  [1.5, True, False, False, 'Scikit-learn', 492, ' < 5 Years'],
#  [0.76, True, True, False, 'Keras', 53603, ' < 5 Years'],
#  [15.1, True, False, True, 'Scikit-learn', 50554, '15-20 Years'],
#  [1.6, False, False, False, 'Scikit-learn', 60839, ' < 5 Years'],
#  [2.6, True, False, True, 'TensorFlow', 53295, ' < 5 Years'],
#  [21.7, True, False, True, 'TensorFlow', 94431, '20-25 Years'],
#  [2.0, True, False, True, None, 65423, ' < 5 Years'],
#  [1.4, True, False, False, 'Scikit-learn', 63389, ' < 5 Years'],
#  [0.36, True, False, False, 'Scikit-learn', 60688, ' < 5 Years'],
#  [5.0, True, False, False, None, 63539, '5-10 Years'],
#  [1.6, True, False, True, 'Scikit-learn', 7090, ' < 5 Years'],
#  [3.2, True, True, True, 'Scikit-learn', 59500, ' < 5 Years'],
#  [23.0, True, False, False, None, 92713, '20-25 Years'],
#  [3.1, True, False, False, 'Scikit-learn', 52941, ' < 5 Years'],
#  [1.9, False, False, False, 'Scikit-learn', 41582, ' < 5 Years'],
#  [5.1, False, False, False, None, 43918, '5-10 Years'],
#  [0.74, True, False, False, 'PyTorch', 58860, ' < 5 Years'],
#  [3.3, True, False, False, None, 74393, ' < 5 Years'],
#  [0.66, True, False, False, None, 73688, ' < 5 Years'],
#  [6.1, False, True, False, None, 66547, '5-10 Years'],
#  [8.6, True, False, False, None, 28737, '5-10 Years'],
#  [2.1, True, True, True, 'PyTorch', 575, ' < 5 Years'],
#  [1.7, True, False, False, 'Keras', 64756, ' < 5 Years'],
#  [0.71, True, False, False, 'PyTorch', 912, ' < 5 Years'],
#  [3.9, True, False, False, 'Keras', 51848, ' < 5 Years'],
#  [2.0, True, False, False, 'TensorFlow', 998, ' < 5 Years'],
#  [2.3, True, False, False, None, 58817, ' < 5 Years'],
#  [0.72, True, False, True, None, 1412, ' < 5 Years'],
#  [0.85, True, False, True, None, 568, ' < 5 Years'],
#  [16.5, False, True, False, 'Scikit-learn', 222960, '15-20 Years'],
#  [22.4, False, False, False, None, 122107, '20-25 Years'],
#  [0.28, True, False, True, None, 60331, ' < 5 Years'],
#  [4.3, True, True, False, 'TensorFlow', 67008, ' < 5 Years'],
#  [0.29, True, False, False, None, 51349, ' < 5 Years'],
#  [8.2, True, False, True, 'Scikit-learn', 57804, '5-10 Years'],
#  [3.3, False, False, False, None, 52600, ' < 5 Years'],
#  [5.7, True, False, False, 'TensorFlow', 53782, '5-10 Years'],
#  [6.8, True, True, True, 'Scikit-learn', 202388, '5-10 Years'],
#  [0.0, False, False, False, None, 112477, ' < 5 Years'],
#  [0.24, True, False, True, None, 67975, ' < 5 Years'],
#  [0.59, True, False, False, None, 62242, ' < 5 Years'],
#  [4.4, True, True, False, 'PyTorch', 4671, ' < 5 Years'],
#  [3.4, True, False, False, 'TensorFlow', 38713, ' < 5 Years'],
#  [22.2, False, True, True, None, 123702, '20-25 Years'],
#  [1.5, True, True, True, 'Keras', 2124, ' < 5 Years'],
#  [27.6, True, False, True, 'Keras', 42220, '25+ Years'],
#  [19.5, True, False, False, 'Scikit-learn', 52849, '15-20 Years'],
#  [9.7, True, False, True, 'TensorFlow', 65448, '5-10 Years'],
#  [2.5, True, False, True, 'Scikit-learn', 74521, ' < 5 Years'],
#  [13.9, True, False, False, None, 73873, '10-15 Years'],
#  [1.7, True, False, False, 'Scikit-learn', 54342, ' < 5 Years'],
#  [0.68, True, False, False, 'Scikit-learn', 533, ' < 5 Years'],
#  [2.8, True, False, True, None, 853, ' < 5 Years'],
#  [2.0, True, True, False, 'PyTorch', 56962, ' < 5 Years'],
#  [2.7, True, False, True, 'Keras', 51627, ' < 5 Years'],
#  [1.9, True, False, True, 'Keras', 69253, ' < 5 Years'],
#  [0.0, False, False, False, None, 829, ' < 5 Years'],
#  [0.85, False, False, False, 'Scikit-learn', 70634, ' < 5 Years'],
#  [0.0, False, False, False, None, 558, ' < 5 Years'],
#  [3.4, True, False, True, 'TensorFlow', 9494, ' < 5 Years'],
#  [6.1, True, False, True, 'Scikit-learn', 7915, '5-10 Years'],
#  [2.5, True, False, False, 'Scikit-learn', 65943, ' < 5 Years'],
#  [2.2, True, False, False, 'Scikit-learn', 55100, ' < 5 Years'],
#  [16.5, True, True, False, None, 50032, '15-20 Years'],
#  [2.2, True, False, False, 'Scikit-learn', 51541, ' < 5 Years'],
#  [4.9, True, False, True, 'PyTorch', 52086, ' < 5 Years'],
#  [29.5, True, False, True, 'Scikit-learn', 42492, '25+ Years'],
#  [16.3, True, False, False, 'TensorFlow', 34493, '15-20 Years'],
#  [9.0, True, False, False, 'Keras', 97047, '5-10 Years'],
#  [2.4, True, True, True, None, 71882, ' < 5 Years'],
#  [1.7, True, False, True, 'Scikit-learn', 21526, ' < 5 Years'],
#  [5.5, True, False, False, 'Scikit-learn', 102442, '5-10 Years'],
#  [1.3, True, False, False, 'Scikit-learn', 615, ' < 5 Years'],
#  [1.2, True, False, True, 'PyTorch', 61750, ' < 5 Years'],
#  [3.7, False, False, False, 'TensorFlow', 61860, ' < 5 Years'],
#  [2.3, True, False, False, 'TensorFlow', 1897, ' < 5 Years'],
#  [0.0, False, False, False, None, 2677, ' < 5 Years'],
#  [29.3, True, False, False, 'TensorFlow', 121310, '25+ Years'],
#  [27.9, True, False, False, 'Scikit-learn', 26614, '25+ Years'],
#  [28.8, True, True, True, 'Scikit-learn', 121013, '25+ Years'],
#  [4.9, True, False, False, 'Scikit-learn', 57955, ' < 5 Years'],
#  [0.74, True, True, True, None, 8364, ' < 5 Years'],
#  [4.4, True, False, True, 'Keras', 59946, ' < 5 Years'],
#  [1.3, True, False, False, 'Scikit-learn', 69104, ' < 5 Years'],
#  [0.5, True, False, False, 'PyTorch', 53402, ' < 5 Years'],
#  [3.1, True, False, False, 'TensorFlow', 30971, ' < 5 Years'],
#  [0.0, False, False, False, None, 3290, ' < 5 Years'],
#  [11.3, True, False, False, 'TensorFlow', 43863, '10-15 Years'],
#  [7.9, False, False, False, 'Scikit-learn', 137149, '5-10 Years'],
#  [0.51, False, False, False, None, 50576, ' < 5 Years'],
#  [4.0, True, False, False, 'PyTorch', 72622, ' < 5 Years'],
#  [1.9, True, False, True, 'Scikit-learn', 5526, ' < 5 Years'],
#  [2.4, True, False, True, 'Scikit-learn', 72583, ' < 5 Years'],
#  [0.28, False, False, False, None, 903, ' < 5 Years'],
#  [24.2, True, False, True, 'TensorFlow', 74740, '20-25 Years'],
#  [0.0, False, False, False, None, 165, ' < 5 Years'],
#  [3.7, True, False, False, None, 72056, ' < 5 Years'],
#  [4.8, True, True, True, 'Keras', 843, ' < 5 Years'],
#  [3.0, True, False, True, 'Scikit-learn', 38828, ' < 5 Years'],
#  [0.57, True, False, False, None, 51309, ' < 5 Years'],
#  [6.8, True, False, True, 'TensorFlow', 60132, '5-10 Years'],
#  [0.0, False, False, False, None, 712, ' < 5 Years'],
#  [2.0, True, True, False, None, 67213, ' < 5 Years'],
#  [1.6, True, True, True, None, 54485, ' < 5 Years'],
#  [0.58, True, False, True, None, 73763, ' < 5 Years'],
#  [2.5, True, False, False, 'PyTorch', 71343, ' < 5 Years'],
#  [5.0, False, True, False, 'Scikit-learn', 79118, '5-10 Years'],
#  [3.2, True, True, False, 'Keras', 70901, ' < 5 Years'],
#  [0.94, True, False, False, None, 57781, ' < 5 Years'],
#  [6.6, True, False, False, 'Keras', 10295, '5-10 Years'],
#  [0.41, False, False, False, None, 1780, ' < 5 Years'],
#  [5.0, True, False, False, 'Keras', 577, '5-10 Years'],
#  [1.0, True, True, False, 'PyTorch', 298, ' < 5 Years'],
#  [1.8, True, False, False, 'PyTorch', 2646, ' < 5 Years'],
#  [16.6, True, True, True, 'Scikit-learn', 47254, '15-20 Years'],
#  [3.8, True, False, True, None, 63511, ' < 5 Years'],
#  [1.1, True, False, True, None, 81362, ' < 5 Years'],
#  [1.7, True, False, False, None, 53894, ' < 5 Years'],
#  [9.2, True, False, False, 'PyTorch', 59061, '5-10 Years'],
#  [3.2, True, False, False, 'Scikit-learn', 108636, ' < 5 Years'],
#  [8.8, True, False, False, 'Scikit-learn', 12579, '5-10 Years'],
#  [4.8, True, False, False, None, 69950, ' < 5 Years'],
#  [15.1, False, False, False, 'PyTorch', 3633, '15-20 Years'],
#  [2.2, True, False, True, 'Scikit-learn', 50279, ' < 5 Years'],
#  [21.2, True, False, True, 'Scikit-learn', 56306, '20-25 Years'],
#  [1.6, True, False, False, 'PyTorch', 63038, ' < 5 Years'],
#  [1.1, True, True, True, 'Scikit-learn', 57327, ' < 5 Years'],
#  [2.6, True, False, False, 'TensorFlow', 406, ' < 5 Years'],
#  [4.2, True, False, False, 'TensorFlow', 68414, ' < 5 Years'],
#  [17.3, False, True, False, None, 7748, '15-20 Years'],
#  [2.8, True, True, False, 'Scikit-learn', 10606, ' < 5 Years'],
#  [4.1, True, False, False, 'PyTorch', 48165, ' < 5 Years'],
#  [2.2, False, True, False, None, 58642, ' < 5 Years'],
#  [2.4, True, True, False, 'Scikit-learn', 64553, ' < 5 Years'],
#  [0.47, False, True, False, None, 109516, ' < 5 Years'],
#  [2.3, True, False, True, 'Scikit-learn', 71433, ' < 5 Years'],
#  [4.1, True, False, False, 'TensorFlow', 66179, ' < 5 Years'],
#  [2.8, False, False, False, None, 59820, ' < 5 Years'],
#  [1.8, True, False, False, None, 61470, ' < 5 Years'],
#  [2.2, True, False, False, None, 61992, ' < 5 Years'],
#  [20.7, True, True, False, 'TensorFlow', 67565, '20-25 Years'],
#  [11.5, True, False, False, None, 59719, '10-15 Years'],
#  [9.8, False, False, True, None, 253449, '5-10 Years'],
#  [1.4, True, False, True, None, 68794, ' < 5 Years'],
#  [10.3, True, False, False, 'PyTorch', 68617, '10-15 Years'],
#  [4.0, True, False, True, 'PyTorch', 62480, ' < 5 Years'],
#  [0.95, True, True, False, 'TensorFlow', 3159, ' < 5 Years'],
#  [0.72, True, False, True, 'Scikit-learn', 25, ' < 5 Years'],
#  [1.2, True, True, True, None, 62653, ' < 5 Years'],
#  [3.6, True, True, True, 'TensorFlow', 884, ' < 5 Years'],
#  [1.3, True, False, True, None, 976, ' < 5 Years'],
#  [17.8, True, False, False, 'PyTorch', 52237, '15-20 Years'],
#  [9.7, True, False, False, 'PyTorch', 39154, '5-10 Years'],
#  [0.49, True, False, False, 'Scikit-learn', 56487, ' < 5 Years'],
#  [0.68, True, False, False, None, 73344, ' < 5 Years'],
#  [4.8, True, True, True, 'PyTorch', 64295, ' < 5 Years'],
#  [20.2, True, False, True, None, 4558, '20-25 Years'],
#  [5.8, True, False, False, 'Keras', 747, '5-10 Years'],
#  [15.3, False, False, False, 'TensorFlow', 1414, '15-20 Years'],
#  [0.7, True, False, True, None, 63674, ' < 5 Years'],
#  [0.25, True, False, False, 'Scikit-learn', 61954, ' < 5 Years'],
#  [0.66, True, False, False, None, 70382, ' < 5 Years'],
#  [0.87, True, False, True, 'Keras', 35715, ' < 5 Years'],
#  [2.1, True, False, False, 'PyTorch', 71969, ' < 5 Years'],
#  [2.0, True, False, False, 'Scikit-learn', 154, ' < 5 Years'],
#  [7.6, True, False, False, 'Scikit-learn', 585, '5-10 Years'],
#  [1.1, True, False, True, None, 53681, ' < 5 Years'],
#  [23.7, True, False, False, None, 75453, '20-25 Years'],
#  [14.3, False, True, False, None, 22660, '10-15 Years'],
#  [2.1, True, False, False, 'Keras', 666, ' < 5 Years'],
#  [0.69, True, False, True, 'Keras', 2261, ' < 5 Years'],
#  [3.0, True, True, False, 'TensorFlow', 59644, ' < 5 Years'],
#  [2.5, True, False, True, None, 261, ' < 5 Years'],
#  [1.1, True, False, False, 'PyTorch', 70418, ' < 5 Years'],
#  [2.4, True, False, False, 'TensorFlow', 53011, ' < 5 Years'],
#  [2.5, True, False, False, 'TensorFlow', 63167, ' < 5 Years'],
#  [8.3, True, False, False, 'Scikit-learn', 63972, '5-10 Years'],
#  [1.6, True, False, True, None, 52402, ' < 5 Years'],
#  [2.7, True, False, False, 'Scikit-learn', 72288, ' < 5 Years'],
#  [0.95, True, False, False, 'Keras', 338, ' < 5 Years'],
#  [7.6, True, False, True, 'Scikit-learn', 8656, '5-10 Years'],
#  [7.1, True, False, False, 'TensorFlow', 53896, '5-10 Years'],
#  [9.1, True, False, True, 'Keras', 25362, '5-10 Years'],
#  [5.3, True, False, True, 'Keras', 82007, '5-10 Years'],
#  [1.4, True, True, True, 'TensorFlow', 68031, ' < 5 Years'],
#  [2.3, True, False, False, None, 73681, ' < 5 Years'],
#  [27.8, False, False, False, None, 118531, '25+ Years'],
#  [1.5, True, False, True, None, 10408, ' < 5 Years'],
#  [5.5, True, False, False, 'PyTorch', 15620, '5-10 Years'],
#  [3.1, True, True, True, None, 69704, ' < 5 Years'],
#  [1.2, True, False, False, 'Keras', 3019, ' < 5 Years'],
#  [1.3, True, True, False, None, 63332, ' < 5 Years'],
#  [4.3, True, False, True, 'Scikit-learn', 35507, ' < 5 Years'],
#  [1.8, True, False, False, 'PyTorch', 89, ' < 5 Years'],
#  [2.3, True, False, False, 'Scikit-learn', 32501, ' < 5 Years'],
#  [4.4, True, False, True, 'Scikit-learn', 15014, ' < 5 Years'],
#  [0.8, True, False, False, 'PyTorch', 61762, ' < 5 Years'],
#  [0.88, False, True, False, None, 482, ' < 5 Years'],
#  [2.4, True, False, False, 'PyTorch', 51673, ' < 5 Years'],
#  [4.1, True, False, False, 'Scikit-learn', 50860, ' < 5 Years'],
#  [1.4, False, False, False, 'Scikit-learn', 115937, ' < 5 Years'],
#  [0.37, True, True, True, 'PyTorch', 71256, ' < 5 Years'],
#  [7.1, True, False, False, None, 62733, '5-10 Years'],
#  [5.0, True, False, True, None, 54685, '5-10 Years'],
#  [27.2, True, True, False, 'Scikit-learn', 25868, '25+ Years'],
#  [2.1, True, True, True, None, 51105, ' < 5 Years'],
#  [13.0, True, False, True, 'Scikit-learn', 32560, '10-15 Years'],
#  [1.4, True, False, False, 'TensorFlow', 7647, ' < 5 Years'],
#  [2.8, True, False, True, 'Scikit-learn', 54579, ' < 5 Years'],
#  [0.73, True, False, True, 'Scikit-learn', 72941, ' < 5 Years'],
#  [4.2, True, False, False, 'Scikit-learn', 36496, ' < 5 Years'],
#  [11.8, True, True, True, 'TensorFlow', 498506, '10-15 Years'],
#  [2.3, True, False, True, 'Scikit-learn', 866, ' < 5 Years'],
#  [0.67, True, False, False, 'Scikit-learn', 50507, ' < 5 Years'],
#  [1.9, True, False, False, None, 54852, ' < 5 Years'],
#  ...]

# %%
lessthan5 = []     # bins means ranges and isko commulative frequency bhi kha jata h
fiveto10 = []
tento15 = []
fifteento20 = []
twentyto25 = []
moretha25 = []


for i in survey:
    if i[-1] == " < 5 Years":
        lessthan5.append(i[-2])
    elif i[-1] == "5-10 Years":
        fiveto10.append(i[-2])
    elif i[-1] == "10-15 Years":
        tento15.append(i[-2])
    elif i[-1] == "15-20 Years":
        fifteento20.append(i[-2])
    elif i[-1] == "20-25 Years":
        twentyto25.append(i[-2])
    else:
        moretha25.append(i[-2])

# %%
lessthan5
# Out:
# [74321,
#  62593,
#  36288,
#  61302,
#  68984,
#  55418,
#  614,
#  70564,
#  55525,
#  61005,
#  21,
#  620,
#  73527,
#  6992,
#  22311,
#  1377,
#  69174,
#  65937,
#  27856,
#  903,
#  50501,
#  482,
#  70407,
#  8690,
#  73454,
#  8075,
#  59151,
#  70112,
#  70183,
#  2521,
#  63616,
#  31516,
#  4187,
#  64405,
#  114807,
#  632,
#  61157,
#  1194,
#  56553,
#  75177,
#  28009,
#  67074,
#  50059,
#  74321,
#  671,
#  837,
#  2011,
#  62937,
#  685,
#  41615,
#  52572,
#  51856,
#  411,
#  152,
#  8181,
#  2708,
#  68412,
#  6141,
#  3864,
#  24393,
#  70796,
#  21055,
#  59167,
#  55882,
#  73802,
#  79803,
#  73043,
#  14298,
#  68805,
#  73664,
#  434,
#  10284,
#  67971,
#  58465,
#  64488,
#  7709,
#  1957,
#  4131,
#  62593,
#  107644,
#  1047,
#  59909,
#  68344,
#  54427,
#  70930,
#  50835,
#  11681,
#  70991,
#  52416,
#  288146,
#  186,
#  60065,
#  431,
#  45413,
#  4196,
#  61912,
#  67272,
#  70264,
#  264,
#  55482,
#  26,
#  250,
#  66025,
#  63754,
#  70448,
#  68964,
#  58574,
#  330,
#  64478,
#  62142,
#  60873,
#  27748,
#  239,
#  332,
#  51428,
#  50783,
#  226,
#  8015,
#  450,
#  348,
#  59456,
#  62821,
#  59666,
#  57673,
#  29472,
#  5119,
#  282,
#  106203,
#  74289,
#  74445,
#  67736,
#  785,
#  28073,
#  20390,
#  4791,
#  73319,
#  44491,
#  74799,
#  57207,
#  14370,
#  57816,
#  62513,
#  59687,
#  67959,
#  1337,
#  72317,
#  66163,
#  11165,
#  388,
#  12925,
#  3092,
#  13423,
#  4704,
#  740,
#  63,
#  63155,
#  54825,
#  64184,
#  57821,
#  52061,
#  2279,
#  73945,
#  62225,
#  52153,
#  178,
#  553,
#  51701,
#  70917,
#  1672,
#  561,
#  32809,
#  61430,
#  2852,
#  341,
#  3241,
#  5068,
#  66719,
#  380,
#  104,
#  57262,
#  72756,
#  3458,
#  62798,
#  59402,
#  54542,
#  69584,
#  2762,
#  51493,
#  397,
#  13504,
#  69429,
#  62053,
#  20029,
#  64,
#  55068,
#  2756,
#  68080,
#  51110,
#  6055,
#  566,
#  57222,
#  8651,
#  50354,
#  67366,
#  3181,
#  50292,
#  51080,
#  9638,
#  15222,
#  748,
#  25696,
#  57599,
#  61169,
#  72278,
#  56628,
#  58598,
#  1920,
#  64650,
#  61957,
#  280,
#  53807,
#  62815,
#  55603,
#  59812,
#  10176,
#  330,
#  64186,
#  1426,
#  750,
#  64493,
#  79,
#  59061,
#  69723,
#  69452,
#  22665,
#  214,
#  3929,
#  58863,
#  8009,
#  68498,
#  1948,
#  69648,
#  65598,
#  54524,
#  66262,
#  4427,
#  31841,
#  54481,
#  57717,
#  25721,
#  12573,
#  71758,
#  835,
#  601,
#  61209,
#  365,
#  702,
#  67436,
#  73296,
#  58760,
#  70522,
#  59768,
#  1894,
#  98886,
#  797,
#  67900,
#  69490,
#  61535,
#  4951,
#  66662,
#  5345,
#  15827,
#  51943,
#  55361,
#  2284,
#  13232,
#  70,
#  51162,
#  58763,
#  57140,
#  53937,
#  55375,
#  74828,
#  584,
#  42097,
#  62804,
#  4296,
#  60567,
#  29160,
#  1491,
#  614,
#  181179,
#  55377,
#  21934,
#  65,
#  57123,
#  1943,
#  67032,
#  63358,
#  28,
#  3519,
#  356,
#  7226,
#  73268,
#  57188,
#  102,
#  123071,
#  250388,
#  70915,
#  201,
#  11378,
#  50638,
#  20749,
#  70675,
#  70432,
#  78601,
#  1282,
#  1503,
#  53171,
#  26960,
#  610,
#  69739,
#  3134,
#  55165,
#  988,
#  64966,
#  6350,
#  74951,
#  666,
#  106322,
#  60814,
#  70572,
#  68837,
#  62093,
#  54114,
#  979,
#  2235,
#  3303,
#  5145,
#  56213,
#  57850,
#  62878,
#  53195,
#  163016,
#  80274,
#  68870,
#  245,
#  72998,
#  61803,
#  269443,
#  58537,
#  160989,
#  21386,
#  51286,
#  27246,
#  894,
#  55032,
#  62407,
#  57986,
#  58495,
#  60397,
#  51395,
#  87556,
#  4853,
#  4795,
#  85067,
#  60649,
#  29055,
#  402,
#  12966,
#  55051,
#  55936,
#  72312,
#  55815,
#  57116,
#  71248,
#  2620,
#  72617,
#  5838,
#  51572,
#  70132,
#  53668,
#  59530,
#  253920,
#  549,
#  755,
#  38078,
#  525,
#  47261,
#  24554,
#  17937,
#  72360,
#  57700,
#  1524,
#  53965,
#  73004,
#  50276,
#  54145,
#  322,
#  574,
#  71045,
#  69120,
#  490,
#  72533,
#  250,
#  54947,
#  56963,
#  8316,
#  63330,
#  67994,
#  60833,
#  55193,
#  1788,
#  51397,
#  54401,
#  72472,
#  52835,
#  70275,
#  1833,
#  51048,
#  12130,
#  660,
#  4356,
#  48658,
#  67022,
#  55014,
#  74808,
#  69191,
#  5414,
#  8027,
#  304,
#  68620,
#  68705,
#  3266,
#  56404,
#  72267,
#  756,
#  3064,
#  53474,
#  3446,
#  50527,
#  54821,
#  65435,
#  73399,
#  64946,
#  18800,
#  56757,
#  2592,
#  16612,
#  19143,
#  120711,
#  52082,
#  67918,
#  59017,
#  864,
#  664,
#  475180,
#  10746,
#  56503,
#  378,
#  21123,
#  62,
#  11020,
#  64688,
#  71694,
#  62257,
#  57612,
#  17739,
#  103218,
#  1507,
#  7254,
#  41563,
#  67010,
#  5784,
#  22030,
#  67377,
#  796,
#  72472,
#  63048,
#  9892,
#  56203,
#  72018,
#  13,
#  60665,
#  70969,
#  37353,
#  73574,
#  53506,
#  26289,
#  5122,
#  5330,
#  8372,
#  63035,
#  66297,
#  74909,
#  68897,
#  55103,
#  65436,
#  68892,
#  61718,
#  621,
#  64470,
#  53512,
#  71858,
#  1481,
#  508,
#  10373,
#  57164,
#  7724,
#  325,
#  554,
#  39643,
#  71105,
#  5051,
#  74783,
#  682,
#  65441,
#  69484,
#  72595,
#  141,
#  4006,
#  3085,
#  27020,
#  76,
#  38476,
#  70504,
#  6973,
#  544,
#  58032,
#  325,
#  119,
#  11114,
#  31534,
#  9606,
#  62179,
#  58568,
#  9603,
#  9078,
#  943,
#  52653,
#  221,
#  53034,
#  11002,
#  53292,
#  456,
#  71624,
#  73324,
#  11855,
#  12407,
#  67512,
#  968,
#  69126,
#  56472,
#  63077,
#  52625,
#  68695,
#  6528,
#  64466,
#  57584,
#  64878,
#  65180,
#  60218,
#  4645,
#  68252,
#  70314,
#  766,
#  54022,
#  53318,
#  56645,
#  52326,
#  11425,
#  484,
#  4893,
#  56945,
#  52839,
#  58164,
#  14807,
#  2789,
#  73427,
#  58350,
#  16755,
#  953,
#  65157,
#  67006,
#  753,
#  59231,
#  495,
#  42047,
#  64311,
#  4314,
#  623,
#  472,
#  2724,
#  594,
#  10808,
#  340,
#  837,
#  65343,
#  65800,
#  639,
#  378,
#  88125,
#  47405,
#  61031,
#  1869,
#  64635,
#  51402,
#  21777,
#  50854,
#  181181,
#  56455,
#  55947,
#  24310,
#  1773,
#  63503,
#  8517,
#  677,
#  95980,
#  61704,
#  2096,
#  3332,
#  53241,
#  65015,
#  69794,
#  1688,
#  69211,
#  66810,
#  70512,
#  70396,
#  54649,
#  163626,
#  50557,
#  835,
#  74524,
#  55162,
#  66597,
#  73110,
#  63709,
#  181429,
#  22534,
#  67768,
#  211,
#  68852,
#  63195,
#  954,
#  67835,
#  67498,
#  2743,
#  2000,
#  52961,
#  542,
#  68699,
#  270,
#  73596,
#  791,
#  65499,
#  9095,
#  56712,
#  64964,
#  304,
#  27862,
#  56429,
#  4377,
#  66917,
#  40909,
#  52440,
#  51,
#  26060,
#  19404,
#  53072,
#  54171,
#  67687,
#  61813,
#  2910,
#  851,
#  552,
#  70663,
#  64573,
#  311,
#  804,
#  44540,
#  26130,
#  114075,
#  285,
#  52671,
#  88205,
#  31158,
#  750,
#  64017,
#  20431,
#  16710,
#  58403,
#  19659,
#  2090,
#  44685,
#  729,
#  24801,
#  59184,
#  522,
#  12092,
#  240163,
#  993,
#  109344,
#  922,
#  68036,
#  16529,
#  53990,
#  52974,
#  66042,
#  57331,
#  57104,
#  83630,
#  55929,
#  68255,
#  235,
#  69649,
#  71502,
#  52610,
#  62294,
#  1930,
#  4433,
#  62465,
#  54577,
#  68372,
#  1678,
#  51937,
#  50259,
#  74182,
#  435,
#  61823,
#  64756,
#  53237,
#  73060,
#  62007,
#  40814,
#  51046,
#  81841,
#  16697,
#  69434,
#  50606,
#  53658,
#  72,
#  2490,
#  94693,
#  228,
#  70227,
#  55834,
#  54306,
#  8148,
#  49765,
#  67123,
#  67552,
#  1051,
#  66,
#  58950,
#  53478,
#  94589,
#  63952,
#  74401,
#  55406,
#  1884,
#  668,
#  249,
#  52869,
#  66135,
#  3158,
#  928,
#  5691,
#  50807,
#  285370,
#  449,
#  10908,
#  64432,
#  58564,
#  1836,
#  7811,
#  231692,
#  55004,
#  61434,
#  8021,
#  71260,
#  1658,
#  58006,
#  62797,
#  65569,
#  53249,
#  68526,
#  58783,
#  15653,
#  69180,
#  17145,
#  88001,
#  62331,
#  106198,
#  72387,
#  314,
#  64134,
#  3838,
#  48741,
#  70982,
#  59359,
#  5371,
#  31675,
#  14342,
#  22274,
#  4466,
#  69763,
#  94683,
#  385,
#  1327,
#  50663,
#  61170,
#  55408,
#  6549,
#  15108,
#  55108,
#  13784,
#  700,
#  74964,
#  64080,
#  67484,
#  957,
#  3874,
#  3548,
#  29614,
#  40734,
#  58695,
#  586,
#  60706,
#  65369,
#  70851,
#  45383,
#  55089,
#  160,
#  68860,
#  242,
#  53412,
#  16074,
#  64949,
#  54879,
#  13946,
#  2133,
#  2464,
#  52783,
#  2835,
#  5231,
#  72843,
#  65177,
#  5974,
#  50939,
#  72461,
#  73525,
#  66489,
#  36491,
#  72234,
#  105548,
#  63967,
#  691,
#  2842,
#  61426,
#  102677,
#  4674,
#  51166,
#  73558,
#  14303,
#  53876,
#  222,
#  65517,
#  3113,
#  51398,
#  59888,
#  61552,
#  330,
#  73091,
#  348857,
#  34922,
#  251,
#  42979,
#  2857,
#  62429,
#  67300,
#  63320,
#  58092,
#  60398,
#  60076,
#  6994,
#  9061,
#  2899,
#  72529,
#  5952,
#  6170,
#  55022,
#  59462,
#  4151,
#  37957,
#  51120,
#  63950,
#  26655,
#  950,
#  43498,
#  85,
#  1474,
#  54752,
#  68531,
#  68821,
#  73079,
#  68161,
#  56379,
#  55935,
#  32,
#  23805,
#  166358,
#  67212,
#  1056,
#  59988,
#  2283,
#  62082,
#  73361,
#  313,
#  50879,
#  70120,
#  694,
#  69857,
#  73213,
#  1851,
#  64086,
#  59888,
#  492,
#  53603,
#  60839,
#  53295,
#  65423,
#  63389,
#  60688,
#  7090,
#  59500,
#  52941,
#  41582,
#  58860,
#  74393,
#  73688,
#  575,
#  64756,
#  912,
#  51848,
#  998,
#  58817,
#  1412,
#  568,
#  60331,
#  67008,
#  51349,
#  52600,
#  112477,
#  67975,
#  62242,
#  4671,
#  38713,
#  2124,
#  74521,
#  54342,
#  533,
#  853,
#  56962,
#  51627,
#  69253,
#  829,
#  70634,
#  558,
#  9494,
#  65943,
#  55100,
#  51541,
#  52086,
#  71882,
#  21526,
#  615,
#  61750,
#  61860,
#  1897,
#  2677,
#  57955,
#  8364,
#  59946,
#  69104,
#  53402,
#  30971,
#  3290,
#  50576,
#  72622,
#  5526,
#  72583,
#  903,
#  165,
#  72056,
#  843,
#  38828,
#  51309,
#  712,
#  67213,
#  ...]

# %%
min(lessthan5)
# Out:
# 0

# %%
max(lessthan5)
# Out:
# 1492951

# %%
len(lessthan5)
# Out:
# 18753

# %%
sum(lessthan5)/len(lessthan5)
# Out:
# 45047.87484669119

# %%
sum(fiveto10)/len(fiveto10)
# Out:
# 59312.82033470161

# %%
cat = [lessthan5, fiveto10,tento15, fifteento20,twentyto25, moretha25]

for c in cat:
    print(sum(c)/len(c))
# Out:
# 45047.87484669119
# 59312.82033470161
# 80226.75581395348
# 75101.82694106642
# 103159.80432432433
# 90444.98512221042

# %%
headers
# Out:
# ['experience_coding',
#  'python_user',
#  'r_user',
#  'sql_user',
#  'most_used',
#  'compensation']

# %%
headers.append("categories")

# %%
headers
# Out:
# ['experience_coding',
#  'python_user',
#  'r_user',
#  'sql_user',
#  'most_used',
#  'compensation',
#  'categories']

# %%
with open("updated_file.csv", mode='w', newline="") as new_file:
    writer  = csv.writer(new_file, delimiter = ",")
    writer.writerow(headers)
    writer.writerows(survey)

# %%
writer

# %%
dir(writer)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'dialect',
#  'writerow',
#  'writerows']
