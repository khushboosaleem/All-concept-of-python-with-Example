# %%
print("hello world")   # abc@gmai.com
# Out:
# hello world

# %%
print(hello world)
# Out:
#   File "<ipython-input-5-6135c6da936c>", line 1
#     print(hello world)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# " " srting "Ayaan"
# int 23
# float  2.0
# complex 2+j, 2j

# %%
print('ali's house')
# Out:
#   File "<ipython-input-7-70edbca7a2a6>", line 1
#     print('ali's house')
#                       ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("Ali's house")
# Out:
# Ali's house

# %%
print('hello world')
# Out:
# hello world

# %%
a = "khushboo saleem"
type(a)
# Out:
# str

# %%
a = 23
print(a)
type(a)
# Out:
# 23
# int

# %%
print(23.56)
# Out:
# 23.56

# %%
a = 23.56
type(a)
# Out:
# float

# %%
name = "Ayaan"
name
# Out:
# 'Ayaan'

# %%
print(name)
# Out:
# Ayaan

# %%
print("today is our 1st session
  and we are learning python")
# Out:
#   File "<ipython-input-21-53d9be063492>", line 1
#     print("today is our 1st session
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
""" today is our 1st session
  and we are learning python
""""
# Out:
#   File "<ipython-input-22-460c15f51cfb>", line 3
#     """"
#        ^
# SyntaxError: unterminated string literal (detected at line 3)

# %%
""" today is our 1st session
  and we are learning python
"""
# Out:
# ' today is our 1st session\n  and we are learning python\n'

# %%
print(""" today is our 1st session
  and we are learning python""")
# Out:
#  today is our 1st session
#   and we are learning python

# %%
2+3
# Out:
# 5

# %%
print(2+3)
# Out:
# 5

# %%
print(2*3)
# Out:
# 6

# %%
print(2.3.00)
# Out:
#   File "<ipython-input-27-27821ad7a57d>", line 1
#     print(2.3.00)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print(2j)
# Out:
# 2j

# %%
a = 2j
type(a)
# Out:
# complex

# %%
43.000000.000000

# %%
# print and without print
# check data type
# print int, float, complex
